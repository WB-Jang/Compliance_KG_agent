# %%
import re
from typing import List, Dict
from langchain_community.document_loaders import PyPDFLoader

# 은행 버전을 참조해서, 법령의 메타 데이터도 조문 안으로 들어가도록 설정하자
def _pdf_to_text(path: str) -> str:
    pdf_file = path
    loader = PyPDFLoader(pdf_file)
    pages = loader.load()
    text_for_delete = r"법제처\s+\d+\s+국가법령정보센터\n개인정보 보호법"
    law_text = "\n".join([re.sub(text_for_delete, "", p.page_content).strip() for p in pages])
    
    return law_text

def _parse_law(law_text):
    # 서문 분리
    # '^'로 시작하여 '제1장' 또는 '제1조' 직전까지의 모든 텍스트를 탐색 
    preamble_pattern = r'^(.*?)(?=제1장|제1조)'
    preamble = re.search(preamble_pattern, law_text, re.DOTALL)
    if preamble:
        preamble = preamble.group(1).strip()
    
    # 장 분리 
    # '제X장' 형식의 제목과 그 뒤에 오는 모든 조항을 하나의 그룹화 
    chapter_pattern = r'(제\d+장\s+.+?)\n((?:제\d+조(?:의\d+)?(?:\(\w+\))?.*?)(?=제\d+장|부칙|$))'
    chapters = re.findall(chapter_pattern, law_text, re.DOTALL)
    
    # 부칙 분리
    # '부칙'으로 시작하는 모든 텍스트를 탐색 
    appendix_pattern = r'(부칙.*)'
    appendix = re.search(appendix_pattern, law_text, re.DOTALL)
    if appendix:
        appendix = appendix.group(1)
    
    # 파싱 결과를 저장할 딕셔너리 초기화
    parsed_law = {'서문': preamble, '장': {}, '부칙': appendix}
    
    # 각 장 내에서 조 분리
    for chapter_title, chapter_content in chapters:
        # 조 분리 패턴
        # 1. '제X조'로 시작 ('제X조의Y' 형식도 가능)
        # 2. 조 번호 뒤에 반드시 '(항목명)' 형식의 제목이 와야 함 
        # 3. 다음 조가 시작되기 전까지 또는 문서의 끝까지의 모든 내용을 포함
        article_pattern = r'(제\d+조(?:의\d+)?\s*\([^)]+\).*?)(?=제\d+조(?:의\d+)?\s*\([^)]+\)|$)'
        
        # 정규표현식을 이용해 모든 조항을 탐색 
        articles = re.findall(article_pattern, chapter_content, re.DOTALL)
        
        # 각 조항의 앞뒤 공백을 제거하고 결과 딕셔너리에 저장
        parsed_law['장'][chapter_title.strip()] = [article.strip() for article in articles]

    law_list = []

    for law in parsed_law["장"].keys():
        for article in parsed_law["장"][law]:
            law_list.append(article)
    
    return law_list

# %%
law_text = _parse_law(_pdf_to_text("../../data/개인정보 보호법(법률)(제19234호)(20250313).pdf"))

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.document_loaders import PyPDFLoader
import requests
import json, os 
import numpy as np 
import re

# 임베딩 모델을 사용하고 은행에서 사용한 버전을 그대로 사용할 것
# llama server 사용 방식은 llama.cpp 폴더 안에 가이드 파일 참조

BASE_URL = "http://host.docker.internal:8080/v1" 

llm = ChatOpenAI(
    model="bge-m3",           # 서버에서 인식 가능한 임의의 모델명
    base_url=BASE_URL,
    api_key="sk-local-anything", # 의미없는 토큰도 OK
    temperature=0.7,
    max_tokens=512               # 서버 토큰 제한 고려
)

# %%
def _embedding(texts):
    """
    llama-server의 v1/embeddings 엔드 포인트를 사용해 bge-m3.gguf 임베딩 진행
    반환 결과 : (N,D) float32 numpy array
    N = chunk나 sentence 개수
    D = Vector의 차원(bge-m3는 1,024로 고정)
    """
    out = []
    for t in texts:
        vecs = None
        try:
            r= requests.post(f"{BASE_URL}/embeddings", json={"model": "bge-m3", "input": t}, timeout=45)
            if r.ok and "data" in r.json():
                vecs = r.json()["data"][0]["embedding"]
                v = np.array(vecs, dtype=np.float32)
                v /= (np.linalg.norm(v)+1e-12)
                out.append(v)
        except Exception:
            pass
    if vecs is None:
        raise RuntimeError(f"embedding API 실패 : {t}")

    return np.vstack(out).astype("float32")

# %%
embedded_law_text = _embedding(law_text)

# %%
embedded_law_text.shape
# Out:
# (112, 1024)

# %%
import numpy as np, networkx as nx
from sklearn.neighbors import NearestNeighbors

def _block_by_cosine(X: np.ndarray, k=8, sim_thresh=0.85):
    nbrs = NearestNeighbors(n_neighbors=min(k,len(X)), metric="cosine").fit(X)
    dists, idxs = nbrs.kneighbors(X)
    G = nx.Graph(); G.add_nodes_from(range(len(X)))
    for i,(dr,ir) in enumerate(zip(dists,idxs)):
        for d,j in zip(dr,ir):
            if i==j: continue
            sim = 1-d
            if sim>=sim_thresh: G.add_edge(i,j,weight=sim)
    return [sorted(list(c)) for c in nx.connected_components(G)]

# %%
blocked_embedded_texts = _block_by_cosine(embedded_law_text)

# %%
len(blocked_embedded_texts)
# Out:
# 98

# %%
from __future__ import annotations
import os, json
from typing import List, Dict, Type
from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import Runnable
from langchain_core.output_parsers import StrOutputParser

BASE_URL = "http://host.docker.internal:8080/v1" 

llm = ChatOpenAI(
    model="Midm-2.0-Base-Instruct-q4_0",           # 서버에서 인식 가능한 임의의 모델명
    base_url=BASE_URL,
    api_key="sk-local-anything", # 의미없는 토큰도 OK
    temperature=0.5,
    max_tokens=8192               # 서버 토큰 제한 고려
)

class Distilled(BaseModel):
    doc_type: str | None = None
    title: str | None = None
    authority: str | None = None
    effective_date: str | None = None
    amendments: list[dict] = Field(default_factory=list)
    articles: list[dict] = Field(default_factory=list)

class Entities(BaseModel):
    entities: list[dict]

class Relations(BaseModel):
    relations: list[dict]


DISTILL_SYS = ("""
당신은 법률/규제 문서를 정밀하게 요약·정제하는 역할을 합니다. 
    다음 지침을 반드시 지키세요: 
    - 제공된 텍스트에 근거하여 blueprint를 채우세요. 
    - 원문에 없는 경우 null로 표기하세요. 
    - 배열은 간결하게 유지하세요. 
    - 출력은 반드시 JSON 형식으로 하세요. 
    - 출력의 모든 값은 한국어로 작성하세요
""")

DISTILL_HUMAN = """
아래 blueprint를 기준으로 텍스트를 요약하여 채워 주세요.  
반드시 JSON으로만 출력하고, 값은 한국어로 작성해야 합니다.

Blueprint (JSON-like):
{blueprint}

텍스트 묶음 (의미적으로 유사한 그룹):
{joined_texts}

"""
ENT_SYS = ("""
당신은 한국어 법률 조문에서 핵심 엔티티를 추출하는 역할을 합니다.  
다음 지침을 반드시 지키세요:

- 출력은 JSON 형식으로만 하세요.
- canonical은 반드시 하나의 한국어 표현으로 지정하세요.
- aliases에는 약어, 다른 한국어 표현, 영어 번역명을 넣을 수 있습니다.
- 출력의 canonical, aliases, type, evidence 값은 반드시 한국어로 작성하세요.
- 조문 전체를 canonical로 두지 마세요. 원자적 개념(법률명, 조문번호, 정의된 용어, 기관명, 행위, 조건, 수치 등)만 추출하세요.
""")

ENT_HUMAN = """아래 텍스트에서 엔티티를 추출해 주세요.  
반드시 JSON으로만 출력하며, 키 이름은 정확히 'entities' 여야 합니다.  
출력 예시는 다음과 같습니다:

[{{
  "id":"e1",
  "canonical":"개인정보 보호법",
  "aliases":["개보법","Privacy Act"],
  "type":"법률",
  "source":["doc://개인정보보호법#제28조의2"],
  "evidence":["..."]
}},{{
  "id":"e2",
  "canonical":"제28조의2",
  "aliases":["가명정보의 처리"],
  "type":"조문",
  "source":["doc://개인정보보호법#제28조의2"],
  "evidence":["..."]
}}]

텍스트:
{distilled}
"""

REL_SYS = ("""
당신은 한국어 법률 조문에서 엔티티 간 관계를 추출하는 역할을 합니다.  
다음 지침을 반드시 지키세요:

- 출력은 JSON 형식으로만 하세요.
- 관계의 subject(s), predicate(p), object(o)는 모두 엔티티 canonical을 참조하세요.
- predicate 값은 한국어 동사 또는 명사구로 작성하세요. (예: "정의한다","허용한다","적용된다","발급한다","제한한다")
- evidence 값은 반드시 한국어 원문 일부를 그대로 인용하세요.
- 출력 JSON 이외의 설명은 하지 마세요.
""")
REL_HUMAN = """아래 엔티티와 텍스트를 참고하여 관계를 추출해 주세요.  
반드시 JSON으로만 출력하며, 키 이름은 정확히 'relations' 여야 합니다.  

엔티티:
{entities}

텍스트:
{distilled}
"""
# rels 추출에는 차라리 제로샷이 나은 듯. few shot은 그 예시에 너무 집착하는 듯한 모습을 보임
def _structured_chain(system: str, human: str, schema: Type[BaseModel]) -> Runnable:
    """
    - ChatPromptTemplate → ChatOpenAI(with_structured_output) 로 이어지는 체인
    - 입력: dict (프롬프트 변수)
    - 출력: Pydantic 모델 인스턴스
    """
    prompt = ChatPromptTemplate.from_messages(
        [("system", system), ("human", human)]
    )
    return prompt | llm.with_structured_output(schema)

# 체인 인스턴스
_distill_chain = _structured_chain(DISTILL_SYS, DISTILL_HUMAN, Distilled)
_entities_chain = _structured_chain(ENT_SYS, ENT_HUMAN, Entities)
_relations_chain = _structured_chain(REL_SYS, REL_HUMAN, Relations)

# ---------------------------
# 5) 공개 함수 (파이프 접점)
# ---------------------------
def distill_group(blueprint: dict, texts: List[str], max_chars: int = 16000) -> dict:
    """
    코사인 블로킹으로 묶인 텍스트들(gtexts)을 증류 블루프린트에 맞게 구조화.
    - blueprint: iText2KG 스타일 JSON 블루프린트
    - texts: 그룹 내 원문 단위 텍스트들 (gtexts)
    """
    joined = "\n---\n".join(texts)[:max_chars]
    out: Distilled = _distill_chain.invoke(
        {"blueprint": json.dumps(blueprint, ensure_ascii=False),
         "joined_texts": joined}
    )
    return out.model_dump()

def extract_entities(distilled: dict) -> dict:
    """
    증류 결과(distilled JSON)를 기반으로 '고유 개념' 엔터티 목록만 추출.
    """
    out: Entities = _entities_chain.invoke(
        {"distilled": json.dumps(distilled, ensure_ascii=False)}
    )
    return out.model_dump()

def extract_relations(distilled: dict, entities: dict) -> dict:
    """
    확정된 엔터티 집합을 컨텍스트로 관계 추출.
    """
    out: Relations = _relations_chain.invoke(
        {
            "distilled": json.dumps(distilled, ensure_ascii=False),
            "entities": json.dumps(entities, ensure_ascii=False),
        }
    )
    return out.model_dump()

# %%
gtexts = []
for gi,g in enumerate(blocked_embedded_texts):
    print(f'gi : {gi}, g : {g}')
    gtext=[law_text[i] for i in g]
    print(gtext)
    gtexts.append(gtext)
# Out:
# gi : 0, g : [0]
# ['제1조(목적) 이 법은 개인정보의 처리 및 보호에 관한 사항을 정함으로써 개인의 자유와 권리를 보호하고, 나아가 개인\n의 존엄과 가치를 구현함을 목적으로 한다. <개정 2014. 3. 24.>']
# gi : 1, g : [1]
# ['제2조(정의) 이 법에서 사용하는 용어의 뜻은 다음과 같다. <개정 2014. 3. 24., 2020. 2. 4., 2023. 3. 14.>\n1. “개인정보”란 살아 있는 개인에 관한 정보로서 다음 각 목의 어느 하나에 해당하는 정보를 말한다.\n가. 성명, 주민등록번호 및 영상 등을 통하여 개인을 알아볼 수 있는 정보\n나. 해당 정보만으로는 특정 개인을 알아볼 수 없더라도 다른 정보와 쉽게 결합하여 알아볼 수 있는 정보. 이 경우\n쉽게 결합할 수 있는지 여부는 다른 정보의 입수 가능성 등 개인을 알아보는 데 소요되는 시간, 비용, 기술 등\n을 합리적으로 고려하여야 한다.\n다. 가목 또는 나목을 제1호의2에 따라 가명처리함으로써 원래의 상태로 복원하기 위한 추가 정보의 사용ㆍ결합\n없이는 특정 개인을 알아볼 수 없는 정보(이하 “가명정보”라 한다)\n1의2. “가명처리”란 개인정보의 일부를 삭제하거나 일부 또는 전부를 대체하는 등의 방법으로 추가 정보가 없이는\n특정 개인을 알아볼 수 없도록 처리하는 것을 말한다.\n2. “처리”란 개인정보의 수집, 생성, 연계, 연동, 기록, 저장, 보유, 가공, 편집, 검색, 출력, 정정(訂正), 복구, 이용, 제공,\n공개, 파기(破棄), 그 밖에 이와 유사한 행위를 말한다.\n3. “정보주체”란 처리되는 정보에 의하여 알아볼 수 있는 사람으로서 그 정보의 주체가 되는 사람을 말한다.\n4. “개인정보파일”이란 개인정보를 쉽게 검색할 수 있도록 일정한 규칙에 따라 체계적으로 배열하거나 구성한 개인\n정보의 집합물(集合物)을 말한다.\n5. “개인정보처리자”란 업무를 목적으로 개인정보파일을 운용하기 위하여 스스로 또는 다른 사람을 통하여 개인정\n보를 처리하는 공공기관, 법인, 단체 및 개인 등을 말한다.\n6. “공공기관”이란 다음 각 목의 기관을 말한다.\n가. 국회, 법원, 헌법재판소, 중앙선거관리위원회의 행정사무를 처리하는 기관, 중앙행정기관(대통령 소속 기관과\n국무총리 소속 기관을 포함한다) 및 그 소속 기관, 지방자치단체\n나. 그 밖의 국가기관 및 공공단체 중 대통령령으로 정하는 기관\n7. “고정형 영상정보처리기기”란 일정한 공간에 설치되어 지속적 또는 주기적으로 사람 또는 사물의 영상 등을 촬영\n하거나 이를 유ㆍ무선망을 통하여 전송하는 장치로서 대통령령으로 정하는 장치를 말한다.\n7의2. “이동형 영상정보처리기기”란 사람이 신체에 착용 또는 휴대하거나 이동 가능한 물체에 부착 또는 거치(据置\n)하여 사람 또는 사물의 영상 등을 촬영하거나 이를 유ㆍ무선망을 통하여 전송하는 장치로서 대통령령으로 정하\n는 장치를 말한다.\n8. “과학적 연구”란 기술의 개발과 실증, 기초연구, 응용연구 및 민간 투자 연구 등 과학적 방법을 적용하는 연구를\n말한다.']
# gi : 2, g : [2]
# ['제3조(개인정보 보호 원칙) ① 개인정보처리자는 개인정보의 처리 목적을 명확하게 하여야 하고 그 목적에 필요한 범위\n에서 최소한의 개인정보만을 적법하고 정당하게 수집하여야 한다.\n② 개인정보처리자는 개인정보의 처리 목적에 필요한 범위에서 적합하게 개인정보를 처리하여야 하며, 그 목적 외\n의 용도로 활용하여서는 아니 된다.\n③ 개인정보처리자는 개인정보의 처리 목적에 필요한 범위에서 개인정보의 정확성, 완전성 및 최신성이 보장되도록\n하여야 한다.\n④ 개인정보처리자는 개인정보의 처리 방법 및 종류 등에 따라 정보주체의 권리가 침해받을 가능성과 그 위험 정도\n를 고려하여 개인정보를 안전하게 관리하여야 한다.\n⑤ 개인정보처리자는 제30조에 따른 개인정보 처리방침 등 개인정보의 처리에 관한 사항을 공개하여야 하며, 열람\n청구권 등 정보주체의 권리를 보장하여야 한다.<개정 2023. 3. 14.>\n⑥ 개인정보처리자는 정보주체의 사생활 침해를 최소화하는 방법으로 개인정보를 처리하여야 한다.\n⑦ 개인정보처리자는 개인정보를 익명 또는 가명으로 처리하여도 개인정보 수집목적을 달성할 수 있는 경우 익명\n처리가 가능한 경우에는 익명에 의하여, 익명처리로 목적을 달성할 수 없는 경우에는 가명에 의하여 처리될 수 있도\n록 하여야 한다.<개정 2020. 2. 4.>\n⑧ 개인정보처리자는 이 법 및 관계 법령에서 규정하고 있는 책임과 의무를 준수하고 실천함으로써 정보주체의 신\n뢰를 얻기 위하여 노력하여야 한다.']
# gi : 3, g : [3]
# ['제4조(정보주체의 권리) 정보주체는 자신의 개인정보 처리와 관련하여 다음 각 호의 권리를 가진다. <개정 2023. 3.\n14.>\n1. 개인정보의 처리에 관한 정보를 제공받을 권리\n2. 개인정보의 처리에 관한 동의 여부, 동의 범위 등을 선택하고 결정할 권리\n3. 개인정보의 처리 여부를 확인하고 개인정보에 대한 열람(사본의 발급을 포함한다. 이하 같다) 및 전송을 요구할\n권리\n4. 개인정보의 처리 정지, 정정ㆍ삭제 및 파기를 요구할 권리\n5. 개인정보의 처리로 인하여 발생한 피해를 신속하고 공정한 절차에 따라 구제받을 권리\n6. 완전히 자동화된 개인정보 처리에 따른 결정을 거부하거나 그에 대한 설명 등을 요구할 권리']
# gi : 4, g : [4]
# ['제5조(국가 등의 책무) ① 국가와 지방자치단체는 개인정보의 목적 외 수집, 오용ㆍ남용 및 무분별한 감시ㆍ추적 등에\n따른 폐해를 방지하여 인간의 존엄과 개인의 사생활 보호를 도모하기 위한 시책을 강구하여야 한다.\n② 국가와 지방자치단체는 제4조에 따른 정보주체의 권리를 보호하기 위하여 법령의 개선 등 필요한 시책을 마련하\n여야 한다.\n③ 국가와 지방자치단체는 만 14세 미만 아동이 개인정보 처리가 미치는 영향과 정보주체의 권리 등을 명확하게 알\n수 있도록 만 14세 미만 아동의 개인정보 보호에 필요한 시책을 마련하여야 한다.<신설 2023. 3. 14.>\n④ 국가와 지방자치단체는 개인정보의 처리에 관한 불합리한 사회적 관행을 개선하기 위하여 개인정보처리자의 자\n율적인 개인정보 보호활동을 존중하고 촉진ㆍ지원하여야 한다.<개정 2023. 3. 14.>\n⑤ 국가와 지방자치단체는 개인정보의 처리에 관한 법령 또는 조례를 적용할 때에는 정보주체의 권리가 보장될 수\n있도록 개인정보 보호 원칙에 맞게 적용하여야 한다.<개정 2023. 3. 14.>']
# gi : 5, g : [5]
# ['제6조(다른 법률과의 관계) ① 개인정보의 처리 및 보호에 관하여 다른 법률에 특별한 규정이 있는 경우를 제외하고는\n이 법에서 정하는 바에 따른다. <개정 2014. 3. 24., 2023. 3. 14.>\n② 개인정보의 처리 및 보호에 관한 다른 법률을 제정하거나 개정하는 경우에는 이 법의 목적과 원칙에 맞도록 하\n여야 한다.<신설 2023. 3. 14.>']
# gi : 6, g : [6]
# ['제7조(개인정보 보호위원회) ① 개인정보 보호에 관한 사무를 독립적으로 수행하기 위하여 국무총리 소속으로 개인정\n보 보호위원회(이하 “보호위원회”라 한다)를 둔다. <개정 2020. 2. 4.>\n② 보호위원회는 「정부조직법」 제2조에 따른 중앙행정기관으로 본다. 다만, 다음 각 호의 사항에 대하여는 「정부조\n직법」 제18조를 적용하지 아니한다.<개정 2020. 2. 4.>\n1. 제7조의8제3호 및 제4호의 사무\n2. 제7조의9제1항의 심의ㆍ의결 사항 중 제1호에 해당하는 사항\n③ 삭제<2020. 2. 4.>\n④ 삭제<2020. 2. 4.>\n⑤ 삭제<2020. 2. 4.>\n⑥ 삭제<2020. 2. 4.>\n⑦ 삭제<2020. 2. 4.>\n⑧ 삭제<2020. 2. 4.>\n⑨ 삭제<2020. 2. 4.>']
# gi : 7, g : [7]
# ['제7조의2(보호위원회의 구성 등) ① 보호위원회는 상임위원 2명(위원장 1명, 부위원장 1명)을 포함한 9명의 위원으로\n구성한다.\n② 보호위원회의 위원은 개인정보 보호에 관한 경력과 전문지식이 풍부한 다음 각 호의 사람 중에서 위원장과 부위\n원장은 국무총리의 제청으로, 그 외 위원 중 2명은 위원장의 제청으로, 2명은 대통령이 소속되거나 소속되었던 정당\n의 교섭단체 추천으로, 3명은 그 외의 교섭단체 추천으로 대통령이 임명 또는 위촉한다.\n1. 개인정보 보호 업무를 담당하는 3급 이상 공무원(고위공무원단에 속하는 공무원을 포함한다)의 직에 있거나 있었\n던 사람\n2. 판사ㆍ검사ㆍ변호사의 직에 10년 이상 있거나 있었던 사람\n3. 공공기관 또는 단체(개인정보처리자로 구성된 단체를 포함한다)에 3년 이상 임원으로 재직하였거나 이들 기관 또\n는 단체로부터 추천받은 사람으로서 개인정보 보호 업무를 3년 이상 담당하였던 사람\n4. 개인정보 관련 분야에 전문지식이 있고 「고등교육법」 제2조제1호에 따른 학교에서 부교수 이상으로 5년 이상 재\n직하고 있거나 재직하였던 사람\n③ 위원장과 부위원장은 정무직 공무원으로 임명한다.\n④ 위원장, 부위원장, 제7조의13에 따른 사무처의 장은 「정부조직법」 제10조에도 불구하고 정부위원이 된다.\n[본조신설 2020. 2. 4.]']
# gi : 8, g : [8]
# ['제7조의3(위원장) ① 위원장은 보호위원회를 대표하고, 보호위원회의 회의를 주재하며, 소관 사무를 총괄한다.\n② 위원장이 부득이한 사유로 직무를 수행할 수 없을 때에는 부위원장이 그 직무를 대행하고, 위원장ㆍ부위원장이\n모두 부득이한 사유로 직무를 수행할 수 없을 때에는 위원회가 미리 정하는 위원이 위원장의 직무를 대행한다.\n③ 위원장은 국회에 출석하여 보호위원회의 소관 사무에 관하여 의견을 진술할 수 있으며, 국회에서 요구하면 출석\n하여 보고하거나 답변하여야 한다.\n④ 위원장은 국무회의에 출석하여 발언할 수 있으며, 그 소관 사무에 관하여 국무총리에게 의안 제출을 건의할 수\n있다.\n[본조신설 2020. 2. 4.]']
# gi : 9, g : [9]
# ['제7조의4(위원의 임기) ① 위원의 임기는 3년으로 하되, 한 차례만 연임할 수 있다.\n② 위원이 궐위된 때에는 지체 없이 새로운 위원을 임명 또는 위촉하여야 한다. 이 경우 후임으로 임명 또는 위촉된\n위원의 임기는 새로이 개시된다.\n[본조신설 2020. 2. 4.]']
# gi : 10, g : [10, np.int64(80)]
# ['제7조의5(위원의 신분보장) ① 위원은 다음 각 호의 어느 하나에 해당하는 경우를 제외하고는 그 의사에 반하여 면직\n또는 해촉되지 아니한다.\n1. 장기간 심신장애로 인하여 직무를 수행할 수 없게 된 경우\n2. 제7조의7의 결격사유에 해당하는 경우\n3. 이 법 또는 그 밖의 다른 법률에 따른 직무상의 의무를 위반한 경우\n② 위원은 법률과 양심에 따라 독립적으로 직무를 수행한다.\n[본조신설 2020. 2. 4.]', '제41조(위원의 신분보장) 위원은 자격정지 이상의 형을 선고받거나 심신상의 장애로 직무를 수행할 수 없는 경우를 제\n외하고는 그의 의사에 반하여 면직되거나 해촉되지 아니한다.']
# gi : 11, g : [11]
# ['제7조의6(겸직금지 등) ① 위원은 재직 중 다음 각 호의 직(職)을 겸하거나 직무와 관련된 영리업무에 종사하여서는 아\n니 된다.\n1. 국회의원 또는 지방의회의원\n2. 국가공무원 또는 지방공무원\n3. 그 밖에 대통령령으로 정하는 직\n② 제1항에 따른 영리업무에 관한 사항은 대통령령으로 정한다.\n③ 위원은 정치활동에 관여할 수 없다.\n[본조신설 2020. 2. 4.]']
# gi : 12, g : [12]
# ['제7조의7(결격사유) ① 다음 각 호의 어느 하나에 해당하는 사람은 위원이 될 수 없다.\n1. 대한민국 국민이 아닌 사람\n2. 「국가공무원법」 제33조 각 호의 어느 하나에 해당하는 사람\n3. 「정당법」 제22조에 따른 당원\n② 위원이 제1항 각 호의 어느 하나에 해당하게 된 때에는 그 직에서 당연 퇴직한다. 다만, 「국가공무원법」 제33조\n제2호는 파산선고를 받은 사람으로서 「채무자 회생 및 파산에 관한 법률」에 따라 신청기한 내에 면책신청을 하지\n아니하였거나 면책불허가 결정 또는 면책 취소가 확정된 경우만 해당하고, 같은 법 제33조제5호는 「형법」 제129조\n부터 제132조까지, 「성폭력범죄의 처벌 등에 관한 특례법」 제2조, 「아동ㆍ청소년의 성보호에 관한 법률」 제2조제\n2호 및 직무와 관련하여 「형법」 제355조 또는 제356조에 규정된 죄를 범한 사람으로서 금고 이상의 형의 선고유예\n를 받은 경우만 해당한다.\n[본조신설 2020. 2. 4.]']
# gi : 13, g : [13]
# ['제7조의8(보호위원회의 소관 사무) 보호위원회는 다음 각 호의 소관 사무를 수행한다. <개정 2023. 3. 14.>\n1. 개인정보의 보호와 관련된 법령의 개선에 관한 사항\n2. 개인정보 보호와 관련된 정책ㆍ제도ㆍ계획 수립ㆍ집행에 관한 사항\n3. 정보주체의 권리침해에 대한 조사 및 이에 따른 처분에 관한 사항\n4. 개인정보의 처리와 관련한 고충처리ㆍ권리구제 및 개인정보에 관한 분쟁의 조정\n5. 개인정보 보호를 위한 국제기구 및 외국의 개인정보 보호기구와의 교류ㆍ협력\n6. 개인정보 보호에 관한 법령ㆍ정책ㆍ제도ㆍ실태 등의 조사ㆍ연구, 교육 및 홍보에 관한 사항\n7. 개인정보 보호에 관한 기술개발의 지원ㆍ보급, 기술의 표준화 및 전문인력의 양성에 관한 사항\n8. 이 법 및 다른 법령에 따라 보호위원회의 사무로 규정된 사항\n[본조신설 2020. 2. 4.]']
# gi : 14, g : [14]
# ['제7조의9(보호위원회의 심의ㆍ의결 사항 등) ① 보호위원회는 다음 각 호의 사항을 심의ㆍ의결한다. <개정 2023. 3.\n14.>\n1. 제8조의2에 따른 개인정보 침해요인 평가에 관한 사항\n2. 제9조에 따른 기본계획 및 제10조에 따른 시행계획에 관한 사항\n3. 개인정보 보호와 관련된 정책, 제도 및 법령의 개선에 관한 사항\n4. 개인정보의 처리에 관한 공공기관 간의 의견조정에 관한 사항\n5. 개인정보 보호에 관한 법령의 해석ㆍ운용에 관한 사항\n6. 제18조제2항제5호에 따른 개인정보의 이용ㆍ제공에 관한 사항\n6의2. 제28조의9에 따른 개인정보의 국외 이전 중지 명령에 관한 사항\n7. 제33조제4항에 따른 영향평가 결과에 관한 사항\n8. 제64조의2에 따른 과징금 부과에 관한 사항\n9. 제61조에 따른 의견제시 및 개선권고에 관한 사항\n9의2. 제63조의2제2항에 따른 시정권고에 관한 사항\n10. 제64조에 따른 시정조치 등에 관한 사항\n11. 제65조에 따른 고발 및 징계권고에 관한 사항\n12. 제66조에 따른 처리 결과의 공표 및 공표명령에 관한 사항\n13. 제75조에 따른 과태료 부과에 관한 사항\n14. 소관 법령 및 보호위원회 규칙의 제정ㆍ개정 및 폐지에 관한 사항\n15. 개인정보 보호와 관련하여 보호위원회의 위원장 또는 위원 2명 이상이 회의에 부치는 사항\n16. 그 밖에 이 법 또는 다른 법령에 따라 보호위원회가 심의ㆍ의결하는 사항\n② 보호위원회는 제1항 각 호의 사항을 심의ㆍ의결하기 위하여 필요한 경우 다음 각 호의 조치를 할 수 있다.\n1. 관계 공무원, 개인정보 보호에 관한 전문 지식이 있는 사람이나 시민사회단체 및 관련 사업자로부터의 의견 청취\n2. 관계 기관 등에 대한 자료제출이나 사실조회 요구\n③ 제2항제2호에 따른 요구를 받은 관계 기관 등은 특별한 사정이 없으면 이에 따라야 한다.\n④ 보호위원회는 제1항제3호의 사항을 심의ㆍ의결한 경우에는 관계 기관에 그 개선을 권고할 수 있다.\n⑤ 보호위원회는 제4항에 따른 권고 내용의 이행 여부를 점검할 수 있다.\n[본조신설 2020. 2. 4.]']
# gi : 15, g : [15]
# ['제7조의10(회의) ① 보호위원회의 회의는 위원장이 필요하다고 인정하거나 재적위원 4분의 1 이상의 요구가 있는 경우\n에 위원장이 소집한다.\n② 위원장 또는 2명 이상의 위원은 보호위원회에 의안을 제의할 수 있다.\n③ 보호위원회의 회의는 재적위원 과반수의 출석으로 개의하고, 출석위원 과반수의 찬성으로 의결한다.\n[본조신설 2020. 2. 4.]']
# gi : 16, g : [16, np.int64(81)]
# ['제7조의11(위원의 제척ㆍ기피ㆍ회피) ① 위원은 다음 각 호의 어느 하나에 해당하는 경우에는 심의ㆍ의결에서 제척된\n다.\n1. 위원 또는 그 배우자나 배우자였던 자가 해당 사안의 당사자가 되거나 그 사건에 관하여 공동의 권리자 또는 의\n무자의 관계에 있는 경우\n2. 위원이 해당 사안의 당사자와 친족이거나 친족이었던 경우\n3. 위원이 해당 사안에 관하여 증언, 감정, 법률자문을 한 경우\n4. 위원이 해당 사안에 관하여 당사자의 대리인으로서 관여하거나 관여하였던 경우\n5. 위원이나 위원이 속한 공공기관ㆍ법인 또는 단체 등이 조언 등 지원을 하고 있는 자와 이해관계가 있는 경우\n② 위원에게 심의ㆍ의결의 공정을 기대하기 어려운 사정이 있는 경우 당사자는 기피 신청을 할 수 있고, 보호위원회\n는 의결로 이를 결정한다.\n③ 위원이 제1항 또는 제2항의 사유가 있는 경우에는 해당 사안에 대하여 회피할 수 있다.\n[본조신설 2020. 2. 4.]', '제42조(위원의 제척ㆍ기피ㆍ회피) ① 분쟁조정위원회의 위원은 다음 각 호의 어느 하나에 해당하는 경우에는 제43조제\n1항에 따라 분쟁조정위원회에 신청된 분쟁조정사건(이하 이 조에서 “사건”이라 한다)의 심의ㆍ의결에서 제척(除斥\n)된다.\n1. 위원 또는 그 배우자나 배우자였던 자가 그 사건의 당사자가 되거나 그 사건에 관하여 공동의 권리자 또는 의무\n자의 관계에 있는 경우\n2. 위원이 그 사건의 당사자와 친족이거나 친족이었던 경우\n3. 위원이 그 사건에 관하여 증언, 감정, 법률자문을 한 경우\n4. 위원이 그 사건에 관하여 당사자의 대리인으로서 관여하거나 관여하였던 경우\n② 당사자는 위원에게 공정한 심의ㆍ의결을 기대하기 어려운 사정이 있으면 위원장에게 기피신청을 할 수 있다. 이\n경우 위원장은 기피신청에 대하여 분쟁조정위원회의 의결을 거치지 아니하고 결정한다.\n③ 위원이 제1항 또는 제2항의 사유에 해당하는 경우에는 스스로 그 사건의 심의ㆍ의결에서 회피할 수 있다.']
# gi : 17, g : [17]
# ['제7조의12(소위원회) ① 보호위원회는 효율적인 업무 수행을 위하여 개인정보 침해 정도가 경미하거나 유사ㆍ반복되\n는 사항 등을 심의ㆍ의결할 소위원회를 둘 수 있다.\n② 소위원회는 3명의 위원으로 구성한다.\n③ 소위원회가 제1항에 따라 심의ㆍ의결한 것은 보호위원회가 심의ㆍ의결한 것으로 본다.\n④ 소위원회의 회의는 구성위원 전원의 출석과 출석위원 전원의 찬성으로 의결한다.\n[본조신설 2020. 2. 4.]']
# gi : 18, g : [18]
# ['제7조의13(사무처) 보호위원회의 사무를 처리하기 위하여 보호위원회에 사무처를 두며, 이 법에 규정된 것 외에 보호위\n원회의 조직에 관한 사항은 대통령령으로 정한다.\n[본조신설 2020. 2. 4.]']
# gi : 19, g : [19]
# ['제7조의14(운영 등) 이 법과 다른 법령에 규정된 것 외에 보호위원회의 운영 등에 필요한 사항은 보호위원회의 규칙으\n로 정한다.\n[본조신설 2020. 2. 4.]\n \n제8조 삭제 <2020. 2. 4.>']
# gi : 20, g : [20]
# ['제8조의2(개인정보 침해요인 평가) ① 중앙행정기관의 장은 소관 법령의 제정 또는 개정을 통하여 개인정보 처리를 수\n반하는 정책이나 제도를 도입ㆍ변경하는 경우에는 보호위원회에 개인정보 침해요인 평가를 요청하여야 한다.\n② 보호위원회가 제1항에 따른 요청을 받은 때에는 해당 법령의 개인정보 침해요인을 분석ㆍ검토하여 그 법령의 소\n관기관의 장에게 그 개선을 위하여 필요한 사항을 권고할 수 있다.\n③ 제1항에 따른 개인정보 침해요인 평가의 절차와 방법에 관하여 필요한 사항은 대통령령으로 정한다.\n[본조신설 2015. 7. 24.]']
# gi : 21, g : [21]
# ['제9조(기본계획) ① 보호위원회는 개인정보의 보호와 정보주체의 권익 보장을 위하여 3년마다 개인정보 보호 기본계획\n(이하 “기본계획”이라 한다)을 관계 중앙행정기관의 장과 협의하여 수립한다. <개정 2013. 3. 23., 2014. 11. 19.,\n2015. 7. 24.>\n② 기본계획에는 다음 각 호의 사항이 포함되어야 한다.\n1. 개인정보 보호의 기본목표와 추진방향\n2. 개인정보 보호와 관련된 제도 및 법령의 개선\n3. 개인정보 침해 방지를 위한 대책\n4. 개인정보 보호 자율규제의 활성화\n5. 개인정보 보호 교육ㆍ홍보의 활성화\n6. 개인정보 보호를 위한 전문인력의 양성\n7. 그 밖에 개인정보 보호를 위하여 필요한 사항\n③ 국회, 법원, 헌법재판소, 중앙선거관리위원회는 해당 기관(그 소속 기관을 포함한다)의 개인정보 보호를 위한 기\n본계획을 수립ㆍ시행할 수 있다.']
# gi : 22, g : [22]
# ['제10조(시행계획) ① 중앙행정기관의 장은 기본계획에 따라 매년 개인정보 보호를 위한 시행계획을 작성하여 보호위원\n회에 제출하고, 보호위원회의 심의ㆍ의결을 거쳐 시행하여야 한다.\n② 시행계획의 수립ㆍ시행에 필요한 사항은 대통령령으로 정한다.']
# gi : 23, g : [23]
# ['제11조(자료제출 요구 등) ① 보호위원회는 기본계획을 효율적으로 수립하기 위하여 개인정보처리자, 관계 중앙행정기\n관의 장, 지방자치단체의 장 및 관계 기관ㆍ단체 등에 개인정보처리자의 법규 준수 현황과 개인정보 관리 실태 등에\n관한 자료의 제출이나 의견의 진술 등을 요구할 수 있다. <개정 2013. 3. 23., 2014. 11. 19., 2015. 7. 24.>\n② 보호위원회는 개인정보 보호 정책 추진, 성과평가 등을 위하여 필요한 경우 개인정보처리자, 관계 중앙행정기관\n의 장, 지방자치단체의 장 및 관계 기관ㆍ단체 등을 대상으로 개인정보관리 수준 및 실태파악 등을 위한 조사를 실\n시할 수 있다.<신설 2015. 7. 24., 2017. 7. 26., 2020. 2. 4.>\n③ 중앙행정기관의 장은 시행계획을 효율적으로 수립ㆍ추진하기 위하여 소관 분야의 개인정보처리자에게 제1항에\n따른 자료제출 등을 요구할 수 있다.<개정 2015. 7. 24.>\n④ 제1항부터 제3항까지에 따른 자료제출 등을 요구받은 자는 특별한 사정이 없으면 이에 따라야 한다.<개정 2015.\n7. 24.>\n⑤ 제1항부터 제3항까지에 따른 자료제출 등의 범위와 방법 등 필요한 사항은 대통령령으로 정한다.<개정 2015. 7.\n24.>']
# gi : 24, g : [24]
# ['제11조의2(개인정보 보호수준 평가) ① 보호위원회는 공공기관 중 중앙행정기관 및 그 소속기관, 지방자치단체, 그 밖\n에 대통령령으로 정하는 기관을 대상으로 매년 개인정보 보호 정책ㆍ업무의 수행 및 이 법에 따른 의무의 준수 여부\n등을 평가(이하 “개인정보 보호수준 평가”라 한다)하여야 한다.\n② 보호위원회는 개인정보 보호수준 평가에 필요한 경우 해당 공공기관의 장에게 관련 자료를 제출하게 할 수 있다.\n③ 보호위원회는 개인정보 보호수준 평가의 결과를 인터넷 홈페이지 등을 통하여 공개할 수 있다.\n④ 보호위원회는 개인정보 보호수준 평가의 결과에 따라 우수기관 및 그 소속 직원에 대하여 포상할 수 있고, 개인\n정보 보호를 위하여 필요하다고 인정하면 해당 공공기관의 장에게 개선을 권고할 수 있다. 이 경우 권고를 받은 공\n공기관의 장은 이를 이행하기 위하여 성실하게 노력하여야 하며, 그 조치 결과를 보호위원회에 알려야 한다.\n⑤ 그 밖에 개인정보 보호수준 평가의 기준ㆍ방법ㆍ절차 및 제2항에 따른 자료 제출의 범위 등에 필요한 사항은 대\n통령령으로 정한다.\n[본조신설 2023. 3. 14.]']
# gi : 25, g : [25]
# ['제12조(개인정보 보호지침) ① 보호위원회는 개인정보의 처리에 관한 기준, 개인정보 침해의 유형 및 예방조치 등에 관\n한 표준 개인정보 보호지침(이하 “표준지침”이라 한다)을 정하여 개인정보처리자에게 그 준수를 권장할 수 있다. <개\n정 2013. 3. 23., 2014. 11. 19., 2017. 7. 26., 2020. 2. 4.>\n② 중앙행정기관의 장은 표준지침에 따라 소관 분야의 개인정보 처리와 관련한 개인정보 보호지침을 정하여 개인\n정보처리자에게 그 준수를 권장할 수 있다.\n③ 국회, 법원, 헌법재판소 및 중앙선거관리위원회는 해당 기관(그 소속 기관을 포함한다)의 개인정보 보호지침을\n정하여 시행할 수 있다.']
# gi : 26, g : [26]
# ['제13조(자율규제의 촉진 및 지원) 보호위원회는 개인정보처리자의 자율적인 개인정보 보호활동을 촉진하고 지원하기\n위하여 다음 각 호의 필요한 시책을 마련하여야 한다. <개정 2013. 3. 23., 2014. 11. 19., 2017. 7. 26., 2020. 2. 4.>\n1. 개인정보 보호에 관한 교육ㆍ홍보\n2. 개인정보 보호와 관련된 기관ㆍ단체의 육성 및 지원\n3. 개인정보 보호 인증마크의 도입ㆍ시행 지원\n4. 개인정보처리자의 자율적인 규약의 제정ㆍ시행 지원\n5. 그 밖에 개인정보처리자의 자율적 개인정보 보호활동을 지원하기 위하여 필요한 사항']
# gi : 27, g : [27]
# ['제13조의2(개인정보 보호의 날) ① 개인정보의 보호 및 처리의 중요성을 국민에게 알리기 위하여 매년 9월 30일을 개\n인정보 보호의 날로 지정한다.\n② 국가와 지방자치단체는 개인정보 보호의 날이 포함된 주간에 개인정보 보호 문화 확산을 위한 각종 행사를 실시\n할 수 있다.\n[본조신설 2023. 3. 14.]']
# gi : 28, g : [28]
# ['제14조(국제협력) ① 정부는 국제적 환경에서의 개인정보 보호 수준을 향상시키기 위하여 필요한 시책을 마련하여야\n한다.\n② 정부는 개인정보 국외 이전으로 인하여 정보주체의 권리가 침해되지 아니하도록 관련 시책을 마련하여야 한다.']
# gi : 29, g : [29, np.int64(30), np.int64(31), np.int64(32), np.int64(33)]
# ['제15조(개인정보의 수집ㆍ이용) ① 개인정보처리자는 다음 각 호의 어느 하나에 해당하는 경우에는 개인정보를 수집할\n수 있으며 그 수집 목적의 범위에서 이용할 수 있다. <개정 2023. 3. 14.>\n1. 정보주체의 동의를 받은 경우\n2. 법률에 특별한 규정이 있거나 법령상 의무를 준수하기 위하여 불가피한 경우\n3. 공공기관이 법령 등에서 정하는 소관 업무의 수행을 위하여 불가피한 경우\n4. 정보주체와 체결한 계약을 이행하거나 계약을 체결하는 과정에서 정보주체의 요청에 따른 조치를 이행하기 위하\n여 필요한 경우\n5. 명백히 정보주체 또는 제3자의 급박한 생명, 신체, 재산의 이익을 위하여 필요하다고 인정되는 경우\n6. 개인정보처리자의 정당한 이익을 달성하기 위하여 필요한 경우로서 명백하게 정보주체의 권리보다 우선하는 경\n우. 이 경우 개인정보처리자의 정당한 이익과 상당한 관련이 있고 합리적인 범위를 초과하지 아니하는 경우에 한\n한다.\n7. 공중위생 등 공공의 안전과 안녕을 위하여 긴급히 필요한 경우\n② 개인정보처리자는 제1항제1호에 따른 동의를 받을 때에는 다음 각 호의 사항을 정보주체에게 알려야 한다. 다음\n각 호의 어느 하나의 사항을 변경하는 경우에도 이를 알리고 동의를 받아야 한다.\n1. 개인정보의 수집ㆍ이용 목적\n2. 수집하려는 개인정보의 항목\n3. 개인정보의 보유 및 이용 기간\n4. 동의를 거부할 권리가 있다는 사실 및 동의 거부에 따른 불이익이 있는 경우에는 그 불이익의 내용\n③ 개인정보처리자는 당초 수집 목적과 합리적으로 관련된 범위에서 정보주체에게 불이익이 발생하는지 여부, 암호\n화 등 안전성 확보에 필요한 조치를 하였는지 여부 등을 고려하여 대통령령으로 정하는 바에 따라 정보주체의 동의\n없이 개인정보를 이용할 수 있다.<신설 2020. 2. 4.>', '제16조(개인정보의 수집 제한) ① 개인정보처리자는 제15조제1항 각 호의 어느 하나에 해당하여 개인정보를 수집하는\n경우에는 그 목적에 필요한 최소한의 개인정보를 수집하여야 한다. 이 경우 최소한의 개인정보 수집이라는 입증책임\n은 개인정보처리자가 부담한다.\n② 개인정보처리자는 정보주체의 동의를 받아 개인정보를 수집하는 경우 필요한 최소한의 정보 외의 개인정보 수\n집에는 동의하지 아니할 수 있다는 사실을 구체적으로 알리고 개인정보를 수집하여야 한다.<신설 2013. 8. 6.>\n③ 개인정보처리자는 정보주체가 필요한 최소한의 정보 외의 개인정보 수집에 동의하지 아니한다는 이유로 정보주\n체에게 재화 또는 서비스의 제공을 거부하여서는 아니 된다.<개정 2013. 8. 6.>', '제17조(개인정보의 제공) ① 개인정보처리자는 다음 각 호의 어느 하나에 해당되는 경우에는 정보주체의 개인정보를\n제3자에게 제공(공유를 포함한다. 이하 같다)할 수 있다. <개정 2020. 2. 4., 2023. 3. 14.>\n1. 정보주체의 동의를 받은 경우\n2. 제15조제1항제2호, 제3호 및 제5호부터 제7호까지에 따라 개인정보를 수집한 목적 범위에서 개인정보를 제공하\n는 경우\n② 개인정보처리자는 제1항제1호에 따른 동의를 받을 때에는 다음 각 호의 사항을 정보주체에게 알려야 한다. 다음\n각 호의 어느 하나의 사항을 변경하는 경우에도 이를 알리고 동의를 받아야 한다.\n1. 개인정보를 제공받는 자\n2. 개인정보를 제공받는 자의 개인정보 이용 목적\n3. 제공하는 개인정보의 항목\n4. 개인정보를 제공받는 자의 개인정보 보유 및 이용 기간\n5. 동의를 거부할 권리가 있다는 사실 및 동의 거부에 따른 불이익이 있는 경우에는 그 불이익의 내용\n③ 삭제<2023. 3. 14.>\n④ 개인정보처리자는 당초 수집 목적과 합리적으로 관련된 범위에서 정보주체에게 불이익이 발생하는지 여부, 암호\n화 등 안전성 확보에 필요한 조치를 하였는지 여부 등을 고려하여 대통령령으로 정하는 바에 따라 정보주체의 동의\n없이 개인정보를 제공할 수 있다.<신설 2020. 2. 4.>', '제18조(개인정보의 목적 외 이용ㆍ제공 제한) ① 개인정보처리자는 개인정보를 제15조제1항에 따른 범위를 초과하여\n이용하거나 제17조제1항 및 제28조의8제1항에 따른 범위를 초과하여 제3자에게 제공하여서는 아니 된다. <개정\n2020. 2. 4., 2023. 3. 14.>\n② 제1항에도 불구하고 개인정보처리자는 다음 각 호의 어느 하나에 해당하는 경우에는 정보주체 또는 제3자의 이\n익을 부당하게 침해할 우려가 있을 때를 제외하고는 개인정보를 목적 외의 용도로 이용하거나 이를 제3자에게 제공\n할 수 있다. 다만, 제5호부터 제9호까지에 따른 경우는 공공기관의 경우로 한정한다.<개정 2020. 2. 4., 2023. 3. 14.>\n1. 정보주체로부터 별도의 동의를 받은 경우\n2. 다른 법률에 특별한 규정이 있는 경우\n3. 명백히 정보주체 또는 제3자의 급박한 생명, 신체, 재산의 이익을 위하여 필요하다고 인정되는 경우\n4. 삭제<2020. 2. 4.>\n5. 개인정보를 목적 외의 용도로 이용하거나 이를 제3자에게 제공하지 아니하면 다른 법률에서 정하는 소관 업무를\n수행할 수 없는 경우로서 보호위원회의 심의ㆍ의결을 거친 경우\n6. 조약, 그 밖의 국제협정의 이행을 위하여 외국정부 또는 국제기구에 제공하기 위하여 필요한 경우\n7. 범죄의 수사와 공소의 제기 및 유지를 위하여 필요한 경우\n8. 법원의 재판업무 수행을 위하여 필요한 경우\n9. 형(刑) 및 감호, 보호처분의 집행을 위하여 필요한 경우\n10. 공중위생 등 공공의 안전과 안녕을 위하여 긴급히 필요한 경우\n③ 개인정보처리자는 제2항제1호에 따른 동의를 받을 때에는 다음 각 호의 사항을 정보주체에게 알려야 한다. 다음\n각 호의 어느 하나의 사항을 변경하는 경우에도 이를 알리고 동의를 받아야 한다.\n1. 개인정보를 제공받는 자\n2. 개인정보의 이용 목적(제공 시에는 제공받는 자의 이용 목적을 말한다)\n3. 이용 또는 제공하는 개인정보의 항목\n4. 개인정보의 보유 및 이용 기간(제공 시에는 제공받는 자의 보유 및 이용 기간을 말한다)\n5. 동의를 거부할 권리가 있다는 사실 및 동의 거부에 따른 불이익이 있는 경우에는 그 불이익의 내용\n④ 공공기관은 제2항제2호부터 제6호까지, 제8호부터 제10호까지에 따라 개인정보를 목적 외의 용도로 이용하거나\n이를 제3자에게 제공하는 경우에는 그 이용 또는 제공의 법적 근거, 목적 및 범위 등에 관하여 필요한 사항을 보호\n위원회가 고시로 정하는 바에 따라 관보 또는 인터넷 홈페이지 등에 게재하여야 한다.<개정 2013. 3. 23., 2014. 11.\n19., 2017. 7. 26., 2020. 2. 4., 2023. 3. 14.>\n⑤ 개인정보처리자는 제2항 각 호의 어느 하나의 경우에 해당하여 개인정보를 목적 외의 용도로 제3자에게 제공하\n는 경우에는 개인정보를 제공받는 자에게 이용 목적, 이용 방법, 그 밖에 필요한 사항에 대하여 제한을 하거나, 개인\n정보의 안전성 확보를 위하여 필요한 조치를 마련하도록 요청하여야 한다. 이 경우 요청을 받은 자는 개인정보의 안\n전성 확보를 위하여 필요한 조치를 하여야 한다.\n[제목개정 2013. 8. 6.]', '제19조(개인정보를 제공받은 자의 이용ㆍ제공 제한) 개인정보처리자로부터 개인정보를 제공받은 자는 다음 각 호의 어\n느 하나에 해당하는 경우를 제외하고는 개인정보를 제공받은 목적 외의 용도로 이용하거나 이를 제3자에게 제공하\n여서는 아니 된다.\n1. 정보주체로부터 별도의 동의를 받은 경우\n2. 다른 법률에 특별한 규정이 있는 경우']
# gi : 30, g : [34]
# ['제20조(정보주체 이외로부터 수집한 개인정보의 수집 출처 등 통지) ① 개인정보처리자가 정보주체 이외로부터 수집한\n개인정보를 처리하는 때에는 정보주체의 요구가 있으면 즉시 다음 각 호의 모든 사항을 정보주체에게 알려야 한다.\n<개정 2023. 3. 14.>\n1. 개인정보의 수집 출처\n2. 개인정보의 처리 목적\n3. 제37조에 따른 개인정보 처리의 정지를 요구하거나 동의를 철회할 권리가 있다는 사실\n② 제1항에도 불구하고 처리하는 개인정보의 종류ㆍ규모, 종업원 수 및 매출액 규모 등을 고려하여 대통령령으로\n정하는 기준에 해당하는 개인정보처리자가 제17조제1항제1호에 따라 정보주체 이외로부터 개인정보를 수집하여\n처리하는 때에는 제1항 각 호의 모든 사항을 정보주체에게 알려야 한다. 다만, 개인정보처리자가 수집한 정보에 연\n락처 등 정보주체에게 알릴 수 있는 개인정보가 포함되지 아니한 경우에는 그러하지 아니하다.<신설 2016. 3. 29.>\n③ 제2항 본문에 따라 알리는 경우 정보주체에게 알리는 시기ㆍ방법 및 절차 등 필요한 사항은 대통령령으로 정한\n다.<신설 2016. 3. 29.>\n④ 제1항과 제2항 본문은 다음 각 호의 어느 하나에 해당하는 경우에는 적용하지 아니한다. 다만, 이 법에 따른 정\n보주체의 권리보다 명백히 우선하는 경우에 한한다.<개정 2016. 3. 29., 2023. 3. 14.>\n1. 통지를 요구하는 대상이 되는 개인정보가 제32조제2항 각 호의 어느 하나에 해당하는 개인정보파일에 포함되어\n있는 경우\n2. 통지로 인하여 다른 사람의 생명ㆍ신체를 해할 우려가 있거나 다른 사람의 재산과 그 밖의 이익을 부당하게 침해\n할 우려가 있는 경우\n[제목개정 2023. 3. 14.]']
# gi : 31, g : [35]
# ['제20조의2(개인정보 이용ㆍ제공 내역의 통지) ① 대통령령으로 정하는 기준에 해당하는 개인정보처리자는 이 법에 따\n라 수집한 개인정보의 이용ㆍ제공 내역이나 이용ㆍ제공 내역을 확인할 수 있는 정보시스템에 접속하는 방법을 주기\n적으로 정보주체에게 통지하여야 한다. 다만, 연락처 등 정보주체에게 통지할 수 있는 개인정보를 수집ㆍ보유하지\n아니한 경우에는 통지하지 아니할 수 있다.\n② 제1항에 따른 통지의 대상이 되는 정보주체의 범위, 통지 대상 정보, 통지 주기 및 방법 등에 필요한 사항은 대통\n령령으로 정한다.\n[본조신설 2023. 3. 14.]']
# gi : 32, g : [36]
# ['제21조(개인정보의 파기) ① 개인정보처리자는 보유기간의 경과, 개인정보의 처리 목적 달성, 가명정보의 처리 기간 경\n과 등 그 개인정보가 불필요하게 되었을 때에는 지체 없이 그 개인정보를 파기하여야 한다. 다만, 다른 법령에 따라\n보존하여야 하는 경우에는 그러하지 아니하다. <개정 2023. 3. 14.>\n② 개인정보처리자가 제1항에 따라 개인정보를 파기할 때에는 복구 또는 재생되지 아니하도록 조치하여야 한다.\n③ 개인정보처리자가 제1항 단서에 따라 개인정보를 파기하지 아니하고 보존하여야 하는 경우에는 해당 개인정보\n또는 개인정보파일을 다른 개인정보와 분리하여서 저장ㆍ관리하여야 한다.\n④ 개인정보의 파기방법 및 절차 등에 필요한 사항은 대통령령으로 정한다.']
# gi : 33, g : [37]
# ['제22조(동의를 받는 방법) ① 개인정보처리자는 이 법에 따른 개인정보의 처리에 대하여 정보주체(제22조의2제1항에\n따른 법정대리인을 포함한다. 이하 이 조에서 같다)의 동의를 받을 때에는 각각의 동의 사항을 구분하여 정보주체가\n이를 명확하게 인지할 수 있도록 알리고 동의를 받아야 한다. 이 경우 다음 각 호의 경우에는 동의 사항을 구분하여\n각각 동의를 받아야 한다. <개정 2017. 4. 18., 2023. 3. 14.>\n1. 제15조제1항제1호에 따라 동의를 받는 경우\n2. 제17조제1항제1호에 따라 동의를 받는 경우\n3. 제18조제2항제1호에 따라 동의를 받는 경우\n4. 제19조제1호에 따라 동의를 받는 경우\n5. 제23조제1항제1호에 따라 동의를 받는 경우\n6. 제24조제1항제1호에 따라 동의를 받는 경우\n7. 재화나 서비스를 홍보하거나 판매를 권유하기 위하여 개인정보의 처리에 대한 동의를 받으려는 경우\n8. 그 밖에 정보주체를 보호하기 위하여 동의 사항을 구분하여 동의를 받아야 할 필요가 있는 경우로서 대통령령으\n로 정하는 경우\n② 개인정보처리자는 제1항의 동의를 서면(「전자문서 및 전자거래 기본법」 제2조제1호에 따른 전자문서를 포함한\n다)으로 받을 때에는 개인정보의 수집ㆍ이용 목적, 수집ㆍ이용하려는 개인정보의 항목 등 대통령령으로 정하는 중\n요한 내용을 보호위원회가 고시로 정하는 방법에 따라 명확히 표시하여 알아보기 쉽게 하여야 한다.<신설 2017. 4.\n18., 2017. 7. 26., 2020. 2. 4.>\n③ 개인정보처리자는 정보주체의 동의 없이 처리할 수 있는 개인정보에 대해서는 그 항목과 처리의 법적 근거를 정\n보주체의 동의를 받아 처리하는 개인정보와 구분하여 제30조제2항에 따라 공개하거나 전자우편 등 대통령령으로\n정하는 방법에 따라 정보주체에게 알려야 한다. 이 경우 동의 없이 처리할 수 있는 개인정보라는 입증책임은 개인정\n보처리자가 부담한다.<개정 2016. 3. 29., 2017. 4. 18., 2023. 3. 14.>\n④ 삭제<2023. 3. 14.>\n⑤ 개인정보처리자는 정보주체가 선택적으로 동의할 수 있는 사항을 동의하지 아니하거나 제1항제3호 및 제7호에\n따른 동의를 하지 아니한다는 이유로 정보주체에게 재화 또는 서비스의 제공을 거부하여서는 아니 된다.<개정\n2017. 4. 18., 2023. 3. 14.>\n⑥ 삭제<2023. 3. 14.>\n⑦ 제1항부터 제5항까지에서 규정한 사항 외에 정보주체의 동의를 받는 세부적인 방법에 관하여 필요한 사항은 개\n인정보의 수집매체 등을 고려하여 대통령령으로 정한다.<개정 2017. 4. 18., 2023. 3. 14.>']
# gi : 34, g : [38]
# ['제22조의2(아동의 개인정보 보호) ① 개인정보처리자는 만 14세 미만 아동의 개인정보를 처리하기 위하여 이 법에 따\n른 동의를 받아야 할 때에는 그 법정대리인의 동의를 받아야 하며, 법정대리인이 동의하였는지를 확인하여야 한다.\n② 제1항에도 불구하고 법정대리인의 동의를 받기 위하여 필요한 최소한의 정보로서 대통령령으로 정하는 정보는\n법정대리인의 동의 없이 해당 아동으로부터 직접 수집할 수 있다.\n③ 개인정보처리자는 만 14세 미만의 아동에게 개인정보 처리와 관련한 사항의 고지 등을 할 때에는 이해하기 쉬운\n양식과 명확하고 알기 쉬운 언어를 사용하여야 한다.\n④ 제1항부터 제3항까지에서 규정한 사항 외에 동의 및 동의 확인 방법 등에 필요한 사항은 대통령령으로 정한다.\n[본조신설 2023. 3. 14.]\n \n         제2절 개인정보의 처리 제한']
# gi : 35, g : [39]
# ['제23조(민감정보의 처리 제한) ①개인정보처리자는 사상ㆍ신념, 노동조합ㆍ정당의 가입ㆍ탈퇴, 정치적 견해, 건강, 성생\n활 등에 관한 정보, 그 밖에 정보주체의 사생활을 현저히 침해할 우려가 있는 개인정보로서 대통령령으로 정하는 정\n보(이하 “민감정보”라 한다)를 처리하여서는 아니 된다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는  그러하\n지 아니하다. <개정 2016. 3. 29.>\n1. 정보주체에게 제15조제2항 각 호 또는 제17조제2항 각 호의 사항을 알리고 다른 개인정보의 처리에 대한 동의와\n별도로 동의를 받은 경우\n2. 법령에서 민감정보의 처리를 요구하거나 허용하는 경우\n② 개인정보처리자가 제1항 각 호에 따라 민감정보를 처리하는 경우에는 그 민감정보가 분실ㆍ도난ㆍ유출ㆍ위조ㆍ\n변조 또는 훼손되지 아니하도록 제29조에 따른 안전성 확보에 필요한 조치를 하여야 한다.<신설 2016. 3. 29.>\n③ 개인정보처리자는 재화 또는 서비스를 제공하는 과정에서 공개되는 정보에 정보주체의 민감정보가 포함됨으로\n써 사생활 침해의 위험성이 있다고 판단하는 때에는 재화 또는 서비스의 제공 전에 민감정보의 공개 가능성 및 비\n공개를 선택하는 방법을 정보주체가 알아보기 쉽게 알려야 한다.<신설 2023. 3. 14.>']
# gi : 36, g : [40]
# ['제24조(고유식별정보의 처리 제한) ① 개인정보처리자는 다음 각 호의 경우를 제외하고는 법령에 따라 개인을 고유하\n게 구별하기 위하여 부여된 식별정보로서 대통령령으로 정하는 정보(이하 “고유식별정보”라 한다)를 처리할 수 없다.\n1. 정보주체에게 제15조제2항 각 호 또는 제17조제2항 각 호의 사항을 알리고 다른 개인정보의 처리에 대한 동의와\n별도로 동의를 받은 경우\n2. 법령에서 구체적으로 고유식별정보의 처리를 요구하거나 허용하는 경우\n② 삭제<2013. 8. 6.>\n③ 개인정보처리자가 제1항 각 호에 따라 고유식별정보를 처리하는 경우에는 그 고유식별정보가 분실ㆍ도난ㆍ유출\nㆍ위조ㆍ변조 또는 훼손되지 아니하도록 대통령령으로 정하는 바에 따라 암호화 등 안전성 확보에 필요한 조치를\n하여야 한다.<개정 2015. 7. 24.>\n④ 보호위원회는 처리하는 개인정보의 종류ㆍ규모, 종업원 수 및 매출액 규모 등을 고려하여 대통령령으로 정하는\n기준에 해당하는 개인정보처리자가 제3항에 따라 안전성 확보에 필요한 조치를 하였는지에 관하여 대통령령으로\n정하는 바에 따라 정기적으로 조사하여야 한다.<신설 2016. 3. 29., 2017. 7. 26., 2020. 2. 4.>\n⑤ 보호위원회는 대통령령으로 정하는 전문기관으로 하여금 제4항에 따른 조사를 수행하게 할 수 있다.<신설 2016.\n3. 29., 2017. 7. 26., 2020. 2. 4.>']
# gi : 37, g : [41]
# ['제24조의2(주민등록번호 처리의 제한) ① 제24조제1항에도 불구하고 개인정보처리자는 다음 각 호의 어느 하나에 해\n당하는 경우를 제외하고는 주민등록번호를 처리할 수 없다. <개정 2014. 11. 19., 2016. 3. 29., 2017. 7. 26., 2020. 2.\n4.>\n1. 법률ㆍ대통령령ㆍ국회규칙ㆍ대법원규칙ㆍ헌법재판소규칙ㆍ중앙선거관리위원회규칙 및 감사원규칙에서 구체적\n으로 주민등록번호의 처리를 요구하거나 허용한 경우\n2. 정보주체 또는 제3자의 급박한 생명, 신체, 재산의 이익을 위하여 명백히 필요하다고 인정되는 경우\n3. 제1호 및 제2호에 준하여 주민등록번호 처리가 불가피한 경우로서 보호위원회가 고시로 정하는 경우\n② 개인정보처리자는 제24조제3항에도 불구하고 주민등록번호가 분실ㆍ도난ㆍ유출ㆍ위조ㆍ변조 또는 훼손되지 아\n니하도록 암호화 조치를 통하여 안전하게 보관하여야 한다. 이 경우 암호화 적용 대상 및 대상별 적용 시기 등에 관\n하여 필요한 사항은 개인정보의 처리 규모와 유출 시 영향 등을 고려하여 대통령령으로 정한다.<신설 2014. 3. 24.,\n2015. 7. 24.>\n③ 개인정보처리자는 제1항 각 호에 따라 주민등록번호를 처리하는 경우에도 정보주체가 인터넷 홈페이지를 통하\n여 회원으로 가입하는 단계에서는 주민등록번호를 사용하지 아니하고도 회원으로 가입할 수 있는 방법을 제공하여\n야 한다.<개정 2014. 3. 24.>\n④ 보호위원회는 개인정보처리자가 제3항에 따른 방법을 제공할 수 있도록 관계 법령의 정비, 계획의 수립, 필요한\n시설 및 시스템의 구축 등 제반 조치를 마련ㆍ지원할 수 있다.<개정 2014. 3. 24., 2017. 7. 26., 2020. 2. 4.>\n[본조신설 2013. 8. 6.]']
# gi : 38, g : [42]
# ['제25조(고정형 영상정보처리기기의 설치ㆍ운영 제한) ① 누구든지 다음 각 호의 경우를 제외하고는 공개된 장소에 고\n정형 영상정보처리기기를 설치ㆍ운영하여서는 아니 된다. <개정 2023. 3. 14.>\n1. 법령에서 구체적으로 허용하고 있는 경우\n2. 범죄의 예방 및 수사를 위하여 필요한 경우\n3. 시설의 안전 및 관리, 화재 예방을 위하여 정당한 권한을 가진 자가 설치ㆍ운영하는 경우\n4. 교통단속을 위하여 정당한 권한을 가진 자가 설치ㆍ운영하는 경우\n5. 교통정보의 수집ㆍ분석 및 제공을 위하여 정당한 권한을 가진 자가 설치ㆍ운영하는 경우\n6. 촬영된 영상정보를 저장하지 아니하는 경우로서 대통령령으로 정하는 경우\n② 누구든지 불특정 다수가 이용하는 목욕실, 화장실, 발한실(發汗室), 탈의실 등 개인의 사생활을 현저히 침해할 우\n려가 있는 장소의 내부를 볼 수 있도록 고정형 영상정보처리기기를 설치ㆍ운영하여서는 아니 된다. 다만, 교도소,\n정신보건 시설 등 법령에 근거하여 사람을 구금하거나 보호하는 시설로서 대통령령으로 정하는 시설에 대하여는\n그러하지 아니하다.<개정 2023. 3. 14.>\n③ 제1항 각 호에 따라 고정형 영상정보처리기기를 설치ㆍ운영하려는 공공기관의 장과 제2항 단서에 따라 고정형\n영상정보처리기기를 설치ㆍ운영하려는 자는 공청회ㆍ설명회의 개최 등 대통령령으로 정하는 절차를 거쳐 관계 전\n문가 및 이해관계인의 의견을 수렴하여야 한다.<개정 2023. 3. 14.>\n④ 제1항 각 호에 따라 고정형 영상정보처리기기를 설치ㆍ운영하는 자(이하 “고정형영상정보처리기기운영자”라 한\n다)는 정보주체가 쉽게 인식할 수 있도록 다음 각 호의 사항이 포함된 안내판을 설치하는 등 필요한 조치를 하여야\n한다. 다만, 「군사기지 및 군사시설 보호법」 제2조제2호에 따른 군사시설, 「통합방위법」 제2조제13호에 따른 국가\n중요시설, 그 밖에 대통령령으로 정하는 시설의 경우에는 그러하지 아니하다.<개정 2016. 3. 29., 2023. 3. 14.>\n1. 설치 목적 및 장소\n2. 촬영 범위 및 시간\n3. 관리책임자의 연락처\n4. 그 밖에 대통령령으로 정하는 사항\n⑤ 고정형영상정보처리기기운영자는 고정형 영상정보처리기기의 설치 목적과 다른 목적으로 고정형 영상정보처리\n기기를 임의로 조작하거나 다른 곳을 비춰서는 아니 되며, 녹음기능은 사용할 수 없다.<개정 2023. 3. 14.>\n⑥ 고정형영상정보처리기기운영자는 개인정보가 분실ㆍ도난ㆍ유출ㆍ위조ㆍ변조 또는 훼손되지 아니하도록 제\n29조에 따라 안전성 확보에 필요한 조치를 하여야 한다.<개정 2015. 7. 24., 2023. 3. 14.>\n⑦ 고정형영상정보처리기기운영자는 대통령령으로 정하는 바에 따라 고정형 영상정보처리기기 운영ㆍ관리 방침을\n마련하여야 한다. 다만, 제30조에 따른 개인정보 처리방침을 정할 때 고정형 영상정보처리기기 운영ㆍ관리에 관한\n사항을 포함시킨 경우에는 고정형 영상정보처리기기 운영ㆍ관리 방침을 마련하지 아니할 수 있다.<개정 2023. 3.\n14.>\n⑧ 고정형영상정보처리기기운영자는 고정형 영상정보처리기기의 설치ㆍ운영에 관한 사무를 위탁할 수 있다. 다만,\n공공기관이 고정형 영상정보처리기기 설치ㆍ운영에 관한 사무를 위탁하는 경우에는 대통령령으로 정하는 절차 및\n요건에 따라야 한다.<개정 2023. 3. 14.>\n[제목개정 2023. 3. 14.]']
# gi : 39, g : [43]
# ['제25조의2(이동형 영상정보처리기기의 운영 제한) ① 업무를 목적으로 이동형 영상정보처리기기를 운영하려는 자는\n다음 각 호의 경우를 제외하고는 공개된 장소에서 이동형 영상정보처리기기로 사람 또는 그 사람과 관련된 사물의\n영상(개인정보에 해당하는 경우로 한정한다. 이하 같다)을 촬영하여서는 아니 된다.\n1. 제15조제1항 각 호의 어느 하나에 해당하는 경우\n2. 촬영 사실을 명확히 표시하여 정보주체가 촬영 사실을 알 수 있도록 하였음에도 불구하고 촬영 거부 의사를 밝히\n지 아니한 경우. 이 경우 정보주체의 권리를 부당하게 침해할 우려가 없고 합리적인 범위를 초과하지 아니하는 경\n우로 한정한다.\n3. 그 밖에 제1호 및 제2호에 준하는 경우로서 대통령령으로 정하는 경우\n② 누구든지 불특정 다수가 이용하는 목욕실, 화장실, 발한실, 탈의실 등 개인의 사생활을 현저히 침해할 우려가 있\n는 장소의 내부를 볼 수 있는 곳에서 이동형 영상정보처리기기로 사람 또는 그 사람과 관련된 사물의 영상을 촬영\n하여서는 아니 된다. 다만, 인명의 구조ㆍ구급 등을 위하여 필요한 경우로서 대통령령으로 정하는 경우에는 그러하\n지 아니하다.\n③ 제1항 각 호에 해당하여 이동형 영상정보처리기기로 사람 또는 그 사람과 관련된 사물의 영상을 촬영하는 경우\n에는 불빛, 소리, 안내판 등 대통령령으로 정하는 바에 따라 촬영 사실을 표시하고 알려야 한다.\n④ 제1항부터 제3항까지에서 규정한 사항 외에 이동형 영상정보처리기기의 운영에 관하여는 제25조제6항부터 제\n8항까지의 규정을 준용한다.\n[본조신설 2023. 3. 14.]']
# gi : 40, g : [44]
# ['제26조(업무위탁에 따른 개인정보의 처리 제한) ① 개인정보처리자가 제3자에게 개인정보의 처리 업무를 위탁하는 경\n우에는 다음 각 호의 내용이 포함된 문서로 하여야 한다. <개정 2023. 3. 14.>\n1. 위탁업무 수행 목적 외 개인정보의 처리 금지에 관한 사항\n2. 개인정보의 기술적ㆍ관리적 보호조치에 관한 사항\n3. 그 밖에 개인정보의 안전한 관리를 위하여 대통령령으로 정한 사항\n② 제1항에 따라 개인정보의 처리 업무를 위탁하는 개인정보처리자(이하 “위탁자”라 한다)는 위탁하는 업무의 내용\n과 개인정보 처리 업무를 위탁받아 처리하는 자(개인정보 처리 업무를 위탁받아 처리하는 자로부터 위탁받은 업무\n를 다시 위탁받은 제3자를 포함하며, 이하 “수탁자”라 한다)를 정보주체가 언제든지 쉽게 확인할 수 있도록 대통령\n령으로 정하는 방법에 따라  공개하여야 한다.<개정 2023. 3. 14.>\n③ 위탁자가 재화 또는 서비스를 홍보하거나 판매를 권유하는 업무를 위탁하는 경우에는 대통령령으로 정하는 방\n법에 따라 위탁하는 업무의 내용과 수탁자를 정보주체에게 알려야 한다. 위탁하는 업무의 내용이나 수탁자가 변경\n된 경우에도 또한 같다.\n④ 위탁자는 업무 위탁으로 인하여 정보주체의 개인정보가 분실ㆍ도난ㆍ유출ㆍ위조ㆍ변조 또는 훼손되지 아니하\n도록 수탁자를 교육하고, 처리 현황 점검 등 대통령령으로 정하는 바에 따라 수탁자가 개인정보를 안전하게 처리하\n는지를 감독하여야 한다.<개정 2015. 7. 24.>\n⑤ 수탁자는 개인정보처리자로부터 위탁받은 해당 업무 범위를 초과하여 개인정보를 이용하거나 제3자에게 제공하\n여서는 아니 된다.\n⑥ 수탁자는 위탁받은 개인정보의 처리 업무를 제3자에게 다시 위탁하려는 경우에는 위탁자의 동의를 받아야 한다.\n<신설 2023. 3. 14.>\n⑦ 수탁자가 위탁받은 업무와 관련하여 개인정보를 처리하는 과정에서 이 법을 위반하여 발생한 손해배상책임에\n대하여는 수탁자를 개인정보처리자의 소속 직원으로 본다.<개정 2023. 3. 14.>\n⑧ 수탁자에 관하여는 제15조부터 제18조까지, 제21조, 제22조, 제22조의2, 제23조, 제24조, 제24조의2, 제25조, 제\n25조의2, 제27조, 제28조, 제28조의2부터 제28조의5까지, 제28조의7부터 제28조의11까지, 제29조, 제30조, 제30조\n의2, 제31조, 제33조, 제34조, 제34조의2, 제35조, 제35조의2, 제36조, 제37조, 제37조의2, 제38조, 제59조, 제63조,\n제63조의2 및 제64조의2를 준용한다. 이 경우 “개인정보처리자”는 “수탁자”로 본다.<개정 2023. 3. 14.>']
# gi : 41, g : [45]
# ['제27조(영업양도 등에 따른 개인정보의 이전 제한) ① 개인정보처리자는 영업의 전부 또는 일부의 양도ㆍ합병 등으로\n개인정보를 다른 사람에게 이전하는 경우에는 미리 다음 각 호의 사항을 대통령령으로 정하는 방법에 따라 해당 정\n보주체에게 알려야 한다.\n1. 개인정보를 이전하려는 사실\n2. 개인정보를 이전받는 자(이하 “영업양수자등”이라 한다)의 성명(법인의 경우에는 법인의 명칭을 말한다), 주소, 전\n화번호 및 그 밖의 연락처\n3. 정보주체가 개인정보의 이전을 원하지 아니하는 경우 조치할 수 있는 방법 및 절차\n② 영업양수자등은 개인정보를 이전받았을 때에는 지체 없이 그 사실을 대통령령으로 정하는 방법에 따라 정보주\n체에게 알려야 한다. 다만, 개인정보처리자가 제1항에 따라 그 이전 사실을 이미 알린 경우에는 그러하지 아니하다.\n③ 영업양수자등은 영업의 양도ㆍ합병 등으로 개인정보를 이전받은 경우에는 이전 당시의 본래 목적으로만 개인정\n보를 이용하거나 제3자에게 제공할 수 있다. 이 경우 영업양수자등은 개인정보처리자로 본다.']
# gi : 42, g : [46]
# ['제28조(개인정보취급자에 대한 감독) ① 개인정보처리자는 개인정보를 처리함에 있어서 개인정보가 안전하게 관리될\n수 있도록 임직원, 파견근로자, 시간제근로자 등 개인정보처리자의 지휘ㆍ감독을 받아 개인정보를 처리하는 자(이하\n“개인정보취급자”라 한다)의 범위를 최소한으로 제한하고, 개인정보취급자에 대하여 적절한 관리ㆍ감독을 하여야 한\n다. <개정 2023. 3. 14.>\n② 개인정보처리자는 개인정보의 적정한 취급을 보장하기 위하여 개인정보취급자에게 정기적으로 필요한 교육을\n실시하여야 한다.\n \n         제3절 가명정보의 처리에 관한 특례 <신설 2020. 2. 4.>']
# gi : 43, g : [47, 49, np.int64(50)]
# ['제28조의2(가명정보의 처리 등) ① 개인정보처리자는 통계작성, 과학적 연구, 공익적 기록보존 등을 위하여 정보주체의\n동의 없이 가명정보를 처리할 수 있다.\n② 개인정보처리자는 제1항에 따라 가명정보를 제3자에게 제공하는 경우에는 특정 개인을 알아보기 위하여 사용될\n수 있는 정보를 포함해서는 아니 된다.\n[본조신설 2020. 2. 4.]', '제28조의4(가명정보에 대한 안전조치의무 등) ① 개인정보처리자는 제28조의2 또는 제28조의3에 따라 가명정보를 처\n리하는 경우에는 원래의 상태로 복원하기 위한 추가 정보를 별도로 분리하여 보관ㆍ관리하는 등 해당 정보가 분실\nㆍ도난ㆍ유출ㆍ위조ㆍ변조 또는 훼손되지 않도록 대통령령으로 정하는 바에 따라 안전성 확보에 필요한 기술적ㆍ관\n리적 및 물리적 조치를 하여야 한다. <개정 2023. 3. 14.>\n② 개인정보처리자는 제28조의2 또는 제28조의3에 따라 가명정보를 처리하는 경우 처리목적 등을 고려하여 가명\n정보의 처리 기간을 별도로 정할 수 있다.<신설 2023. 3. 14.>\n③ 개인정보처리자는 제28조의2 또는 제28조의3에 따라 가명정보를 처리하고자 하는 경우에는 가명정보의 처리\n목적, 제3자 제공 시 제공받는 자, 가명정보의 처리 기간(제2항에 따라 처리 기간을 별도로 정한 경우에 한한다) 등\n가명정보의 처리 내용을 관리하기 위하여 대통령령으로 정하는 사항에 대한 관련 기록을 작성하여 보관하여야 하\n며, 가명정보를 파기한 경우에는 파기한 날부터 3년 이상 보관하여야 한다.<개정 2023. 3. 14.>\n[본조신설 2020. 2. 4.]', '제28조의5(가명정보 처리 시 금지의무 등) ① 제28조의2 또는 제28조의3에 따라 가명정보를 처리하는 자는 특정 개인\n을 알아보기 위한 목적으로 가명정보를 처리해서는 아니 된다. <개정 2023. 3. 14.>\n② 개인정보처리자는 제28조의2 또는 제28조의3에 따라 가명정보를 처리하는 과정에서 특정 개인을 알아볼 수 있\n는 정보가 생성된 경우에는 즉시 해당 정보의 처리를 중지하고, 지체 없이 회수ㆍ파기하여야 한다.<개정 2023. 3.\n14.>\n[본조신설 2020. 2. 4.]\n \n제28조의6 삭제 <2023. 3. 14.>']
# gi : 44, g : [48]
# ['제28조의3(가명정보의 결합 제한) ① 제28조의2에도 불구하고 통계작성, 과학적 연구, 공익적 기록보존 등을 위한 서로\n다른 개인정보처리자 간의 가명정보의 결합은 보호위원회 또는 관계 중앙행정기관의 장이 지정하는 전문기관이 수\n행한다.\n② 결합을 수행한 기관 외부로 결합된 정보를 반출하려는 개인정보처리자는 가명정보 또는 제58조의2에 해당하는\n정보로 처리한 뒤 전문기관의 장의 승인을 받아야 한다.\n③ 제1항에 따른 결합 절차와 방법, 전문기관의 지정과 지정 취소 기준ㆍ절차, 관리ㆍ감독, 제2항에 따른 반출 및 승\n인 기준ㆍ절차 등 필요한 사항은 대통령령으로 정한다.\n[본조신설 2020. 2. 4.]']
# gi : 45, g : [51]
# ['제28조의7(적용범위) 제28조의2 또는 제28조의3에 따라 처리된 가명정보는 제20조, 제20조의2, 제27조, 제34조제1항,\n제35조, 제35조의2, 제36조 및 제37조를 적용하지 아니한다. <개정 2023. 3. 14.>\n[본조신설 2020. 2. 4.]\n제4절 개인정보의 국외 이전 <신설 2023. 3. 14.>']
# gi : 46, g : [52]
# ['제28조의8(개인정보의 국외 이전) ① 개인정보처리자는 개인정보를 국외로 제공(조회되는 경우를 포함한다)ㆍ처리위탁\nㆍ보관(이하 이 절에서 “이전”이라 한다)하여서는 아니 된다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 개\n인정보를 국외로 이전할 수 있다.\n1. 정보주체로부터 국외 이전에 관한 별도의 동의를 받은 경우\n2. 법률, 대한민국을 당사자로 하는 조약 또는 그 밖의 국제협정에 개인정보의 국외 이전에 관한 특별한 규정이 있\n는 경우\n3. 정보주체와의 계약의 체결 및 이행을 위하여 개인정보의 처리위탁ㆍ보관이 필요한 경우로서 다음 각 목의 어느\n하나에 해당하는 경우\n가. 제2항 각 호의 사항을 제30조에 따른 개인정보 처리방침에 공개한 경우\n나. 전자우편 등 대통령령으로 정하는 방법에 따라 제2항 각 호의 사항을 정보주체에게 알린 경우\n4. 개인정보를 이전받는 자가 제32조의2에 따른 개인정보 보호 인증 등 보호위원회가 정하여 고시하는 인증을 받은\n경우로서 다음 각 목의 조치를 모두 한 경우\n가. 개인정보 보호에 필요한 안전조치 및 정보주체 권리보장에 필요한 조치\n나. 인증받은 사항을 개인정보가 이전되는 국가에서 이행하기 위하여 필요한 조치\n5. 개인정보가 이전되는 국가 또는 국제기구의 개인정보 보호체계, 정보주체 권리보장 범위, 피해구제 절차 등이 이\n법에 따른 개인정보 보호 수준과 실질적으로 동등한 수준을 갖추었다고 보호위원회가 인정하는 경우\n② 개인정보처리자는 제1항제1호에 따른 동의를 받을 때에는 미리 다음 각 호의 사항을 정보주체에게 알려야 한다.\n1. 이전되는 개인정보 항목\n2. 개인정보가 이전되는 국가, 시기 및 방법\n3. 개인정보를 이전받는 자의 성명(법인인 경우에는 그 명칭과 연락처를 말한다)\n4. 개인정보를 이전받는 자의 개인정보 이용목적 및 보유ㆍ이용 기간\n5. 개인정보의 이전을 거부하는 방법, 절차 및 거부의 효과\n③ 개인정보처리자는 제2항 각 호의 어느 하나에 해당하는 사항을 변경하는 경우에는 정보주체에게 알리고 동의를\n받아야 한다.\n④ 개인정보처리자는 제1항 각 호 외의 부분 단서에 따라 개인정보를 국외로 이전하는 경우 국외 이전과 관련한 이\n법의 다른 규정, 제17조부터 제19조까지의 규정 및']
# gi : 47, g : [53]
# ['제29조(안전조치의무) 개인정보처리자는 개인정보가 분실ㆍ도난ㆍ유출ㆍ위조ㆍ변조 또는 훼손되지 아니하도록 내부\n관리계획 수립, 접속기록 보관 등 대통령령으로 정하는 바에 따라 안전성 확보에 필요한 기술적ㆍ관리적 및 물리적\n조치를 하여야 한다. <개정 2015. 7. 24.>']
# gi : 48, g : [54]
# ['제30조(개인정보 처리방침의 수립 및 공개) ① 개인정보처리자는 다음 각 호의 사항이 포함된 개인정보의 처리 방침(이\n하 “개인정보 처리방침”이라 한다)을 정하여야 한다. 이 경우 공공기관은 제32조에 따라 등록대상이 되는 개인정보\n파일에 대하여 개인정보 처리방침을 정한다. <개정 2016. 3. 29., 2020. 2. 4., 2023. 3. 14.>\n1. 개인정보의 처리 목적\n2. 개인정보의 처리 및 보유 기간\n3. 개인정보의 제3자 제공에 관한 사항(해당되는 경우에만 정한다)\n3의2. 개인정보의 파기절차 및 파기방법(제21조제1항 단서에 따라 개인정보를 보존하여야 하는 경우에는 그 보존근\n거와 보존하는 개인정보 항목을 포함한다)\n3의3. 제23조제3항에 따른 민감정보의 공개 가능성 및 비공개를 선택하는 방법(해당되는 경우에만 정한다)\n4. 개인정보처리의 위탁에 관한 사항(해당되는 경우에만 정한다)\n4의2. 제28조의2 및 제28조의3에 따른 가명정보의 처리 등에 관한 사항(해당되는 경우에만 정한다)\n5. 정보주체와 법정대리인의 권리ㆍ의무 및 그 행사방법에 관한 사항\n6. 제31조에 따른 개인정보 보호책임자의 성명 또는 개인정보 보호업무 및 관련 고충사항을 처리하는 부서의 명칭\n과 전화번호 등 연락처\n7. 인터넷 접속정보파일 등 개인정보를 자동으로 수집하는 장치의 설치ㆍ운영 및 그 거부에 관한 사항(해당하는 경\n우에만 정한다)\n8. 그 밖에 개인정보의 처리에 관하여 대통령령으로 정한 사항\n② 개인정보처리자가 개인정보 처리방침을 수립하거나 변경하는 경우에는 정보주체가 쉽게 확인할 수 있도록 대통\n령령으로 정하는 방법에 따라 공개하여야 한다.\n③ 개인정보 처리방침의 내용과 개인정보처리자와 정보주체 간에 체결한 계약의 내용이 다른 경우에는 정보주체에\n게 유리한 것을 적용한다.\n④ 보호위원회는 개인정보 처리방침의 작성지침을 정하여 개인정보처리자에게 그 준수를 권장할 수 있다.<개정\n2013. 3. 23., 2014. 11. 19., 2017. 7. 26., 2020. 2. 4.>']
# gi : 49, g : [55]
# ['제30조의2(개인정보 처리방침의 평가 및 개선권고) ① 보호위원회는 개인정보 처리방침에 관하여 다음 각 호의 사항을\n평가하고, 평가 결과 개선이 필요하다고 인정하는 경우에는 개인정보처리자에게 제61조제2항에 따라 개선을 권고할\n수 있다.\n1. 이 법에 따라 개인정보 처리방침에 포함하여야 할 사항을 적정하게 정하고 있는지 여부\n2. 개인정보 처리방침을 알기 쉽게 작성하였는지 여부\n3. 개인정보 처리방침을 정보주체가 쉽게 확인할 수 있는 방법으로 공개하고 있는지 여부\n② 개인정보 처리방침의 평가 대상, 기준 및 절차 등에 필요한 사항은 대통령령으로 정한다.\n[본조신설 2023. 3. 14.]']
# gi : 50, g : [56]
# ['제31조(개인정보 보호책임자의 지정 등) ① 개인정보처리자는 개인정보의 처리에 관한 업무를 총괄해서 책임질 개인정\n보 보호책임자를 지정하여야 한다. 다만, 종업원 수, 매출액 등이 대통령령으로 정하는 기준에 해당하는 개인정보처\n리자의 경우에는 지정하지 아니할 수 있다. <개정 2023. 3. 14.>\n② 제1항 단서에 따라 개인정보 보호책임자를 지정하지 아니하는 경우에는 개인정보처리자의 사업주 또는 대표자\n가 개인정보 보호책임자가 된다.<신설 2023. 3. 14.>\n③ 개인정보 보호책임자는 다음 각 호의 업무를 수행한다.<개정 2023. 3. 14.>\n1. 개인정보 보호 계획의 수립 및 시행\n2. 개인정보 처리 실태 및 관행의 정기적인 조사 및 개선\n3. 개인정보 처리와 관련한 불만의 처리 및 피해 구제\n4. 개인정보 유출 및 오용ㆍ남용 방지를 위한 내부통제시스템의 구축\n5. 개인정보 보호 교육 계획의 수립 및 시행\n6. 개인정보파일의 보호 및 관리ㆍ감독\n7. 그 밖에 개인정보의 적절한 처리를 위하여 대통령령으로 정한 업무\n④ 개인정보 보호책임자는 제3항 각 호의 업무를 수행함에 있어서 필요한 경우 개인정보의 처리 현황, 처리 체계 등\n에 대하여 수시로 조사하거나 관계 당사자로부터 보고를 받을 수 있다.<개정 2023. 3. 14.>\n⑤ 개인정보 보호책임자는 개인정보 보호와 관련하여 이 법 및 다른 관계 법령의 위반 사실을 알게 된 경우에는 즉\n시 개선조치를 하여야 하며, 필요하면 소속 기관 또는 단체의 장에게 개선조치를 보고하여야 한다.<개정 2023. 3.\n14.>\n⑥ 개인정보처리자는 개인정보 보호책임자가 제3항 각 호의 업무를 수행함에 있어서 정당한 이유 없이 불이익을 주\n거나 받게 하여서는 아니 되며, 개인정보 보호책임자가 업무를 독립적으로 수행할 수 있도록 보장하여야 한다.<개\n정 2023. 3. 14.>\n⑦ 개인정보처리자는 개인정보의 안전한 처리 및 보호, 정보의 교류, 그 밖에 대통령령으로 정하는 공동의 사업을\n수행하기 위하여 제1항에 따른 개인정보 보호책임자를 구성원으로 하는 개인정보 보호책임자 협의회를 구성ㆍ운영\n할 수 있다.<신설 2023. 3. 14.>\n⑧ 보호위원회는 제7항에 따른 개인정보 보호책임자 협의회의 활동에 필요한 지원을 할 수 있다.<신설 2023. 3.\n14.>\n⑨ 제1항에 따른 개인정보 보호책임자의 자격요건, 제3항에 따른 업무 및 제6항에 따른 독립성 보장 등에 필요한 사\n항은 매출액, 개인정보의 보유 규모 등을 고려하여 대통령령으로 정한다.<개정 2023. 3. 14.>\n[제목개정 2023. 3. 14.]']
# gi : 51, g : [57, np.int64(58)]
# ['제31조의2(국내대리인의 지정) ① 국내에 주소 또는 영업소가 없는 개인정보처리자로서 매출액, 개인정보의 보유 규모\n등을 고려하여 대통령령으로 정하는 자는 다음 각 호의 사항을 대리하는 자(이하 “국내대리인”이라 한다)를 지정하\n여야 한다. 이 경우 국내대리인의 지정은 문서로 하여야 한다. <개정 2023. 3. 14.>\n1. 제31조제3항에 따른 개인정보 보호책임자의 업무\n2. 제34조제1항 및 제3항에 따른 개인정보 유출 등의 통지 및 신고\n3. 제63조제1항에 따른 물품ㆍ서류 등 자료의 제출\n② 국내대리인은 국내에 주소 또는 영업소가 있어야 한다.<개정 2023. 3. 14.>\n③ 개인정보처리자는 제1항에 따라 국내대리인을 지정하는 경우에는 다음 각 호의 사항을 개인정보 처리방침에 포\n함하여야 한다.<개정 2023. 3. 14.>\n1. 국내대리인의 성명(법인의 경우에는 그 명칭 및 대표자의 성명을 말한다)\n2. 국내대리인의 주소(법인의 경우에는 영업소의 소재지를 말한다), 전화번호 및 전자우편 주소\n④ 국내대리인이 제1항 각 호와 관련하여 이 법을 위반한 경우에는 개인정보처리자가 그 행위를 한 것으로 본다.\n<개정 2023. 3. 14.>\n[본조신설 2020. 2. 4.]\n[제39조의11에서 이동 <2023. 3. 14.>]', '제31조의2(국내대리인의 지정) ① 국내에 주소 또는 영업소가 없는 개인정보처리자로서 매출액, 개인정보의 보유 규모\n등을 고려하여 대통령령으로 정하는 자는 다음 각 호의 사항을 대리하는 자(이하 “국내대리인”이라 한다)를 지정하\n여야 한다. 이 경우 국내대리인의 지정은 문서로 하여야 한다. <개정 2023. 3. 14., 2025. 4. 1.>\n1. 제31조제3항제3호에 따른 개인정보 처리와 관련한 불만의 처리 및 피해 구제 업무\n2. 제34조제1항 및 제3항에 따른 개인정보 유출 등의 통지 및 신고\n3. 제63조제1항에 따른 물품ㆍ서류 등 자료의 제출\n② 국내대리인은 국내에 주소 또는 영업소가 있어야 한다. 이 경우 다음 각 호의 어느 하나에 해당하는 법인이 있는\n개인정보처리자는 그 법인 중에서 국내대리인을 지정하여야 한다.<개정 2023. 3. 14., 2025. 4. 1.>\n1. 해당 개인정보처리자가 설립한 국내 법인\n2. 해당 개인정보처리자가 임원 구성, 사업 운영 등에 지배적인 영향력을 행사하는 국내 법인으로서 대통령령으로\n정하는 법인\n③ 제1항에 따라 국내대리인을 지정한 개인정보처리자는 국내대리인이 업무를 충실히 수행하도록 대통령령으로 정\n하는 바에 따라 교육하고 업무현황을 점검하는 등의 관리ㆍ감독을 하여야 한다.<신설 2025. 4. 1.>\n④ 개인정보처리자는 제1항에 따라 국내대리인을 지정하는 경우에는 다음 각 호의 사항을 개인정보 처리방침에 포\n함하여야 한다.<개정 2023. 3. 14., 2025. 4. 1.>\n1. 국내대리인의 성명(법인의 경우에는 그 명칭 및 대표자의 성명을 말한다)\n2. 국내대리인의 주소(법인의 경우에는 영업소의 소재지를 말한다), 전화번호 및 전자우편 주소\n⑤ 국내대리인이 제1항 각 호와 관련하여 이 법을 위반한 경우에는 개인정보처리자가 그 행위를 한 것으로 본다.\n<개정 2023. 3. 14., 2025. 4. 1.>\n[본조신설 2020. 2. 4.]\n[제39조의11에서 이동 <2023. 3. 14.>]\n[시행일: 2025. 10. 2.] 제31조의2']
# gi : 52, g : [59]
# ['제32조(개인정보파일의 등록 및 공개) ① 공공기관의 장이 개인정보파일을 운용하는 경우에는 다음 각 호의 사항을 보\n호위원회에 등록하여야 한다. 등록한 사항이 변경된 경우에도 또한 같다. <개정 2013. 3. 23., 2014. 11. 19., 2017. 7.\n26., 2020. 2. 4.>\n1. 개인정보파일의 명칭\n2. 개인정보파일의 운영 근거 및 목적\n3. 개인정보파일에 기록되는 개인정보의 항목\n4. 개인정보의 처리방법\n5. 개인정보의 보유기간\n6. 개인정보를 통상적 또는 반복적으로 제공하는 경우에는 그 제공받는 자\n7. 그 밖에 대통령령으로 정하는 사항\n② 다음 각 호의 어느 하나에 해당하는 개인정보파일에 대하여는 제1항을 적용하지 아니한다.<개정 2023. 3. 14.>\n1. 국가 안전, 외교상 비밀, 그 밖에 국가의 중대한 이익에 관한 사항을 기록한 개인정보파일\n2. 범죄의 수사, 공소의 제기 및 유지, 형 및 감호의 집행, 교정처분, 보호처분, 보안관찰처분과 출입국관리에 관한 사\n항을 기록한 개인정보파일\n3. 「조세범처벌법」에 따른 범칙행위 조사 및 「관세법」에 따른 범칙행위 조사에 관한 사항을 기록한 개인정보파일\n4. 일회적으로 운영되는 파일 등 지속적으로 관리할 필요성이 낮다고 인정되어 대통령령으로 정하는 개인정보파일\n5. 다른 법령에 따라 비밀로 분류된 개인정보파일\n③ 보호위원회는 필요하면 제1항에 따른 개인정보파일의 등록여부와 그 내용을 검토하여 해당 공공기관의 장에게\n개선을 권고할 수 있다.<개정 2013. 3. 23., 2014. 11. 19., 2017. 7. 26., 2020. 2. 4., 2023. 3. 14.>\n④ 보호위원회는 정보주체의 권리 보장 등을 위하여 필요한 경우 제1항에 따른 개인정보파일의 등록 현황을 누구든\n지 쉽게 열람할 수 있도록 공개할 수 있다.<개정 2013. 3. 23., 2014. 11. 19., 2017. 7. 26., 2020. 2. 4., 2023. 3. 14.>\n⑤ 제1항에 따른 등록과 제4항에 따른 공개의 방법, 범위 및 절차에 관하여 필요한 사항은 대통령령으로 정한다.\n⑥ 국회, 법원, 헌법재판소, 중앙선거관리위원회(그 소속 기관을 포함한다)의 개인정보파일 등록 및 공개에 관하여는\n국회규칙, 대법원규칙, 헌법재판소규칙 및 중앙선거관리위원회규칙으로 정한다.']
# gi : 53, g : [60]
# ['제32조의2(개인정보 보호 인증) ① 보호위원회는 개인정보처리자의 개인정보 처리 및 보호와 관련한 일련의 조치가 이\n법에 부합하는지 등에 관하여 인증할 수 있다. <개정 2017. 7. 26., 2020. 2. 4.>\n② 제1항에 따른 인증의 유효기간은 3년으로 한다.\n③ 보호위원회는 다음 각 호의 어느 하나에 해당하는 경우에는 대통령령으로 정하는 바에 따라 제1항에 따른 인증\n을 취소할 수 있다. 다만, 제1호에 해당하는 경우에는 취소하여야 한다.<개정 2017. 7. 26., 2020. 2. 4.>\n1. 거짓이나 그 밖의 부정한 방법으로 개인정보 보호 인증을 받은 경우\n2. 제4항에 따른 사후관리를 거부 또는 방해한 경우\n3. 제8항에 따른 인증기준에 미달하게 된 경우\n4. 개인정보 보호 관련 법령을 위반하고 그 위반사유가 중대한 경우\n④ 보호위원회는 개인정보 보호 인증의 실효성 유지를 위하여 연 1회 이상 사후관리를 실시하여야 한다.<개정\n2017. 7. 26., 2020. 2. 4.>\n⑤ 보호위원회는 대통령령으로 정하는 전문기관으로 하여금 제1항에 따른 인증, 제3항에 따른 인증 취소, 제4항에\n따른 사후관리 및 제7항에 따른 인증 심사원 관리 업무를 수행하게 할 수 있다.<개정 2017. 7. 26., 2020. 2. 4.>\n⑥ 제1항에 따른 인증을 받은 자는 대통령령으로 정하는 바에 따라 인증의 내용을 표시하거나 홍보할 수 있다.\n⑦ 제1항에 따른 인증을 위하여 필요한 심사를 수행할 심사원의 자격 및 자격 취소 요건 등에 관하여는 전문성과\n경력 및 그 밖에 필요한 사항을 고려하여 대통령령으로 정한다.\n⑧ 그 밖에 개인정보 관리체계, 정보주체 권리보장, 안전성 확보조치가 이 법에 부합하는지 여부 등 제1항에 따른\n인증의 기준ㆍ방법ㆍ절차 등 필요한 사항은 대통령령으로 정한다.\n[본조신설 2015. 7. 24.]']
# gi : 54, g : [61]
# ['제33조(개인정보 영향평가) ① 공공기관의 장은 대통령령으로 정하는 기준에 해당하는 개인정보파일의 운용으로 인하\n여 정보주체의 개인정보 침해가 우려되는 경우에는 그 위험요인의 분석과 개선 사항 도출을 위한 평가(이하 “영향평\n가”라 한다)를 하고 그 결과를 보호위원회에 제출하여야 한다. <개정 2013. 3. 23., 2014. 11. 19., 2017. 7. 26., 2020.\n2. 4., 2023. 3. 14.>\n② 보호위원회는 대통령령으로 정하는 인력ㆍ설비 및 그 밖에 필요한 요건을 갖춘 자를 영향평가를 수행하는 기관\n(이하 “평가기관”이라 한다)으로 지정할 수 있으며, 공공기관의 장은 영향평가를 평가기관에 의뢰하여야 한다.<신설\n2023. 3. 14.>\n③ 영향평가를 하는 경우에는 다음 각 호의 사항을 고려하여야 한다.<개정 2023. 3. 14.>\n1. 처리하는 개인정보의 수\n2. 개인정보의 제3자 제공 여부\n3. 정보주체의 권리를 해할 가능성 및 그 위험 정도\n4. 그 밖에 대통령령으로 정한 사항\n④ 보호위원회는 제1항에 따라 제출받은 영향평가 결과에 대하여 의견을 제시할 수 있다.<개정 2013. 3. 23., 2014.\n11. 19., 2017. 7. 26., 2020. 2. 4., 2023. 3. 14.>\n⑤ 공공기관의 장은 제1항에 따라 영향평가를 한 개인정보파일을 제32조제1항에 따라 등록할 때에는 영향평가 결\n과를 함께 첨부하여야 한다.<개정 2023. 3. 14.>\n⑥ 보호위원회는 영향평가의 활성화를 위하여 관계 전문가의 육성, 영향평가 기준의 개발ㆍ보급 등 필요한 조치를\n마련하여야 한다.<개정 2013. 3. 23., 2014. 11. 19., 2017. 7. 26., 2020. 2. 4., 2023. 3. 14.>\n⑦ 보호위원회는 제2항에 따라 지정된 평가기관이 다음 각 호의 어느 하나에 해당하는 경우에는 평가기관의 지정을\n취소할 수 있다. 다만, 제1호 또는 제2호에 해당하는 경우에는 평가기관의 지정을 취소하여야 한다.<신설 2023. 3.\n14.>\n1. 거짓이나 그 밖의 부정한 방법으로 지정을 받은 경우\n2. 지정된 평가기관 스스로 지정취소를 원하거나 폐업한 경우\n3. 제2항에 따른 지정요건을 충족하지 못하게 된 경우\n4. 고의 또는 중대한 과실로 영향평가업무를 부실하게 수행하여 그 업무를 적정하게 수행할 수 없다고 인정되는 경\n우\n5. 그 밖에 대통령령으로 정하는 사유에 해당하는 경우\n⑧ 보호위원회는 제7항에 따라 지정을 취소하는 경우에는 「행정절차법」에 따른 청문을 실시하여야 한다.<신설\n2023. 3. 14.>\n⑨ 제1항에 따른 영향평가의 기준ㆍ방법ㆍ절차 등에 관하여 필요한 사항은 대통령령으로 정한다.<개정 2023. 3.\n14.>\n⑩ 국회, 법원, 헌법재판소, 중앙선거관리위원회(그 소속 기관을 포함한다)의 영향평가에 관한 사항은 국회규칙, 대\n법원규칙, 헌법재판소규칙 및 중앙선거관리위원회규칙으로 정하는 바에 따른다.<개정 2023. 3. 14.>\n⑪ 공공기관 외의 개인정보처리자는 개인정보파일 운용으로 인하여 정보주체의 개인정보 침해가 우려되는 경우에\n는 영향평가를 하기 위하여 적극 노력하여야 한다.<개정 2023. 3. 14.>']
# gi : 55, g : [62]
# ['제34조(개인정보 유출 등의 통지ㆍ신고) ① 개인정보처리자는 개인정보가 분실ㆍ도난ㆍ유출(이하 이 조에서 “유출등\n”이라 한다)되었음을 알게 되었을 때에는 지체 없이 해당 정보주체에게 다음 각 호의 사항을 알려야 한다. 다만, 정보\n주체의 연락처를 알 수 없는 경우 등 정당한 사유가 있는 경우에는 대통령령으로 정하는 바에 따라 통지를 갈음하는\n조치를 취할 수 있다. <개정 2023. 3. 14.>\n1. 유출등이 된 개인정보의 항목\n2. 유출등이 된 시점과 그 경위\n3. 유출등으로 인하여 발생할 수 있는 피해를 최소화하기 위하여 정보주체가 할 수 있는 방법 등에 관한 정보\n4. 개인정보처리자의 대응조치 및 피해 구제절차\n5. 정보주체에게 피해가 발생한 경우 신고 등을 접수할 수 있는 담당부서 및 연락처\n② 개인정보처리자는 개인정보가 유출등이 된 경우 그 피해를 최소화하기 위한 대책을 마련하고 필요한 조치를 하\n여야 한다.<개정 2023. 3. 14.>\n③ 개인정보처리자는 개인정보의 유출등이 있음을 알게 되었을 때에는 개인정보의 유형, 유출등의 경로 및 규모 등\n을 고려하여 대통령령으로 정하는 바에 따라 제1항 각 호의 사항을 지체 없이 보호위원회 또는 대통령령으로 정하\n는 전문기관에 신고하여야 한다. 이 경우 보호위원회 또는 대통령령으로 정하는 전문기관은 피해 확산방지, 피해 복\n구 등을 위한 기술을 지원할 수 있다.<개정 2013. 3. 23., 2014. 11. 19., 2017. 7. 26., 2020. 2. 4., 2023. 3. 14.>\n④ 제1항에 따른 유출등의 통지 및 제3항에 따른 유출등의 신고의 시기, 방법, 절차 등에 필요한 사항은 대통령령으\n로 정한다.<개정 2023. 3. 14.>\n[제목개정 2023. 3. 14.]']
# gi : 56, g : [63]
# ['제34조의2(노출된 개인정보의 삭제ㆍ차단) ① 개인정보처리자는 고유식별정보, 계좌정보, 신용카드정보 등 개인정보가\n정보통신망을 통하여 공중(公衆)에 노출되지 아니하도록 하여야 한다. <개정 2023. 3. 14.>\n② 개인정보처리자는 공중에 노출된 개인정보에 대하여 보호위원회 또는 대통령령으로 지정한 전문기관의 요청이\n있는 경우에는 해당 정보를 삭제하거나 차단하는 등 필요한 조치를 하여야 한다.<개정 2023. 3. 14.>\n[본조신설 2020. 2. 4.]\n[제39조의10에서 이동, 종전 제34조의2는 삭제 <2023. 3. 14.>]']
# gi : 57, g : [64]
# ['제35조(개인정보의 열람) ① 정보주체는 개인정보처리자가 처리하는 자신의 개인정보에 대한 열람을 해당 개인정보처\n리자에게 요구할 수 있다.\n② 제1항에도 불구하고 정보주체가 자신의 개인정보에 대한 열람을 공공기관에 요구하고자 할 때에는 공공기관에\n직접 열람을 요구하거나 대통령령으로 정하는 바에 따라 보호위원회를 통하여 열람을 요구할 수 있다.<개정 2013.\n3. 23., 2014. 11. 19., 2017. 7. 26., 2020. 2. 4.>\n③ 개인정보처리자는 제1항 및 제2항에 따른 열람을 요구받았을 때에는 대통령령으로 정하는 기간 내에 정보주체\n가 해당 개인정보를 열람할 수 있도록 하여야 한다. 이 경우 해당 기간 내에 열람할 수 없는 정당한 사유가 있을 때\n에는 정보주체에게 그 사유를 알리고 열람을 연기할 수 있으며, 그 사유가 소멸하면 지체 없이 열람하게 하여야 한\n다.\n④ 개인정보처리자는 다음 각 호의 어느 하나에 해당하는 경우에는 정보주체에게 그 사유를 알리고 열람을 제한하\n거나 거절할 수 있다.\n1. 법률에 따라 열람이 금지되거나 제한되는 경우\n2. 다른 사람의 생명ㆍ신체를 해할 우려가 있거나 다른 사람의 재산과 그 밖의 이익을 부당하게 침해할 우려가 있는\n경우\n3. 공공기관이 다음 각 목의 어느 하나에 해당하는 업무를 수행할 때 중대한 지장을 초래하는 경우\n가. 조세의 부과ㆍ징수 또는 환급에 관한 업무\n나. 「초ㆍ중등교육법」 및 「고등교육법」에 따른 각급 학교, 「평생교육법」에 따른 평생교육시설, 그 밖의 다른 법\n률에 따라 설치된 고등교육기관에서의 성적 평가 또는 입학자 선발에 관한 업무\n다. 학력ㆍ기능 및 채용에 관한 시험, 자격 심사에 관한 업무\n라. 보상금ㆍ급부금 산정 등에 대하여 진행 중인 평가 또는 판단에 관한 업무\n마. 다른 법률에 따라 진행 중인 감사 및 조사에 관한 업무\n⑤ 제1항부터 제4항까지의 규정에 따른 열람 요구, 열람 제한, 통지 등의 방법 및 절차에 관하여 필요한 사항은 대\n통령령으로 정한다.']
# gi : 58, g : [65]
# ['제35조의2(개인정보의 전송 요구) ① 정보주체는 개인정보 처리 능력 등을 고려하여 대통령령으로 정하는 기준에 해당\n하는 개인정보처리자에 대하여 다음 각 호의 요건을 모두 충족하는 개인정보를 자신에게로 전송할 것을 요구할 수\n있다.\n1. 정보주체가 전송을 요구하는 개인정보가 정보주체 본인에 관한 개인정보로서 다음 각 목의 어느 하나에 해당하\n는 정보일 것\n가. 제15조제1항제1호, 제23조제1항제1호 또는 제24조제1항제1호에 따른 동의를 받아 처리되는 개인정보\n나. 제15조제1항제4호에 따라 체결한 계약을 이행하거나 계약을 체결하는 과정에서 정보주체의 요청에 따른 조\n치를 이행하기 위하여 처리되는 개인정보\n다. 제15조제1항제2호ㆍ제3호, 제23조제1항제2호 또는 제24조제1항제2호에 따라 처리되는 개인정보 중 정보주\n체의 이익이나 공익적 목적을 위하여 관계 중앙행정기관의 장의 요청에 따라 보호위원회가 심의ㆍ의결하여\n전송 요구의 대상으로 지정한 개인정보\n2. 전송을 요구하는 개인정보가 개인정보처리자가 수집한 개인정보를 기초로 분석ㆍ가공하여 별도로 생성한 정보\n가 아닐 것\n3. 전송을 요구하는 개인정보가 컴퓨터 등 정보처리장치로 처리되는 개인정보일 것\n② 정보주체는 매출액, 개인정보의 보유 규모, 개인정보 처리 능력, 산업별 특성 등을 고려하여 대통령령으로 정하\n는 기준에 해당하는 개인정보처리자에 대하여 제1항에 따른 전송 요구 대상인 개인정보를 기술적으로 허용되는 합\n리적인 범위에서 다음 각 호의 자에게 전송할 것을 요구할 수 있다.\n1. 제35조의3제1항에 따른 개인정보관리 전문기관\n2. 제29조에 따른 안전조치의무를 이행하고 대통령령으로 정하는 시설 및 기술 기준을 충족하는 자\n③ 개인정보처리자는 제1항 및 제2항에 따른 전송 요구를 받은 경우에는 시간, 비용, 기술적으로 허용되는 합리적인\n범위에서 해당 정보를 컴퓨터 등 정보처리장치로 처리 가능한 형태로 전송하여야 한다.\n④ 제1항 및 제2항에 따른 전송 요구를 받은 개인정보처리자는 다음 각 호의 어느 하나에 해당하는 법률의 관련 규\n정에도 불구하고 정보주체에 관한 개인정보를 전송하여야 한다.\n1. 「국세기본법」 제81조의13\n2. 「지방세기본법」 제86조\n3. 그 밖에 제1호 및 제2호와 유사한 규정으로서 대통령령으로 정하는 법률의 규정\n⑤ 정보주체는 제1항 및 제2항에 따른 전송 요구를 철회할 수 있다.\n⑥ 개인정보처리자는 정보주체의 본인 여부가 확인되지 아니하는 경우 등 대통령령으로 정하는 경우에는 제1항 및\n제2항에 따른 전송 요구를 거절하거나 전송을 중단할 수 있다.\n⑦ 정보주체는 제1항 및 제2항에 따른 전송 요구로 인하여 타인의 권리나 정당한 이익을 침해하여서는 아니 된다.\n⑧ 제1항부터 제7항까지에서 규정한 사항 외에 전송 요구의 대상이 되는 정보의 범위, 전송 요구의 방법, 전송의 기\n한 및 방법, 전송 요구 철회의 방법, 전송 요구의 거절 및 전송 중단의 방법 등 필요한 사항은 대통령령으로 정한다.\n[본조신설 2023. 3. 14.]']
# gi : 59, g : [66]
# ['제35조의3(개인정보관리 전문기관) ① 다음 각 호의 업무를 수행하려는 자는 보호위원회 또는 관계 중앙행정기관의 장\n으로부터 개인정보관리 전문기관의 지정을 받아야 한다.\n1. 제35조의2에 따른 개인정보의 전송 요구권 행사 지원\n2. 정보주체의 권리행사를 지원하기 위한 개인정보 전송시스템의 구축 및 표준화\n3. 정보주체의 권리행사를 지원하기 위한 개인정보의 관리ㆍ분석\n4. 그 밖에 정보주체의 권리행사를 효과적으로 지원하기 위하여 대통령령으로 정하는 업무\n② 제1항에 따른 개인정보관리 전문기관의 지정요건은 다음 각 호와 같다.\n1. 개인정보를 전송ㆍ관리ㆍ분석할 수 있는 기술수준 및 전문성을 갖추었을 것\n2. 개인정보를 안전하게 관리할 수 있는 안전성 확보조치 수준을 갖추었을 것\n3. 개인정보관리 전문기관의 안정적인 운영에 필요한 재정능력을 갖추었을 것\n③ 개인정보관리 전문기관은 다음 각 호의 어느 하나에 해당하는 행위를 하여서는 아니 된다.\n1. 정보주체에게 개인정보의 전송 요구를 강요하거나 부당하게 유도하는 행위\n2. 그 밖에 개인정보를 침해하거나 정보주체의 권리를 제한할 우려가 있는 행위로서 대통령령으로 정하는 행위\n④ 보호위원회 및 관계 중앙행정기관의 장은 개인정보관리 전문기관이 다음 각 호의 어느 하나에 해당하는 경우에\n는 개인정보관리 전문기관의 지정을 취소할 수 있다. 다만, 제1호에 해당하는 경우에는 지정을 취소하여야 한다.\n1. 거짓이나 부정한 방법으로 지정을 받은 경우\n2. 제2항에 따른 지정요건을 갖추지 못하게 된 경우\n⑤ 보호위원회 및 관계 중앙행정기관의 장은 제4항에 따라 지정을 취소하는 경우에는 「행정절차법」에 따른 청문을\n실시하여야 한다.\n⑥ 보호위원회 및 관계 중앙행정기관의 장은 개인정보관리 전문기관에 대하여 업무 수행에 필요한 지원을 할 수 있\n다.\n⑦ 개인정보관리 전문기관은 정보주체의 요구에 따라 제1항 각 호의 업무를 수행하는 경우 정보주체로부터 그 업무\n수행에 필요한 비용을 받을 수 있다.\n⑧ 제1항에 따른 개인정보관리 전문기관의 지정 절차, 제2항에 따른 지정요건의 세부기준, 제4항에 따른 지정취소\n의 절차 등에 필요한 사항은 대통령령으로 정한다.\n[본조신설 2023. 3. 14.]']
# gi : 60, g : [67]
# ['제35조의4(개인정보 전송 관리 및 지원) ① 보호위원회는 제35조의2제1항 및 제2항에 따른 개인정보처리자 및 제35조\n의3제1항에 따른 개인정보관리 전문기관 현황, 활용내역 및 관리실태 등을 체계적으로 관리ㆍ감독하여야 한다.\n② 보호위원회는 개인정보가 안전하고 효율적으로 전송될 수 있도록 다음 각 호의 사항을 포함한 개인정보 전송 지\n원 플랫폼을 구축ㆍ운영할 수 있다.\n1. 개인정보관리 전문기관 현황 및 전송 가능한 개인정보 항목 목록\n2. 정보주체의 개인정보 전송 요구ㆍ철회 내역\n3. 개인정보의 전송 이력 관리 등 지원 기능\n4. 그 밖에 개인정보 전송을 위하여 필요한 사항\n③ 보호위원회는 제2항에 따른 개인정보 전송지원 플랫폼의 효율적 운영을 위하여 개인정보관리 전문기관에서 구\n축ㆍ운영하고 있는 전송 시스템을 상호 연계하거나 통합할 수 있다. 이 경우 관계 중앙행정기관의 장 및 해당 개인\n정보관리 전문기관과 사전에 협의하여야 한다.\n④ 제1항부터 제3항까지의 규정에 따른 관리ㆍ감독과 개인정보 전송지원 플랫폼의 구축 및 운영에 필요한 사항은\n대통령령으로 정한다.\n[본조신설 2023. 3. 14.]']
# gi : 61, g : [68]
# ['제36조(개인정보의 정정ㆍ삭제) ① 제35조에 따라 자신의 개인정보를 열람한 정보주체는 개인정보처리자에게 그 개인\n정보의 정정 또는 삭제를 요구할 수 있다. 다만, 다른 법령에서 그 개인정보가 수집 대상으로 명시되어 있는 경우에\n는 그 삭제를 요구할 수 없다.\n② 개인정보처리자는 제1항에 따른 정보주체의 요구를 받았을 때에는 개인정보의 정정 또는 삭제에 관하여 다른 법\n령에 특별한 절차가 규정되어 있는 경우를 제외하고는 지체 없이 그 개인정보를 조사하여 정보주체의 요구에 따라\n정정ㆍ삭제 등 필요한 조치를 한 후 그 결과를 정보주체에게 알려야 한다.\n③ 개인정보처리자가 제2항에 따라 개인정보를 삭제할 때에는 복구 또는 재생되지 아니하도록 조치하여야 한다.\n④ 개인정보처리자는 정보주체의 요구가 제1항 단서에 해당될 때에는 지체 없이 그 내용을 정보주체에게 알려야 한\n다.\n⑤ 개인정보처리자는 제2항에 따른 조사를 할 때 필요하면 해당 정보주체에게 정정ㆍ삭제 요구사항의 확인에 필요\n한 증거자료를 제출하게 할 수 있다.\n⑥ 제1항ㆍ제2항 및 제4항에 따른 정정 또는 삭제 요구, 통지 방법 및 절차 등에 필요한 사항은 대통령령으로 정한\n다.']
# gi : 62, g : [69]
# ['제37조(개인정보의 처리정지 등) ① 정보주체는 개인정보처리자에 대하여 자신의 개인정보 처리의 정지를 요구하거나\n개인정보 처리에 대한 동의를 철회할 수 있다. 이 경우 공공기관에 대해서는 제32조에 따라 등록 대상이 되는 개인\n정보파일 중 자신의 개인정보에 대한 처리의 정지를 요구하거나 개인정보 처리에 대한 동의를 철회할 수 있다. <개\n정 2023. 3. 14.>\n② 개인정보처리자는 제1항에 따른 처리정지 요구를 받았을 때에는 지체 없이 정보주체의 요구에 따라 개인정보 처\n리의 전부를 정지하거나 일부를 정지하여야 한다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 정보주체의\n처리정지 요구를 거절할 수 있다.<개정 2023. 3. 14.>\n1. 법률에 특별한 규정이 있거나 법령상 의무를 준수하기 위하여 불가피한 경우\n2. 다른 사람의 생명ㆍ신체를 해할 우려가 있거나 다른 사람의 재산과 그 밖의 이익을 부당하게 침해할 우려가 있는\n경우\n3. 공공기관이 개인정보를 처리하지 아니하면 다른 법률에서 정하는 소관 업무를 수행할 수 없는 경우\n4. 개인정보를 처리하지 아니하면 정보주체와 약정한 서비스를 제공하지 못하는 등 계약의 이행이 곤란한 경우로서\n정보주체가 그 계약의 해지 의사를 명확하게 밝히지 아니한 경우\n③ 개인정보처리자는 정보주체가 제1항에 따라 동의를 철회한 때에는 지체 없이 수집된 개인정보를 복구ㆍ재생할\n수 없도록 파기하는 등 필요한 조치를 하여야 한다. 다만, 제2항 각 호의 어느 하나에 해당하는 경우에는 동의 철회\n에 따른 조치를 하지 아니할 수 있다.<신설 2023. 3. 14.>\n④ 개인정보처리자는 제2항 단서에 따라 처리정지 요구를 거절하거나 제3항 단서에 따라 동의 철회에 따른 조치를\n하지 아니하였을 때에는 정보주체에게 지체 없이 그 사유를 알려야 한다.<개정 2023. 3. 14.>\n⑤ 개인정보처리자는 정보주체의 요구에 따라 처리가 정지된 개인정보에 대하여 지체 없이 해당 개인정보의 파기\n등 필요한 조치를 하여야 한다.<개정 2023. 3. 14.>\n⑥ 제1항부터 제5항까지의 규정에 따른 처리정지의 요구, 동의 철회, 처리정지의 거절, 통지 등의 방법 및 절차에 필\n요한 사항은 대통령령으로 정한다.<개정 2023. 3. 14.>']
# gi : 63, g : [70]
# ['제37조의2(자동화된 결정에 대한 정보주체의 권리 등) ① 정보주체는 완전히 자동화된 시스템(인공지능 기술을 적용한\n시스템을 포함한다)으로 개인정보를 처리하여 이루어지는 결정(「행정기본법」 제20조에 따른 행정청의 자동적 처분\n은 제외하며, 이하 이 조에서 “자동화된 결정”이라 한다)이 자신의 권리 또는 의무에 중대한 영향을 미치는 경우에는\n해당 개인정보처리자에 대하여 해당 결정을 거부할 수 있는 권리를 가진다. 다만, 자동화된 결정이 제15조제1항제\n1호ㆍ제2호 및 제4호에 따라 이루어지는 경우에는 그러하지 아니하다.\n② 정보주체는 개인정보처리자가 자동화된 결정을 한 경우에는 그 결정에 대하여 설명 등을 요구할 수 있다.\n③ 개인정보처리자는 제1항 또는 제2항에 따라 정보주체가 자동화된 결정을 거부하거나 이에 대한 설명 등을 요구\n한 경우에는 정당한 사유가 없는 한 자동화된 결정을 적용하지 아니하거나 인적 개입에 의한 재처리ㆍ설명 등 필요\n한 조치를 하여야 한다.\n④ 개인정보처리자는 자동화된 결정의 기준과 절차, 개인정보가 처리되는 방식 등을 정보주체가 쉽게 확인할 수 있\n도록 공개하여야 한다.\n⑤ 제1항부터 제4항까지에서 규정한 사항 외에 자동화된 결정의 거부ㆍ설명 등을 요구하는 절차 및 방법, 거부ㆍ설\n명 등의 요구에 따른 필요한 조치, 자동화된 결정의 기준ㆍ절차 및 개인정보가 처리되는 방식의 공개 등에 필요한\n사항은 대통령령으로 정한다.\n[본조신설 2023. 3. 14.]']
# gi : 64, g : [71]
# ['제38조(권리행사의 방법 및 절차) ① 정보주체는 제35조에 따른 열람, 제35조의2에 따른 전송, 제36조에 따른 정정ㆍ삭\n제, 제37조에 따른 처리정지 및 동의 철회, 제37조의2에 따른 거부ㆍ설명 등의 요구(이하 “열람등요구”라 한다)를 문\n서 등 대통령령으로 정하는 방법ㆍ절차에 따라 대리인에게 하게 할 수 있다. <개정 2020. 2. 4., 2023. 3. 14.>\n② 만 14세 미만 아동의 법정대리인은 개인정보처리자에게 그 아동의 개인정보 열람등요구를 할 수 있다.\n③ 개인정보처리자는 열람등요구를 하는 자에게 대통령령으로 정하는 바에 따라 수수료와 우송료(사본의 우송을\n청구하는 경우에 한한다)를 청구할 수 있다. 다만, 제35조의2제2항에 따른 전송 요구의 경우에는 전송을 위해 추가\n로 필요한 설비 등을 함께 고려하여 수수료를 산정할 수 있다.<개정 2023. 3. 14.>\n④ 개인정보처리자는 정보주체가 열람등요구를 할 수 있는 구체적인 방법과 절차를 마련하고, 이를 정보주체가 알\n수 있도록 공개하여야 한다. 이 경우 열람등요구의 방법과 절차는 해당 개인정보의 수집 방법과 절차보다 어렵지 아\n니하도록 하여야 한다.<개정 2023. 3. 14.>\n⑤ 개인정보처리자는 정보주체가 열람등요구에 대한 거절 등 조치에 대하여 불복이 있는 경우 이의를 제기할 수 있\n도록 필요한 절차를 마련하고 안내하여야 한다.']
# gi : 65, g : [72, np.int64(73)]
# ...
# gi : 70, g : [78]
# ['제39조의7(손해배상의 보장) ① 개인정보처리자로서 매출액, 개인정보의 보유 규모 등을 고려하여 대통령령으로 정하\n는 기준에 해당하는 자는 제39조 및 제39조의2에 따른 손해배상책임의 이행을 위하여 보험 또는 공제에 가입하거나\n준비금을 적립하는 등 필요한 조치를 하여야 한다. <개정 2023. 3. 14.>\n② 제1항에도 불구하고 다음 각 호의 어느 하나에 해당하는 자는 제1항에 따른 조치를 하지 아니할 수 있다.<개정\n2023. 3. 14.>\n1. 대통령령으로 정하는 공공기관, 비영리법인 및 단체\n2. 「소상공인기본법」 제2조제1항에 따른 소상공인으로서 대통령령으로 정하는 자에게 개인정보 처리를 위탁한 자\n3. 다른 법률에 따라 제39조 및 제39조의2에 따른 손해배상책임의 이행을 보장하는 보험 또는 공제에 가입하거나\n준비금을 적립한 개인정보처리자\n③ 제1항 및 제2항에 따른 개인정보처리자의 손해배상책임 이행 기준 등에 필요한 사항은 대통령령으로 정한다.\n<신설 2023. 3. 14.>\n[본조신설 2020. 2. 4.]\n[제39조의9에서 이동, 종전 제39조의7은 삭제 <2023. 3. 14.>]']
# gi : 71, g : [79]
# ['제40조(설치 및 구성) ① 개인정보에 관한 분쟁의 조정(調停)을 위하여 개인정보 분쟁조정위원회(이하 “분쟁조정위원회\n”라 한다)를 둔다.\n② 분쟁조정위원회는 위원장 1명을 포함한 30명 이내의 위원으로 구성하며, 위원은 당연직위원과 위촉위원으로 구\n성한다.<개정 2015. 7. 24., 2023. 3. 14.>\n③ 위촉위원은 다음 각 호의 어느 하나에 해당하는 사람 중에서 보호위원회 위원장이 위촉하고, 대통령령으로 정하\n는 국가기관 소속 공무원은 당연직위원이 된다.<개정 2013. 3. 23., 2014. 11. 19., 2015. 7. 24.>\n1. 개인정보 보호업무를 관장하는 중앙행정기관의 고위공무원단에 속하는 공무원으로 재직하였던 사람 또는 이에\n상당하는 공공부문 및 관련 단체의 직에 재직하고 있거나 재직하였던 사람으로서 개인정보 보호업무의 경험이\n있는 사람\n2. 대학이나 공인된 연구기관에서 부교수 이상 또는 이에 상당하는 직에 재직하고 있거나 재직하였던 사람\n3. 판사ㆍ검사 또는 변호사로 재직하고 있거나 재직하였던 사람\n4. 개인정보 보호와 관련된 시민사회단체 또는 소비자단체로부터 추천을 받은 사람\n5. 개인정보처리자로 구성된 사업자단체의 임원으로 재직하고 있거나 재직하였던 사람\n④ 위원장은 위원 중에서 공무원이 아닌 사람으로 보호위원회 위원장이 위촉한다.<개정 2013. 3. 23., 2014. 11. 19.,\n2015. 7. 24.>\n⑤ 위원장과 위촉위원의 임기는 2년으로 하되, 1차에 한하여 연임할 수 있다.<개정 2015. 7. 24.>\n⑥ 분쟁조정위원회는 분쟁조정 업무를 효율적으로 수행하기 위하여 필요하면 대통령령으로 정하는 바에 따라 조정\n사건의 분야별로 5명 이내의 위원으로 구성되는 조정부를 둘 수 있다. 이 경우 조정부가 분쟁조정위원회에서 위임\n받아 의결한 사항은 분쟁조정위원회에서 의결한 것으로 본다.\n⑦ 분쟁조정위원회 또는 조정부는 재적위원 과반수의 출석으로 개의하며 출석위원 과반수의 찬성으로 의결한다.\n⑧ 보호위원회는 분쟁조정 접수, 사실 확인 등 분쟁조정에 필요한 사무를 처리할 수 있다.<개정 2015. 7. 24.>\n⑨ 이 법에서 정한 사항 외에 분쟁조정위원회 운영에 필요한 사항은 대통령령으로 정한다.']
# gi : 72, g : [82]
# ['제43조(조정의 신청 등) ① 개인정보와 관련한 분쟁의 조정을 원하는 자는 분쟁조정위원회에 분쟁조정을 신청할 수 있\n다.\n② 분쟁조정위원회는 당사자 일방으로부터 분쟁조정 신청을 받았을 때에는 그 신청내용을 상대방에게 알려야 한다.\n③ 개인정보처리자가 제2항에 따른 분쟁조정의 통지를 받은 경우에는 특별한 사유가 없으면 분쟁조정에 응하여야\n한다.<개정 2023. 3. 14.>']
# gi : 73, g : [83]
# ['제44조(처리기간) ① 분쟁조정위원회는 제43조제1항에 따른 분쟁조정 신청을 받은 날부터 60일 이내에 이를 심사하여\n조정안을 작성하여야 한다. 다만, 부득이한 사정이 있는 경우에는 분쟁조정위원회의 의결로 처리기간을 연장할 수\n있다.\n② 분쟁조정위원회는 제1항 단서에 따라 처리기간을 연장한 경우에는 기간연장의 사유와 그 밖의 기간연장에 관한\n사항을 신청인에게 알려야 한다.']
# gi : 74, g : [84]
# ['제45조(자료의 요청 및 사실조사 등) ① 분쟁조정위원회는 제43조제1항에 따라 분쟁조정 신청을 받았을 때에는 해당\n분쟁의 조정을 위하여 필요한 자료를 분쟁당사자에게 요청할 수 있다. 이 경우 분쟁당사자는 정당한 사유가 없으면\n요청에 따라야 한다.\n② 분쟁조정위원회는 분쟁의 조정을 위하여 사실 확인이 필요한 경우에는 분쟁조정위원회의 위원 또는 대통령령으\n로 정하는 사무기구의 소속 공무원으로 하여금 사건과 관련된 장소에 출입하여 관련 자료를 조사하거나 열람하게\n할 수 있다. 이 경우 분쟁당사자는 해당 조사ㆍ열람을 거부할 정당한 사유가 있을 때에는 그 사유를 소명하고 조사\nㆍ열람에 따르지 아니할 수 있다.<신설 2023. 3. 14.>\n③ 제2항에 따른 조사ㆍ열람을 하는 위원 또는 공무원은 그 권한을 표시하는 증표를 지니고 이를 관계인에게 내보\n여야 한다.<신설 2023. 3. 14.>\n④ 분쟁조정위원회는 분쟁의 조정을 위하여 필요하다고 인정하면 관계 기관 등에 자료 또는 의견의 제출 등 필요한\n협조를 요청할 수 있다.<신설 2023. 3. 14.>\n⑤ 분쟁조정위원회는 필요하다고 인정하면 분쟁당사자나 참고인을 위원회에 출석하도록 하여 그 의견을 들을 수\n있다.<개정 2023. 3. 14.>\n[제목개정 2023. 3. 14.]']
# gi : 75, g : [85]
# ['제45조의2(진술의 원용 제한) 조정절차에서의 의견과 진술은 소송(해당 조정에 대한 준재심은 제외한다)에서 원용(援用\n)하지 못한다.\n[본조신설 2023. 3. 14.]']
# gi : 76, g : [86]
# ['제46조(조정 전 합의 권고) 분쟁조정위원회는 제43조제1항에 따라 분쟁조정 신청을 받았을 때에는 당사자에게 그 내용\n을 제시하고 조정 전 합의를 권고할 수 있다.']
# gi : 77, g : [87]
# ['제47조(분쟁의 조정) ① 분쟁조정위원회는 다음 각 호의 어느 하나의 사항을 포함하여 조정안을 작성할 수 있다.\n1. 조사 대상 침해행위의 중지\n2. 원상회복, 손해배상, 그 밖에 필요한 구제조치\n3. 같거나 비슷한 침해의 재발을 방지하기 위하여 필요한 조치\n② 분쟁조정위원회는 제1항에 따라 조정안을 작성하면 지체 없이 각 당사자에게 제시하여야 한다.\n③ 제2항에 따라 조정안을 제시받은 당사자가 제시받은 날부터 15일 이내에 수락 여부를 알리지 아니하면 조정을\n수락한 것으로 본다.<개정 2023. 3. 14.>\n④ 당사자가 조정내용을 수락한 경우(제3항에 따라 수락한 것으로 보는 경우를 포함한다) 분쟁조정위원회는 조정서\n를 작성하고, 분쟁조정위원회의 위원장과 각 당사자가 기명날인 또는 서명을 한 후 조정서 정본을 지체 없이 각 당\n사자 또는 그 대리인에게 송달하여야 한다. 다만, 제3항에 따라 수락한 것으로 보는 경우에는 각 당사자의 기명날인\n및 서명을 생략할 수 있다.<개정 2023. 3. 14.>\n⑤ 제4항에 따른 조정의 내용은 재판상 화해와 동일한 효력을 갖는다.']
# gi : 78, g : [88]
# ['제48조(조정의 거부 및 중지) ① 분쟁조정위원회는 분쟁의 성질상 분쟁조정위원회에서 조정하는 것이 적합하지 아니하\n다고 인정하거나 부정한 목적으로 조정이 신청되었다고 인정하는 경우에는 그 조정을 거부할 수 있다. 이 경우 조정\n거부의 사유 등을 신청인에게 알려야 한다.\n② 분쟁조정위원회는 신청된 조정사건에 대한 처리절차를 진행하던 중에 한 쪽 당사자가 소를 제기하면 그 조정의\n처리를 중지하고 이를 당사자에게 알려야 한다.']
# gi : 79, g : [89]
# ['제49조(집단분쟁조정) ① 국가 및 지방자치단체, 개인정보 보호단체 및 기관, 정보주체, 개인정보처리자는 정보주체의\n피해 또는 권리침해가 다수의 정보주체에게 같거나 비슷한 유형으로 발생하는 경우로서 대통령령으로 정하는 사건\n에 대하여는 분쟁조정위원회에 일괄적인 분쟁조정(이하 “집단분쟁조정”이라 한다)을 의뢰 또는 신청할 수 있다.\n② 제1항에 따라 집단분쟁조정을 의뢰받거나 신청받은 분쟁조정위원회는 그 의결로써 제3항부터 제7항까지의 규\n정에 따른 집단분쟁조정의 절차를 개시할 수 있다. 이 경우 분쟁조정위원회는 대통령령으로 정하는 기간 동안 그 절\n차의 개시를 공고하여야 한다.\n③ 분쟁조정위원회는 집단분쟁조정의 당사자가 아닌 정보주체 또는 개인정보처리자로부터 그 분쟁조정의 당사자\n에 추가로 포함될 수 있도록 하는 신청을 받을 수 있다.\n④ 분쟁조정위원회는 그 의결로써 제1항 및 제3항에 따른 집단분쟁조정의 당사자 중에서 공동의 이익을 대표하기\n에 가장 적합한 1인 또는 수인을 대표당사자로 선임할 수 있다.\n⑤ 분쟁조정위원회는 개인정보처리자가 분쟁조정위원회의 집단분쟁조정의 내용을 수락한 경우에는 집단분쟁조정\n의 당사자가 아닌 자로서 피해를 입은 정보주체에 대한 보상계획서를 작성하여 분쟁조정위원회에 제출하도록 권고\n할 수 있다.\n⑥ 제48조제2항에도 불구하고 분쟁조정위원회는 집단분쟁조정의 당사자인 다수의 정보주체 중 일부의 정보주체가\n법원에 소를 제기한 경우에는 그 절차를 중지하지 아니하고, 소를 제기한 일부의 정보주체를 그 절차에서 제외한다.\n⑦ 집단분쟁조정의 기간은 제2항에 따른 공고가 종료된 날의 다음 날부터 60일 이내로 한다. 다만, 부득이한 사정이\n있는 경우에는 분쟁조정위원회의 의결로 처리기간을 연장할 수 있다.\n⑧ 집단분쟁조정의 절차 등에 관하여 필요한 사항은 대통령령으로 정한다.']
# gi : 80, g : [90]
# ['제50조(조정절차 등) ① 제43조부터 제49조까지의 규정에서 정한 것 외에 분쟁의 조정방법, 조정절차 및 조정업무의 처\n리 등에 필요한 사항은 대통령령으로 정한다.\n② 분쟁조정위원회의 운영 및 분쟁조정 절차에 관하여 이 법에서 규정하지 아니한 사항에 대하여는 「민사조정법」\n을 준용한다.']
# gi : 81, g : [91]
# ['제50조의2(개선의견의 통보) 분쟁조정위원회는 소관 업무 수행과 관련하여 개인정보 보호 및 정보주체의 권리 보호를\n위한 개선의견을 보호위원회 및 관계 중앙행정기관의 장에게 통보할 수 있다.\n[본조신설 2023. 3. 14.]']
# gi : 82, g : [92]
# ['제51조(단체소송의 대상 등) 다음 각 호의 어느 하나에 해당하는 단체는 개인정보처리자가 제49조에 따른 집단분쟁조\n정을 거부하거나 집단분쟁조정의 결과를 수락하지 아니한 경우에는 법원에 권리침해 행위의 금지ㆍ중지를 구하는\n소송(이하 “단체소송”이라 한다)을 제기할 수 있다.\n1. 「소비자기본법」 제29조에 따라 공정거래위원회에 등록한 소비자단체로서 다음 각 목의 요건을 모두 갖춘 단체\n가. 정관에 따라 상시적으로 정보주체의 권익증진을 주된 목적으로 하는 단체일 것\n나. 단체의 정회원수가 1천명 이상일 것\n다. 「소비자기본법」 제29조에 따른 등록 후 3년이 경과하였을 것\n2. 「비영리민간단체 지원법」 제2조에 따른 비영리민간단체로서 다음 각 목의 요건을 모두 갖춘 단체\n가. 법률상 또는 사실상 동일한 침해를 입은 100명 이상의 정보주체로부터 단체소송의 제기를 요청받을 것\n나. 정관에 개인정보 보호를 단체의 목적으로 명시한 후 최근 3년 이상 이를 위한 활동실적이 있을 것\n다. 단체의 상시 구성원수가 5천명 이상일 것\n라. 중앙행정기관에 등록되어 있을 것']
# gi : 83, g : [93]
# ['제52조(전속관할) ① 단체소송의 소는 피고의 주된 사무소 또는 영업소가 있는 곳, 주된 사무소나 영업소가 없는 경우\n에는 주된 업무담당자의 주소가 있는 곳의 지방법원 본원 합의부의 관할에 전속한다.\n② 제1항을 외국사업자에 적용하는 경우 대한민국에 있는 이들의 주된 사무소ㆍ영업소 또는 업무담당자의 주소에\n따라 정한다.']
# gi : 84, g : [94]
# ['제53조(소송대리인의 선임) 단체소송의 원고는 변호사를 소송대리인으로 선임하여야 한다.']
# gi : 85, g : [95]
# ['제54조(소송허가신청) ① 단체소송을 제기하는 단체는 소장과 함께 다음 각 호의 사항을 기재한 소송허가신청서를 법\n원에 제출하여야 한다.\n1. 원고 및 그 소송대리인\n2. 피고\n3. 정보주체의 침해된 권리의 내용\n② 제1항에 따른 소송허가신청서에는 다음 각 호의 자료를 첨부하여야 한다.\n1. 소제기단체가 제51조 각 호의 어느 하나에 해당하는 요건을 갖추고 있음을 소명하는 자료\n2. 개인정보처리자가 조정을 거부하였거나 조정결과를 수락하지 아니하였음을 증명하는 서류']
# gi : 86, g : [96]
# ['제55조(소송허가요건 등) ① 법원은 다음 각 호의 요건을 모두 갖춘 경우에 한하여 결정으로 단체소송을 허가한다.\n1. 개인정보처리자가 분쟁조정위원회의 조정을 거부하거나 조정결과를 수락하지 아니하였을 것\n2. 제54조에 따른 소송허가신청서의 기재사항에 흠결이 없을 것\n② 단체소송을 허가하거나 불허가하는 결정에 대하여는 즉시항고할 수 있다.']
# gi : 87, g : [97]
# ['제56조(확정판결의 효력) 원고의 청구를 기각하는 판결이 확정된 경우 이와 동일한 사안에 관하여는 제51조에 따른 다\n른 단체는 단체소송을 제기할 수 없다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 그러하지 아니하다.\n1. 판결이 확정된 후 그 사안과 관련하여 국가ㆍ지방자치단체 또는 국가ㆍ지방자치단체가 설립한 기관에 의하여 새\n로운 증거가 나타난 경우\n2. 기각판결이 원고의 고의로 인한 것임이 밝혀진 경우']
# gi : 88, g : [98]
# ['제57조(「민사소송법」의 적용 등) ① 단체소송에 관하여 이 법에 특별한 규정이 없는 경우에는 「민사소송법」을 적용한\n다.\n② 제55조에 따른 단체소송의 허가결정이 있는 경우에는 「민사집행법」 제4편에 따른 보전처분을 할 수 있다.\n③ 단체소송의 절차에 관하여 필요한 사항은 대법원규칙으로 정한다.']
# gi : 89, g : [99]
# ['제58조(적용의 일부 제외) ① 다음 각 호의 어느 하나에 해당하는 개인정보에 관하여는']
# gi : 90, g : [100, np.int64(101), np.int64(104)]
# ['제70조(벌칙) 다음 각 호의 어느 하나에 해당하는 자는 10년 이하의 징역 또는 1억원 이하의 벌금에 처한다. <개정\n2015. 7. 24.>\n1. 공공기관의 개인정보 처리업무를 방해할 목적으로 공공기관에서 처리하고 있는 개인정보를 변경하거나 말소하\n여 공공기관의 업무 수행의 중단ㆍ마비 등 심각한 지장을 초래한 자\n2. 거짓이나 그 밖의 부정한 수단이나 방법으로 다른 사람이 처리하고 있는 개인정보를 취득한 후 이를 영리 또는\n부정한 목적으로 제3자에게 제공한 자와 이를 교사ㆍ알선한 자', '제71조(벌칙) 다음 각 호의 어느 하나에 해당하는 자는 5년 이하의 징역 또는 5천만원 이하의 벌금에 처한다. <개정\n2016. 3. 29., 2020. 2. 4., 2023. 3. 14.>\n1. 제17조제1항제2호에 해당하지 아니함에도 같은 항 제1호(제26조제8항에 따라 준용되는 경우를 포함한다)를 위\n반하여 정보주체의 동의를 받지 아니하고 개인정보를 제3자에게 제공한 자 및 그 사정을 알면서도 개인정보를 제\n공받은 자\n2. 제18조제1항ㆍ제2항, 제27조제3항 또는', '제73조(벌칙) ① 다음 각 호의 어느 하나에 해당하는 자는 2년 이하의 징역 또는 2천만원 이하의 벌금에 처한다.\n1. 제36조제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 정정ㆍ삭제 등 필요한 조치를 하지 아\n니하고 개인정보를 계속 이용하거나 이를 제3자에게 제공한 자\n2. 제37조제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 개인정보의 처리를 정지하지 아니하고\n개인정보를 계속 이용하거나 제3자에게 제공한 자\n3. 국내외에서 정당한 이유 없이 제39조의4에 따른 비밀유지명령을 위반한 자\n4. 제63조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)에 따른 자료제출 요구에 대하여 법 위반사항을 은\n폐 또는 축소할 목적으로 자료제출을 거부하거나 거짓의 자료를 제출한 자\n5. 제63조제2항(제26조제8항에 따라 준용되는 경우를 포함한다)에 따른 출입ㆍ검사 시 자료의 은닉ㆍ폐기, 접근 거\n부 또는 위조ㆍ변조 등을 통하여 조사를 거부ㆍ방해 또는 기피한 자\n② 제1항제3호의 죄는 비밀유지명령을 신청한 자의 고소가 없으면 공소를 제기할 수 없다.\n[전문개정 2023. 3. 14.]']
# gi : 91, g : [102]
# ['제28조의2(제26조제8항에 따라 준용되는 경우를 포함한다), 제19조 또\n는 제26조제5항을 위반하여 개인정보를 이용하거나 제3자에게 제공한 자 및 그 사정을 알면서도 영리 또는 부정\n한 목적으로 개인정보를 제공받은 자\n3. 제22조의2제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 법정대리인의 동의를 받지 아니하\n고 만 14세 미만인 아동의 개인정보를 처리한 자\n4. 제23조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 민감정보를 처리한 자\n5. 제24조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 고유식별정보를 처리한 자\n6. 제28조의3제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 보호위원회 또는 관계 중앙행정기\n관의 장으로부터 전문기관으로 지정받지 아니하고 가명정보를 결합한 자\n7. 제28조의3제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 전문기관의 장의 승인을 받지 아니\n하고 결합을 수행한 기관 외부로 결합된 정보를 반출하거나 이를 제3자에게 제공한 자 및 그 사정을 알면서도 영\n리 또는 부정한 목적으로 결합된 정보를 제공받은 자\n8. 제28조의5제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 특정 개인을 알아보기 위한 목적으\n로 가명정보를 처리한 자\n9. 제59조제2호를 위반하여 업무상 알게 된 개인정보를 누설하거나 권한 없이 다른 사람이 이용하도록 제공한 자\n및 그 사정을 알면서도 영리 또는 부정한 목적으로 개인정보를 제공받은 자\n10. 제59조제3호를 위반하여 다른 사람의 개인정보를 이용, 훼손, 멸실, 변경, 위조 또는 유출한 자']
# gi : 92, g : [103]
# ['제72조(벌칙) 다음 각 호의 어느 하나에 해당하는 자는 3년 이하의 징역 또는 3천만원 이하의 벌금에 처한다. <개정\n2023. 3. 14.>\n1. 제25조제5항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 고정형 영상정보처리기기의 설치 목적\n과 다른 목적으로 고정형 영상정보처리기기를 임의로 조작하거나 다른 곳을 비추는 자 또는 녹음기능을 사용한\n자\n2. 제59조제1호를 위반하여 거짓이나 그 밖의 부정한 수단이나 방법으로 개인정보를 취득하거나 개인정보 처리에\n관한 동의를 받는 행위를 한 자 및 그 사정을 알면서도 영리 또는 부정한 목적으로 개인정보를 제공받은 자\n3. 제60조를 위반하여 직무상 알게 된 비밀을 누설하거나 직무상 목적 외에 이용한 자']
# gi : 93, g : [105]
# ['제74조(양벌규정) ① 법인의 대표자나 법인 또는 개인의 대리인, 사용인, 그 밖의 종업원이 그 법인 또는 개인의 업무에\n관하여 제70조에 해당하는 위반행위를 하면 그 행위자를 벌하는 외에 그 법인 또는 개인을 7천만원 이하의 벌금에\n처한다. 다만, 법인 또는 개인이 그 위반행위를 방지하기 위하여 해당 업무에 관하여 상당한 주의와 감독을 게을리하\n지 아니한 경우에는 그러하지 아니하다.\n② 법인의 대표자나 법인 또는 개인의 대리인, 사용인, 그 밖의 종업원이 그 법인 또는 개인의 업무에 관하여 제\n71조부터 제73조까지의 어느 하나에 해당하는 위반행위를 하면 그 행위자를 벌하는 외에 그 법인 또는 개인에게도\n해당 조문의 벌금형을 과(科)한다. 다만, 법인 또는 개인이 그 위반행위를 방지하기 위하여 해당 업무에 관하여 상당\n한 주의와 감독을 게을리하지 아니한 경우에는 그러하지 아니하다.']
# gi : 94, g : [106]
# ['제74조의2(몰수ㆍ추징 등) 제70조부터 제73조까지의 어느 하나에 해당하는 죄를 지은 자가 해당 위반행위와 관련하여\n취득한 금품이나 그 밖의 이익은 몰수할 수 있으며, 이를 몰수할 수 없을 때에는 그 가액을 추징할 수 있다. 이 경우\n몰수 또는 추징은 다른 벌칙에 부가하여 과할 수 있다.\n[본조신설 2015. 7. 24.]']
# gi : 95, g : [107, np.int64(109)]
# ['제75조(과태료) ① 다음 각 호의 어느 하나에 해당하는 자에게는 5천만원 이하의 과태료를 부과한다.\n1. 제25조제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 고정형 영상정보처리기기를 설치ㆍ운\n영한 자\n2. 제25조의2제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 이동형 영상정보처리기기로 사람\n또는 그 사람과 관련된 사물의 영상을 촬영한 자\n② 다음 각 호의 어느 하나에 해당하는 자에게는 3천만원 이하의 과태료를 부과한다.\n1. 제16조제3항ㆍ제22조제5항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 재화 또는 서비스의 제\n공을 거부한 자\n2. 제20조제1항ㆍ제2항을 위반하여 정보주체에게 같은 조 제1항 각 호의 사실을 알리지 아니한 자\n3. 제20조의2제1항을 위반하여 개인정보의 이용ㆍ제공 내역이나 이용ㆍ제공 내역을 확인할 수 있는 정보시스템에\n접속하는 방법을 통지하지 아니한 자\n4. 제21조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 개인정보의 파기 등 필요한 조치를 하\n지 아니한 자\n5. 제23조제2항ㆍ제24조제3항ㆍ제25조제6항(제25조의2제4항에 따라 준용되는 경우를 포함한다)ㆍ제28조의4제1항\nㆍ', '제75조(과태료) ① 다음 각 호의 어느 하나에 해당하는 자에게는 5천만원 이하의 과태료를 부과한다.\n1. 제25조제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 고정형 영상정보처리기기를 설치ㆍ운\n영한 자\n2. 제25조의2제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 이동형 영상정보처리기기로 사람\n또는 그 사람과 관련된 사물의 영상을 촬영한 자\n② 다음 각 호의 어느 하나에 해당하는 자에게는 3천만원 이하의 과태료를 부과한다.\n1. 제16조제3항ㆍ제22조제5항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 재화 또는 서비스의 제\n공을 거부한 자\n2. 제20조제1항ㆍ제2항을 위반하여 정보주체에게 같은 조 제1항 각 호의 사실을 알리지 아니한 자\n3. 제20조의2제1항을 위반하여 개인정보의 이용ㆍ제공 내역이나 이용ㆍ제공 내역을 확인할 수 있는 정보시스템에\n접속하는 방법을 통지하지 아니한 자\n4. 제21조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 개인정보의 파기 등 필요한 조치를 하\n지 아니한 자\n5. 제23조제2항ㆍ제24조제3항ㆍ제25조제6항(제25조의2제4항에 따라 준용되는 경우를 포함한다)ㆍ제28조의4제1항\nㆍ']
# gi : 96, g : [108, np.int64(110)]
# ['제29조(제26조제8항에 따라 준용되는 경우를 포함한다)를 위반하여 안전성 확보에 필요한 조치를 하지 아니한\n자\n6. 제23조제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 민감정보의 공개 가능성 및 비공개를\n선택하는 방법을 알리지 아니한 자\n7. 제24조의2제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 주민등록번호를 처리한 자\n8. 제24조의2제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 암호화 조치를 하지 아니한 자\n9. 제24조의2제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 정보주체가 주민등록번호를 사용하\n지 아니할 수 있는 방법을 제공하지 아니한 자\n10. 제25조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 고정형 영상정보처리기기를 설치ㆍ운\n영한 자\n11. 제25조의2제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 사람 또는 그 사람과 관련된 사물\n의 영상을 촬영한 자\n12. 제26조제3항을 위반하여 정보주체에게 알려야 할 사항을 알리지 아니한 자\n13. 제28조의5제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 개인을 알아볼 수 있는 정보가 생\n성되었음에도 이용을 중지하지 아니하거나 이를 회수ㆍ파기하지 아니한 자\n14. 제28조의8제4항(제26조제8항 및 제28조의11에 따라 준용되는 경우를 포함한다)을 위반하여 보호조치를 하지\n아니한 자\n15. 제32조의2제6항을 위반하여 인증을 받지 아니하였음에도 거짓으로 인증의 내용을 표시하거나 홍보한 자\n16. 제33조제1항을 위반하여 영향평가를 하지 아니하거나 그 결과를 보호위원회에 제출하지 아니한 자\n17. 제34조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 정보주체에게 같은 항 각 호의 사실을\n알리지 아니한 자\n18. 제34조제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 보호위원회 또는 대통령령으로 정하\n는 전문기관에 신고하지 아니한 자\n19. 제35조제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 열람을 제한하거나 거절한 자\n20. 제35조의3제1항에 따른 지정을 받지 아니하고 같은 항 제2호의 업무를 수행한 자\n21. 제35조의3제3항을 위반한 자\n22. 제36조제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 정정ㆍ삭제 등 필요한 조치를 하지 아\n니한 자\n23. 제37조제3항 또는 제5항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 파기 등 필요한 조치를 하\n지 아니한 자\n24. 제37조의2제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 정당한 사유 없이 정보주체의 요\n구에 따르지 아니한 자\n25. 제63조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)에 따른 관계 물품ㆍ서류 등 자료를 제출하지 아니\n하거나 거짓으로 제출한 자\n26. 제63조제2항(제26조제8항에 따라 준용되는 경우를 포함한다)에 따른 출입ㆍ검사를 거부ㆍ방해 또는 기피한 자\n27. 제64조제1항에 따른 시정조치 명령에 따르지 아니한 자\n③ 다음 각 호의 어느 하나에 해당하는 자에게는 2천만원 이하의 과태료를 부과한다.\n1. 제26조제6항을 위반하여 위탁자의 동의를 받지 아니하고 제3자에게 다시 위탁한 자\n2. 제31조의2제1항을 위반하여 국내대리인을 지정하지 아니한 자\n④ 다음 각 호의 어느 하나에 해당하는 자에게는 1천만원 이하의 과태료를 부과한다.\n1. 제11조의2제2항을 위반하여 정당한 사유 없이 자료를 제출하지 아니하거나 거짓으로 제출한 자\n2. 제21조제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 개인정보를 분리하여 저장ㆍ관리하지\n아니한 자\n3. 제22조제1항부터 제3항까지(제26조제8항에 따라 준용되는 경우를 포함한다)를 위반하여 동의를 받은 자\n4. 제26조제1항을 위반하여 업무 위탁 시 같은 항 각 호의 내용이 포함된 문서로 하지 아니한 자\n5. 제26조제2항을 위반하여 위탁하는 업무의 내용과 수탁자를 공개하지 아니한 자\n6. 제27조제1항ㆍ제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 정보주체에게 개인정보의 이전\n사실을 알리지 아니한 자\n7. 제28조의4제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 관련 기록을 작성하여 보관하지 아\n니한 자\n8. 제30조제1항 또는 제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 개인정보 처리방침을 정하\n지 아니하거나 이를 공개하지 아니한 자\n9. 제31조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 개인정보 보호책임자를 지정하지 아니\n한 자\n10. 제35조제3항ㆍ제4항, 제36조제2항ㆍ제4항 또는 제37조제4항(제26조제8항에 따라 준용되는 경우를 포함한다\n)을 위반하여 정보주체에게 알려야 할 사항을 알리지 아니한 자\n11. 제45조제1항에 따른 자료를 정당한 사유 없이 제출하지 아니하거나 거짓으로 제출한 자\n12. 제45조제2항에 따른 출입ㆍ조사ㆍ열람을 정당한 사유 없이 거부ㆍ방해 또는 기피한 자\n⑤ 제1항부터 제4항까지에 따른 과태료는 대통령령으로 정하는 바에 따라 보호위원회가 부과ㆍ징수한다. 이 경우\n보호위원회는 위반행위의 정도ㆍ동기ㆍ결과, 개인정보처리자의 규모 등을 고려하여 과태료를 감경하거나 면제할\n수 있다.\n[전문개정 2023. 3. 14.]', '제29조(제26조제8항에 따라 준용되는 경우를 포함한다)를 위반하여 안전성 확보에 필요한 조치를 하지 아니한\n자\n6. 제23조제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 민감정보의 공개 가능성 및 비공개를\n선택하는 방법을 알리지 아니한 자\n7. 제24조의2제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 주민등록번호를 처리한 자\n8. 제24조의2제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 암호화 조치를 하지 아니한 자\n9. 제24조의2제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 정보주체가 주민등록번호를 사용하\n지 아니할 수 있는 방법을 제공하지 아니한 자\n10. 제25조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 고정형 영상정보처리기기를 설치ㆍ운\n영한 자\n11. 제25조의2제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 사람 또는 그 사람과 관련된 사물\n의 영상을 촬영한 자\n12. 제26조제3항을 위반하여 정보주체에게 알려야 할 사항을 알리지 아니한 자\n13. 제28조의5제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 개인을 알아볼 수 있는 정보가 생\n성되었음에도 이용을 중지하지 아니하거나 이를 회수ㆍ파기하지 아니한 자\n14. 제28조의8제4항(제26조제8항 및 제28조의11에 따라 준용되는 경우를 포함한다)을 위반하여 보호조치를 하지\n아니한 자\n15. 제32조의2제6항을 위반하여 인증을 받지 아니하였음에도 거짓으로 인증의 내용을 표시하거나 홍보한 자\n16. 제33조제1항을 위반하여 영향평가를 하지 아니하거나 그 결과를 보호위원회에 제출하지 아니한 자\n17. 제34조제1항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 정보주체에게 같은 항 각 호의 사실을\n알리지 아니한 자\n18. 제34조제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 보호위원회 또는 대통령령으로 정하\n는 전문기관에 신고하지 아니한 자\n19. 제35조제3항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 열람을 제한하거나 거절한 자\n20. 제35조의3제1항에 따른 지정을 받지 아니하고 같은 항 제2호의 업무를 수행한 자\n21. 제35조의3제3항을 위반한 자\n22. 제36조제2항(제26조제8항에 따라 준용되는 경우를 포함한다)을 위반하여 정정ㆍ삭제 등 필요한 조치를 하지 아\n니한 자\n23. 제37조제3항 또는 제5항(제26조제8항에 따라 준용되는 경우를 ...
# gi : 97, g : [111]
# ['제76조(과태료에 관한 규정 적용의 특례) 제75조의 과태료에 관한 규정을 적용할 때 제64조의2에 따라 과징금을 부과\n한 행위에 대하여는 과태료를 부과할 수 없다. <개정 2023. 3. 14.>\n[본조신설 2013. 8. 6.]']

# %%
print(type(gtexts[2]))
# Out:
# <class 'list'>

# %%
joined = "\n---\n".join(gtexts[2])
print(len(joined))
# Out:
# 726

# %%
from typing import TypedDict, List, Dict, Any

class State(TypedDict):
    intent: str           # "ingest" | "ask" | "compare"
    user_input: str
    file_path: str | None
    doc_id: str | None
    blueprint: Dict
    units: List[Dict]
    texts: List[str]
    embeddings: Any
    groups: List[List[int]]
    distilled: List[Dict]
    entities: List[Dict]
    relations: List[Dict]
    merged_entities: List[Dict]
    version: int | None
    answer: str | None
    diff_report: Dict | None
    contexts: List[str]

import json
from pathlib import Path

json_file_path = Path('../../configs/blueprint.json')

# 5. 파일을 열고 json.load()를 사용해 파이썬 dict로 변환합니다.
try:
    with open(json_file_path, 'r', encoding='utf-8') as f:
        blueprint = json.load(f)
    
    # 결과 출력
    print("성공적으로 파일을 불러왔습니다.")
    print(blueprint)
    # print(type(data_dict)) # <class 'dict'>

except FileNotFoundError:
    print(f"오류: 파일을 찾을 수 없습니다. 경로: {json_file_path}")


distilled = distill_group(blueprint, gtexts[1])
ents = extract_entities(distilled)["entities"]
rels = extract_relations(distilled, {"entities":ents})["relations"]
# Out:
# 성공적으로 파일을 불러왔습니다.
# {'doc_type': 'regulation', 'title': None, 'authority': None, 'effective_date': None, 'amendments': [{'date': None, 'summary': None}], 'articles': [{'no': None, 'heading': None, 'text': None, 'definitions': [], 'applicability': [], 'exceptions': [], 'penalties': [], 'references': []}]}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 42
#      38     print(f"오류: 파일을 찾을 수 없습니다. 경로: {json_file_path}")
#      41 distilled = distill_group(blueprint, gtexts[1])
# ---> 42 ents = extract_entities(distilled)["entities"]
#      43 rels = extract_relations(distilled, {"entities":ents})["relations"]
#
# Cell In[131], line 158, in extract_entities(distilled)
#     154 def extract_entities(distilled: dict) -> dict:
#     155     """
#     156     증류 결과(distilled JSON)를 기반으로 '고유 개념' 엔터티 목록만 추출.
#     157     """
# --> 158     out: Entities = _entities_chain.invoke(
#     159         {"distilled": json.dumps(distilled, ensure_ascii=False)}
#     160     )
#     161     return out.model_dump()
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:3080, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3078 with set_config_context(config) as context:
#    3079     if i == 0:
# -> 3080         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3081     else:
#    3082         input_ = context.run(step.invoke, input_, config)
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/prompts/base.py:216, in BasePromptTemplate.invoke(self, input, config, **kwargs)
#     214 if self.tags:
#     215     config["tags"] = config["tags"] + self.tags
# --> 216 return self._call_with_config(
#     217     self._format_prompt_with_error_handling,
#     218     input,
#     219     config,
#     220     run_type="prompt",
#     221     serialized=self._serialized,
#     222 )
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:1953, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    1949     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1950     with set_config_context(child_config) as context:
#    1951         output = cast(
#    1952             "Output",
# -> 1953             context.run(
#    1954                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1955                 func,
#    1956                 input_,
#    1957                 config,
#    1958                 run_manager,
#    1959                 **kwargs,
#    1960             ),
#    1961         )
#    1962 except BaseException as e:
#    1963     run_manager.on_chain_error(e)
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/runnables/config.py:429, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     427 if run_manager is not None and accepts_run_manager(func):
#     428     kwargs["run_manager"] = run_manager
# --> 429 return func(input, **kwargs)
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/prompts/base.py:189, in BasePromptTemplate._format_prompt_with_error_handling(self, inner_input)
#     188 def _format_prompt_with_error_handling(self, inner_input: dict) -> PromptValue:
# --> 189     inner_input_ = self._validate_input(inner_input)
#     190     return self.format_prompt(**inner_input_)
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/prompts/base.py:183, in BasePromptTemplate._validate_input(self, inner_input)
#     177     example_key = missing.pop()
#     178     msg += (
#     179         f"\nNote: if you intended {{{example_key}}} to be part of the string"
#     180         " and not a variable, please escape it with double curly braces like: "
#     181         f"'{{{{{example_key}}}}}'."
#     182     )
# --> 183     raise KeyError(
#     184         create_message(message=msg, error_code=ErrorCode.INVALID_PROMPT_INPUT)
#     185     )
#     186 return inner_input
#
# KeyError: 'Input to ChatPromptTemplate is missing variables {\'\\n  "id"\', \'clause_text\'}.  Expected: [\'\\n  "id"\', \'clause_text\'] Received: [\'distilled\']\nNote: if you intended {\n  "id"} to be part of the string and not a variable, please escape it with double curly braces like: \'{{\n  "id"}}\'.\nFor troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/INVALID_PROMPT_INPUT '

# %%
rels = extract_relations(distilled, {"entities":ents})["relations"]

# %%
print(ents)
# Out:
# [{'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e5', 'canonical': '과학적 연구', 'aliases': ['과학적 연구', 'scientific research', 'scientific inquiry'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e6', 'canonical': '개인정보', 'aliases': ['개인정보', 'personal information', 'personal data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e7', 'canonical': '정보주체', 'aliases': ['정보주체', 'information subject', 'data subject'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e8', 'canonical': '개인정보 파일', 'aliases': ['개인정보 파일', 'personal information file', 'personal data file'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e9', 'canonical': '개인정보 처리자', 'aliases': ['개인정보 처리자', 'personal information processor', 'personal data processor'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e10', 'canonical': '고정형 영상정보처리기기', 'aliases': ['고정형 영상정보처리기기', 'fixed video information processing device', 'fixed video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e11', 'canonical': '휴대형 영상정보처리기기', 'aliases': ['휴대형 영상정보처리기기', 'portable video information processing device', 'portable video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e12', 'canonical': '중앙행정기관', 'aliases': ['중앙행정기관', 'central administrative agencies', 'central government agencies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e13', 'canonical': '지방자치단체', 'aliases': ['지방자치단체', 'local governments', 'local administrative bodies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e14', 'canonical': '공공기관', 'aliases': ['공공기관', 'public institution', 'public body'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e15', 'canonical': '영상정보', 'aliases': ['영상정보', 'video information', 'video data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e17', 'canonical': '정보의 생성', 'aliases': ['정보의 생성', 'creation', 'data generation'], 'type': '행위', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e19', 'canonical': '정보의 연계', 'aliases': ['정보의 연계', 'linkage', 'data linkage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e20', 'canonical': '정보의 기록', 'aliases': ['정보의 기록', 'recording', 'data recording'], 'type': '행위', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e21', 'canonical': '정보의 저장', 'aliases': ['정보의 저장', 'storage', 'data storage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e22', 'canonical': '정보의 보유', 'aliases': ['정보의 보유', 'retention', 'data retention'], 'type': '행위', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e23', 'canonical': '정보의 처리', 'aliases': ['정보의 처리', 'processing', 'data processing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2'], 'evidence': ['...']}, {'id': 'e24', 'canonical': '정보의 편집', 'aliases': ['정보의 편집', 'editing', 'data editi ...

# %%
rels
# Out:
# [{'subject': '개인정보 보호법',
#   'predicate': '정의한다',
#   'object': '가명정보의 처리',
#   'evidence': '제28조의2(가명정보의 처리) ① 개인정보처리자는 통계작성, 과학적 연구, 공익적 기록보존 등을 위하여 정보주체의 동의 없이 가명정보를 처리할 수 있다.'},
#  {'subject': '개인정보 보호법',
#   'predicate': '허용한다',
#   'object': '가명정보의 처리',
#   'evidence': '① 개인정보처리자는 통계작성, 과학적 연구, 공익적 기록보존 등을 위하여 정보주체의 동의 없이 가명정보를 처리할 수 있다.'},
#  {'subject': '개인정보 보호법',
#   'predicate': '포함한다',
#   'object': '고정형 영상정보처리기기',
#   'evidence': '7. Fixed video information processing device means a device installed in a specific space that continuously or periodically captures images of people or objects, or transmits them through wired or wireless networks, as specified by Presidential Decree.'},
#  {'subject': '개인정보 보호법',
#   'predicate': '포함한다',
#   'object': '휴대형 영상정보처리기기',
#   'evidence': '7-2. Portable video information processing device means a device that can capture images of people or objects when worn or carried by a person, or attached or placed on a movable object, and transmits them through wired or wireless networks, as specified by Presidential Decree.'},
#  {'subject': '개인정보 보호법',
#   'predicate': '포함한다',
#   'object': '중앙행정기관',
#   'evidence': '6. Public institution means the following agencies: a. Agencies handling administrative affairs of the National Assembly, the courts, the Constitutional Court, the National Election Commission, central administrative agencies (including agencies under the President and the Prime Minister) and their subordinate agencies, and local governments'},
#  {'subject': '개인정보 보호법',
#   'predicate': '포함한다',
#   'object': '지방자치단체',
#   'evidence': '6. Public institution means the following agencies: a. Agencies handling administrative affairs of the National Assembly, the courts, the Constitutional Court, the National Election Commission, central administrative agencies (including agencies under the President and the Prime Minister) and their subordinate agencies, and local governments'},
#  {'subject': '개인정보 보호법',
#   'predicate': '포함한다',
#   'object': '공공기관',
#   'evidence': '6. Public institution means the following agencies:'}]

# %%
for e in ents:
    print(e)
for r in rels:
    print(type(r['evidence']))
# Out:
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e5', 'canonical': '과학적 연구', 'aliases': ['과학적 연구', 'scientific research', 'scientific inquiry'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e6', 'canonical': '개인정보', 'aliases': ['개인정보', 'personal information', 'personal data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e7', 'canonical': '정보주체', 'aliases': ['정보주체', 'information subject', 'data subject'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e8', 'canonical': '개인정보 파일', 'aliases': ['개인정보 파일', 'personal information file', 'personal data file'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e9', 'canonical': '개인정보 처리자', 'aliases': ['개인정보 처리자', 'personal information processor', 'personal data processor'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e10', 'canonical': '고정형 영상정보처리기기', 'aliases': ['고정형 영상정보처리기기', 'fixed video information processing device', 'fixed video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e11', 'canonical': '휴대형 영상정보처리기기', 'aliases': ['휴대형 영상정보처리기기', 'portable video information processing device', 'portable video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e12', 'canonical': '중앙행정기관', 'aliases': ['중앙행정기관', 'central administrative agencies', 'central government agencies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e13', 'canonical': '지방자치단체', 'aliases': ['지방자치단체', 'local governments', 'local administrative bodies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e14', 'canonical': '공공기관', 'aliases': ['공공기관', 'public institution', 'public body'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e15', 'canonical': '영상정보', 'aliases': ['영상정보', 'video information', 'video data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e17', 'canonical': '정보의 생성', 'aliases': ['정보의 생성', 'creation', 'data generation'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e19', 'canonical': '정보의 연계', 'aliases': ['정보의 연계', 'linkage', 'data linkage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e20', 'canonical': '정보의 기록', 'aliases': ['정보의 기록', 'recording', 'data recording'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e21', 'canonical': '정보의 저장', 'aliases': ['정보의 저장', 'storage', 'data storage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e22', 'canonical': '정보의 보유', 'aliases': ['정보의 보유', 'retention', 'data retention'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e23', 'canonical': '정보의 처리', 'aliases': ['정보의 처리', 'processing', 'data processing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e24', 'canonical': '정보의 편집', 'aliases': ['정보의 편집', 'editing', 'data editing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e25', 'canonical': '정보의 검색', 'aliases': ['정보의 검색', 'search', 'data search'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e26', 'canonical': '정보의 출력', 'aliases': ['정보의 출력', 'output', 'data output'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1'], 'evidence': ['...']}
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
gi = 1
all_e, all_r = [], []
for e in ents:
    e.setdefault("id", f"e_{len(all_e)+1}")
    e.setdefault("source",[]).append(f"group:{gi}")
for r in rels: 
    r.setdefault("group",[]).append(f"group:{gi}")
all_e.extend(ents); all_r.extend(rels)
# merged = judge.merge_entities(all_e)

# %%
all_e
# Out:
# [{'id': 'e1',
#   'canonical': '개인정보 보호법',
#   'aliases': ['개보법', 'Privacy Act'],
#   'type': '법률',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e2',
#   'canonical': '제28조의2',
#   'aliases': ['가명정보의 처리'],
#   'type': '조문',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e3',
#   'canonical': '가명정보',
#   'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e4',
#   'canonical': '가명처리',
#   'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e5',
#   'canonical': '과학적 연구',
#   'aliases': ['과학적 연구', 'scientific research', 'scientific inquiry'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e6',
#   'canonical': '개인정보',
#   'aliases': ['개인정보', 'personal information', 'personal data'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e7',
#   'canonical': '정보주체',
#   'aliases': ['정보주체', 'information subject', 'data subject'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e8',
#   'canonical': '개인정보 파일',
#   'aliases': ['개인정보 파일', 'personal information file', 'personal data file'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e9',
#   'canonical': '개인정보 처리자',
#   'aliases': ['개인정보 처리자',
#    'personal information processor',
#    'personal data processor'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e10',
#   'canonical': '고정형 영상정보처리기기',
#   'aliases': ['고정형 영상정보처리기기',
#    'fixed video information processing device',
#    'fixed video surveillance device'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e11',
#   'canonical': '휴대형 영상정보처리기기',
#   'aliases': ['휴대형 영상정보처리기기',
#    'portable video information processing device',
#    'portable video surveillance device'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e12',
#   'canonical': '중앙행정기관',
#   'aliases': ['중앙행정기관',
#    'central administrative agencies',
#    'central government agencies'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e13',
#   'canonical': '지방자치단체',
#   'aliases': ['지방자치단체', 'local governments', 'local administrative bodies'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e14',
#   'canonical': '공공기관',
#   'aliases': ['공공기관', 'public institution', 'public body'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e15',
#   'canonical': '영상정보',
#   'aliases': ['영상정보', 'video information', 'video data'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e16',
#   'canonical': '정보의 수집',
#   'aliases': ['정보의 수집', 'collection', 'data collection'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e17',
#   'canonical': '정보의 생성',
#   'aliases': ['정보의 생성', 'creation', 'data generation'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e18',
#   'canonical': '정보의 결합',
#   'aliases': ['정보의 결합', 'connection', 'data connection'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e19',
#   'canonical': '정보의 연계',
#   'aliases': ['정보의 연계', 'linkage', 'data linkage'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e20',
#   'canonical': '정보의 기록',
#   'aliases': ['정보의 기록', 'recording', 'data recording'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e21',
#   'canonical': '정보의 저장',
#   'aliases': ['정보의 저장', 'storage', 'data storage'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e22',
#   'canonical': '정보의 보유',
#   'aliases': ['정보의 보유', 'retention', 'data retention'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e23',
#   'canonical': '정보의 처리',
#   'aliases': ['정보의 처리', 'processing', 'data processing'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e24',
#   'canonical': '정보의 편집',
#   'aliases': ['정보의 편집', 'editing', 'data editing'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e25',
#   'canonical': '정보의 검색',
#   'aliases': ['정보의 검색', 'search', 'data search'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e26',
#   'canonical': '정보의 출력',
#   'aliases': ['정보의 출력', 'output', 'data output'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e27',
#   'canonical': '정보의 정정',
#   'aliases': ['정보의 정정', 'correction', 'data correction'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e28',
#   'canonical': '정보의 복구',
#   'aliases': ['정보의 복구', 'recovery', 'data recovery'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e29',
#   'canonical': '정보의 이용',
#   'aliases': ['정보의 이용', 'use', 'data utilization'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e30',
#   'canonical': '정보의 제공',
#   'aliases': ['정보의 제공', 'provision', 'data provision'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e31',
#   'canonical': '정보의 공개',
#   'aliases': ['정보의 공개', 'disclosure', 'data disclosure'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e32',
#   'canonical': '정보의 파기',
#   'aliases': ['정보의 파기', 'destruction', 'data destruction'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e33',
#   'canonical': '유사행위',
#   'aliases': ['유사행위', 'other similar acts', 'analogous acts'],
#   'type': '행위',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e34',
#   'canonical': '주민등록번호',
#   'aliases': ['주민등록번호',
#    'resident registration number',
#    'resident registration ID'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']},
#  {'id': 'e35',
#   'canonical': '이미지',
#   'aliases': ['이미지', 'images', 'visual data'],
#   'type': '용어',
#   'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#   'evidence': ['...']}]

# %%
distilled2 = distill_group(blueprint, gtexts[2])
ents2 = extract_entities(distilled2)["entities"]
rels2 = extract_relations(distilled2, {"entities":ents2})["relations"]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[178], line 2
#       1 distilled2 = distill_group(blueprint, gtexts[2])
# ----> 2 ents2 = extract_entities(distilled2)["entities"]
#       3 rels2 = extract_relations(distilled2, {"entities":ents2})["relations"]
#
# Cell In[162], line 149, in extract_entities(distilled)
#     145 def extract_entities(distilled: dict) -> dict:
#     146     """
#     147     증류 결과(distilled JSON)를 기반으로 '고유 개념' 엔터티 목록만 추출.
#     148     """
# --> 149     out: Entities = _entities_chain.invoke(
#     150         {"distilled": json.dumps(distilled, ensure_ascii=False)}
#     151     )
#     152     return out.model_dump()
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:3082, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3080                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3081             else:
# -> 3082                 input_ = context.run(step.invoke, input_, config)
#    3083 # finish the root run
#    3084 except BaseException as e:
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:5495, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5488 @override
#    5489 def invoke(
#    5490     self,
#    (...)
#    5493     **kwargs: Optional[Any],
#    5494 ) -> Output:
# -> 5495     return self.bound.invoke(
#    5496         input,
#    5497         self._merge_configs(config),
#    5498         **{**self.kwargs, **kwargs},
#    5499     )
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:393, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     381 @override
#     382 def invoke(
#     383     self,
#    (...)
#     388     **kwargs: Any,
#     389 ) -> BaseMessage:
#     390     config = ensure_config(config)
#     391     return cast(
#     392         "ChatGeneration",
# --> 393         self.generate_prompt(
#     394             [self._convert_input(input)],
#     395             stop=stop,
#     396             callbacks=config.get("callbacks"),
#     397             tags=config.get("tags"),
#     398             metadata=config.get("metadata"),
#     399             run_name=config.get("run_name"),
#     400             run_id=config.pop("run_id", None),
#     401             **kwargs,
#     402         ).generations[0][0],
#     403     ).message
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1019, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1010 @override
#    1011 def generate_prompt(
#    1012     self,
#    (...)
#    1016     **kwargs: Any,
#    1017 ) -> LLMResult:
#    1018     prompt_messages = [p.to_messages() for p in prompts]
# -> 1019     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:837, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     834 for i, m in enumerate(input_messages):
#     835     try:
#     836         results.append(
# --> 837             self._generate_with_cache(
#     838                 m,
#     839                 stop=stop,
#     840                 run_manager=run_managers[i] if run_managers else None,
#     841                 **kwargs,
#     842             )
#     843         )
#     844     except BaseException as e:
#     845         if run_managers:
#
# File /app/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1085, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1083     result = generate_from_stream(iter(chunks))
#    1084 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1085     result = self._generate(
#    1086         messages, stop=stop, run_manager=run_manager, **kwargs
#    1087     )
#    1088 else:
#    1089     result = self._generate(messages, stop=stop, **kwargs)
#
# File /app/.venv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1151, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1148 payload.pop("stream")
#    1149 try:
#    1150     raw_response = (
# -> 1151         self.root_client.chat.completions.with_raw_response.parse(
#    1152             **payload
#    1153         )
#    1154     )
#    1155     response = raw_response.parse()
#    1156 except openai.BadRequestError as e:
#
# File /app/.venv/lib/python3.10/site-packages/openai/_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File /app/.venv/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:183, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, safety_identifier, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     176 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     177     return _parse_chat_completion(
#     178         response_format=response_format,
#     179         chat_completion=raw_completion,
#     180         input_tools=chat_completion_tools,
#     181     )
# --> 183 return self._post(
#     184     "/chat/completions",
#     185     body=maybe_transform(
#     186         {
#     187             "messages": messages,
#     188             "model": model,
#     189             "audio": audio,
#     190             "frequency_penalty": frequency_penalty,
#     191             "function_call": function_call,
#     192             "functions": functions,
#     193             "logit_bias": logit_bias,
#     194             "logprobs": logprobs,
#     195             "max_completion_tokens": max_completion_tokens,
#     196             "max_tokens": max_tokens,
#     197             "metadata": metadata,
#     198             "modalities": modalities,
#     199             "n": n,
#     200             "parallel_tool_calls": parallel_tool_calls,
#     201             "prediction": prediction,
#     202             "presence_penalty": presence_penalty,
#     203             "prompt_cache_key": prompt_cache_key,
#     204             "reasoning_effort": reasoning_effort,
#     205             "response_format": _type_to_response_format(response_format),
#     206             "safety_identifier": safety_identifier,
#     207             "seed": seed,
#     208             "service_tier": service_tier,
#     209             "stop": stop,
#     210             "store": store,
#     211             "stream": False,
#     212             "stream_options": stream_options,
#     213             "temperature": temperature,
#     214             "tool_choice": tool_choice,
#     215             "tools": tools,
#     216             "top_logprobs": top_logprobs,
#     217             "top_p": top_p,
#     218             "user": user,
#     219             "verbosity": verbosity,
#     220             "web_search_options": web_search_options,
#     221         },
#     222         completion_create_params.CompletionCreateParams,
#     223     ),
#     224     options=make_request_options(
#     225         extra_headers=extra_headers,
#     226         extra_query=extra_query,
#     227         extra_body=extra_body,
#     228         timeout=timeout,
#     229         post_parser=parser,
#     230     ),
#     231     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     232     # in the `parser` function above
#     233     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     234     stream=False,
#     235 )
#
# File /app/.venv/lib/python3.10/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /app/.venv/lib/python3.10/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /app/.venv/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /app/.venv/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /app/.venv/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /app/.venv/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /app/.venv/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /app/.venv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /app/.venv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /app/.venv/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /app/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /app/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /app/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /app/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /app/.venv/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
gi = 2
for e in ents2:
    e.setdefault("id", f"e_{len(all_e)+1}")
    e.setdefault("source",[]).append(f"group:{gi}")
for r in rels2: r.setdefault("group",[]).append(f"group:{gi}")
all_e.extend(ents2); all_r.extend(rels2)

# %%
len(all_e)
# Out:
# 2

# %%
all_r
# Out:
# [{'s': 'Personal information',
#   'p': 'refers to',
#   'o': 'information about living individuals',
#   'evidence': ['Personal information refers to information about living individuals that falls under any of the following categories:',
#    'group:1']},
#  {'s': 'Processing',
#   'p': 'means',
#   'o': 'the collection, generation, connection, integration, recording, storage, retention, processing, editing, retrieval, output, correction, recovery, use, provision, disclosure, destruction, and other similar actions regarding personal information',
#   'evidence': ['Processing means the collection, generation, connection, integration, recording, storage, retention, processing, editing, retrieval, output, correction, recovery, use, provision, disclosure, destruction, and other similar actions regarding personal information.']},
#  {'s': 'Data subject',
#   'p': 'is a person',
#   'o': 'who can be identified from the processed information and is the subject of that information',
#   'evidence': ['A data subject is a person who can be identified from the processed information and is the subject of that information.',
#    'group:1']},
#  {'s': 'Personal information file',
#   'p': 'refers to',
#   'o': 'a collection of personal information that is systematically arranged or organized to facilitate easy search',
#   'evidence': ['A personal information file refers to a collection of personal information that is systematically arranged or organized to facilitate easy search.',
#    'group:1']},
#  {'s': 'Personal information processor',
#   'p': 'refers to',
#   'o': 'public institutions, corporations, organizations, and individuals, etc., that process personal information for business purposes, either directly or through others, to operate personal information files',
#   'evidence': ['A personal information processor refers to public institutions, corporations, organizations, and individuals, etc., that process personal information for business purposes, either directly or through others, to operate personal information files.',
#    'group:1']},
#  {'s': 'Public institution',
#   'p': 'includes',
#   'o': 'a) Institutions handling administrative affairs of the National Assembly, the courts, the Constitutional Court, and the National Election Commission; central administrative agencies (including those under the President and the Prime Minister) and their affiliated organizations; local governments; b) Other national institutions and public organizations specified by Presidential Decree',
#   'evidence': ['Public institutions include: a) Institutions handling administrative affairs of the National Assembly, the courts, the Constitutional Court, and the National Election Commission; central administrative agencies (including those under the President and the Prime Minister) and their affiliated organizations; local governments; b) Other national institutions and public organizations specified by Presidential Decree.',
#    'group:1']},
#  {'s': 'Fixed video information processing device',
#   'p': 'refers to',
#   'o': 'a device installed in a certain space that continuously or periodically captures images of people or objects, or transmits them through wired or wireless networks, as specified by Presidential Decree',
#   'evidence': ['A fixed video information processing device refers to a device installed in a certain space that continuously or periodically captures images of people or objects, or transmits them through wired or wireless networks, as specified by Presidential Decree.',
#    'group:1']},
#  {'s': 'Mobile video information processing device',
#   'p': 'refers to',
#   'o': 'a device that is worn, carried by a person, or attached or placed on a movable object to capture images of people or objects, or transmit them through wired or wireless networks, as specified by Presidential Decree',
#   'evidence': ['A mobile video information processing device refers to a device that is worn, carried by a person, or attached or placed on a movable object to capture images of people or objects, or transmit them through wired or wireless networks, as specified by Presidential Decree.',
#    'group:1']},
#  {'s': 'Scientific research',
#   'p': 'refers to',
#   'o': 'research that applies scientific methods, including technology development and demonstration, basic research, applied research, and privately funded research',
#   'evidence': ['Scientific research refers to research that applies scientific methods, including technology development and demonstration, basic research, applied research, and privately funded research.',
#    'group:1']},
#  {'s': 'personal data processors',
#   'p': 'must clearly define',
#   'o': 'purpose of personal data processing',
#   'evidence': ['Personal data processors must clearly define the purpose of personal data processing and collect only the minimum necessary personal data legally and justly within the required scope.',
#    'group:2']},
#  {'s': 'personal data processors',
#   'p': 'process',
#   'o': 'personal data appropriately',
#   'evidence': ['Personal data processors must process personal data appropriately within the scope needed for the purpose and shall not use it for purposes other than the stated one.',
#    'group:2']},
#  {'s': 'personal data processors',
#   'p': 'ensure',
#   'o': 'accuracy, completeness, and up-to-dateness of personal data',
#   'evidence': ['Personal data processors must ensure accuracy, completeness, and up-to-dateness of personal data within the scope needed for the purpose.',
#    'group:2']},
#  {'s': 'personal data processors',
#   'p': 'safely manage',
#   'o': 'personal data',
#   'evidence': ['Personal data processors must safely manage personal data considering the possibility and degree of risk of rights infringement of data subjects based on the method and type of personal data processing.',
#    'group:2']},
#  {'s': 'personal data processors',
#   'p': 'disclose',
#   'o': 'matters related to personal data processing',
#   'evidence': ['Personal data processors must disclose matters related to personal data processing, such as personal data processing policies, and guarantee the rights of data subjects, including the right to access.',
#    'group:2']},
#  {'s': 'personal data processors',
#   'p': 'process',
#   'o': 'personal data',
#   'evidence': ['Personal data processors must process personal data in a way that minimizes the invasion of privacy of data subjects.',
#    'group:2']},
#  {'s': 'personal data processors',
#   'p': 'process',
#   'o': 'personal data anonymously or pseudonymously',
#   'evidence': ['When personal data can be collected for the purpose with anonymization or pseudonymization, it should be processed anonymously; if anonymization cannot achieve the purpose, it should be processed pseudonymously.',
#    'group:2']},
#  {'s': 'personal data processors',
#   'p': 'strive',
#   'o': 'gain trust of data subjects',
#   'evidence': ['Personal data processors must strive to gain the trust of data subjects by complying with and practicing the responsibilities and obligations stipulated in this Act and related laws.',
#    'group:2']}]

# %%
# app/components/judge.py
from __future__ import annotations
import os, itertools, json
from typing import List, Dict, Type
from pydantic import BaseModel, Field
from rapidfuzz import fuzz

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# ---------------------------
# 1) 온프레미스 LLM (llama-server OpenAI 호환)
# ---------------------------

BASE_URL = "http://host.docker.internal:8080/v1" 

llm = ChatOpenAI(
    model="Midm-2.0-Base-Instruct-q4_0",           # 서버에서 인식 가능한 임의의 모델명
    base_url=BASE_URL,
    api_key="sk-local-anything", # 의미없는 토큰도 OK
    temperature=0.0,
    max_tokens=8192               # 서버 토큰 제한 고려
)

# ---------------------------
# 2) 구조화 출력 스키마 (Pydantic)
# ---------------------------
class JudgeVerdict(BaseModel):
    same: bool = Field(..., description="True if two entities are the same concept")
    why: str | None = Field(default=None, description="Short rationale")

# ---------------------------
# 3) 체인(LCEL): Prompt → LLM(structured)
# ---------------------------
JUDGE_SYS = (
    "You are a strict entity-equivalence judge for a regulatory knowledge graph. "
    "Decide if two entity records denote the SAME real-world concept within this legal context. "
    "Be conservative when definitions or applicability differ."
)

JUDGE_HUMAN = """Return a compact JSON with keys exactly: same (bool), why (str).
A:
{a}
B:
{b}"""

def _judge_chain():
    prompt = ChatPromptTemplate.from_messages([
        ("system", JUDGE_SYS),
        ("human",  JUDGE_HUMAN),
    ])
    # 구조화 출력: Pydantic으로 강제
    return prompt | llm.with_structured_output(JudgeVerdict) # chain을 반환

# ---------------------------
# 4) 후보쌍 생성 (빠른 문자 유사도 블로킹)
# ---------------------------
def candidate_pairs(ents: List[Dict], ratio: int = 85):
    """
    문자 기반(rapidfuzz) 프리필터로 같은/유사 표기 엔티티들만 후보쌍으로 만든다.
    - ratio는 토큰정렬 유사도 기준(0~100)
    """
    pairs = []
    for a, b in itertools.combinations(ents, 2):
        scores = [fuzz.token_sort_ratio(a.get("canonical",""), b.get("canonical",""))]
        for x in a.get("aliases", []):
            for y in b.get("aliases", []):
                scores.append(fuzz.token_sort_ratio(x, y))
        if max(scores) >= ratio:
            pairs.append((a, b))
    return pairs

# ---------------------------
# 5) LLM-as-Judge (체인 사용)
# ---------------------------
def llm_equiv(a: Dict, b: Dict) -> bool:
    """
    LangChain 체인으로 llama-server에 질의 → JudgeVerdict(same, why) 구조로 수신.
    실패 시 보수적으로 False.
    """
    try:
        chain = _judge_chain()
        print(a)
        print(b)
        verdict: JudgeVerdict = chain.invoke({
            "a": json.dumps(a, ensure_ascii=False),
            "b": json.dumps(b, ensure_ascii=False),
        })
        print(bool(verdict.same))
        return bool(verdict.same)
    except Exception:
        print("---Exception---")
        return False

# ---------------------------
# 6) 병합 루프
# ---------------------------
def merge_entities(ents: List[Dict]) -> List[Dict]:
    """
    - 후보쌍(candidate_pairs)으로 블로킹
    - 체인 기반 LLM-as-Judge로 동등 개념 판단
    - 동등하면 alias/source 병합 + 대표명(canonical) 단순 규칙으로 선택
    """
    ents = ents[:]  # shallow copy
    changed = True
    while changed:
        changed = False
        for a, b in candidate_pairs(ents):
            if llm_equiv(a, b):
                # 누락 키 보정
                a.setdefault("aliases", []); b.setdefault("aliases", [])
                a.setdefault("source",  []); b.setdefault("source",  [])

                # alias 병합(원래 canonical까지 alias로 흡수)
                a["aliases"] = sorted(set(
                    a["aliases"] + [a.get("canonical",""), b.get("canonical","")] + b["aliases"]
                ))

                # 대표명 선택(간단: 더 짧은 쪽; 필요시 규칙 고도화)
                if a.get("canonical") and b.get("canonical"):
                    a["canonical"] = min([a["canonical"], b["canonical"]], key=len)
                else:
                    a["canonical"] = a.get("canonical") or b.get("canonical")

                # source 병합
                a["source"] = sorted(set(a["source"] + b["source"]))

                # 타입/정의 충돌 등은 필요시 추가 규칙으로 조정
                # 예: a["type"] 우선, 없으면 b["type"] 채우기
                if not a.get("type") and b.get("type"):
                    a["type"] = b["type"]

                # b 제거 후 다시 루프 시작
                ents.remove(b)
                changed = True
                break
    return ents

# %%
for a, b in itertools.combinations(all_e, 2):
    print(a)
    print(b)
# Out:
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e5', 'canonical': '과학적 연구', 'aliases': ['과학적 연구', 'scientific research', 'scientific inquiry'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e6', 'canonical': '개인정보', 'aliases': ['개인정보', 'personal information', 'personal data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e7', 'canonical': '정보주체', 'aliases': ['정보주체', 'information subject', 'data subject'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e8', 'canonical': '개인정보 파일', 'aliases': ['개인정보 파일', 'personal information file', 'personal data file'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e9', 'canonical': '개인정보 처리자', 'aliases': ['개인정보 처리자', 'personal information processor', 'personal data processor'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e10', 'canonical': '고정형 영상정보처리기기', 'aliases': ['고정형 영상정보처리기기', 'fixed video information processing device', 'fixed video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e11', 'canonical': '휴대형 영상정보처리기기', 'aliases': ['휴대형 영상정보처리기기', 'portable video information processing device', 'portable video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e12', 'canonical': '중앙행정기관', 'aliases': ['중앙행정기관', 'central administrative agencies', 'central government agencies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e13', 'canonical': '지방자치단체', 'aliases': ['지방자치단체', 'local governments', 'local administrative bodies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e14', 'canonical': '공공기관', 'aliases': ['공공기관', 'public institution', 'public body'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e15', 'canonical': '영상정보', 'aliases': ['영상정보', 'video information', 'video data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e17', 'canonical': '정보의 생성', 'aliases': ['정보의 생성', 'creation', 'data generation'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e19', 'canonical': '정보의 연계', 'aliases': ['정보의 연계', 'linkage', 'data linkage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e20', 'canonical': '정보의 기록', 'aliases': ['정보의 기록', 'recording', 'data recording'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e21', 'canonical': '정보의 저장', 'aliases': ['정보의 저장', 'storage', 'data storage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e22', 'canonical': '정보의 보유', 'aliases': ['정보의 보유', 'retention', 'data retention'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e23', 'canonical': '정보의 처리', 'aliases': ['정보의 처리', 'processing', 'data processing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e24', 'canonical': '정보의 편집', 'aliases': ['정보의 편집', 'editing', 'data editing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e25', 'canonical': '정보의 검색', 'aliases': ['정보의 검색', 'search', 'data search'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e26', 'canonical': '정보의 출력', 'aliases': ['정보의 출력', 'output', 'data output'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e1', 'canonical': '개인정보 보호법', 'aliases': ['개보법', 'Privacy Act'], 'type': '법률', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e5', 'canonical': '과학적 연구', 'aliases': ['과학적 연구', 'scientific research', 'scientific inquiry'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e6', 'canonical': '개인정보', 'aliases': ['개인정보', 'personal information', 'personal data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e7', 'canonical': '정보주체', 'aliases': ['정보주체', 'information subject', 'data subject'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e8', 'canonical': '개인정보 파일', 'aliases': ['개인정보 파일', 'personal information file', 'personal data file'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e9', 'canonical': '개인정보 처리자', 'aliases': ['개인정보 처리자', 'personal information processor', 'personal data processor'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e10', 'canonical': '고정형 영상정보처리기기', 'aliases': ['고정형 영상정보처리기기', 'fixed video information processing device', 'fixed video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e11', 'canonical': '휴대형 영상정보처리기기', 'aliases': ['휴대형 영상정보처리기기', 'portable video information processing device', 'portable video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e12', 'canonical': '중앙행정기관', 'aliases': ['중앙행정기관', 'central administrative agencies', 'central government agencies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e13', 'canonical': '지방자치단체', 'aliases': ['지방자치단체', 'local governments', 'local administrative bodies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e14', 'canonical': '공공기관', 'aliases': ['공공기관', 'public institution', 'public body'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e15', 'canonical': '영상정보', 'aliases': ['영상정보', 'video information', 'video data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e17', 'canonical': '정보의 생성', 'aliases': ['정보의 생성', 'creation', 'data generation'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e19', 'canonical': '정보의 연계', 'aliases': ['정보의 연계', 'linkage', 'data linkage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e20', 'canonical': '정보의 기록', 'aliases': ['정보의 기록', 'recording', 'data recording'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e21', 'canonical': '정보의 저장', 'aliases': ['정보의 저장', 'storage', 'data storage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e22', 'canonical': '정보의 보유', 'aliases': ['정보의 보유', 'retention', 'data retention'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e23', 'canonical': '정보의 처리', 'aliases': ['정보의 처리', 'processing', 'data processing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e24', 'canonical': '정보의 편집', 'aliases': ['정보의 편집', 'editing', 'data editing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e25', 'canonical': '정보의 검색', 'aliases': ['정보의 검색', 'search', 'data search'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e26', 'canonical': '정보의 출력', 'aliases': ['정보의 출력', 'output', 'data output'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e5', 'canonical': '과학적 연구', 'aliases': ['과학적 연구', 'scientific research', 'scientific inquiry'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e6', 'canonical': '개인정보', 'aliases': ['개인정보', 'personal information', 'personal data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e7', 'canonical': '정보주체', 'aliases': ['정보주체', 'information subject', 'data subject'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e8', 'canonical': '개인정보 파일', 'aliases': ['개인정보 파일', 'personal information file', 'personal data file'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e9', 'canonical': '개인정보 처리자', 'aliases': ['개인정보 처리자', 'personal information processor', 'personal data processor'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e10', 'canonical': '고정형 영상정보처리기기', 'aliases': ['고정형 영상정보처리기기', 'fixed video information processing device', 'fixed video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e11', 'canonical': '휴대형 영상정보처리기기', 'aliases': ['휴대형 영상정보처리기기', 'portable video information processing device', 'portable video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e12', 'canonical': '중앙행정기관', 'aliases': ['중앙행정기관', 'central administrative agencies', 'central government agencies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e13', 'canonical': '지방자치단체', 'aliases': ['지방자치단체', 'local governments', 'local administrative bodies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e14', 'canonical': '공공기관', 'aliases': ['공공기관', 'public institution', 'public body'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e15', 'canonical': '영상정보', 'aliases': ['영상정보', 'video information', 'video data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e17', 'canonical': '정보의 생성', 'aliases': ['정보의 생성', 'creation', 'data generation'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e19', 'canonical': '정보의 연계', 'aliases': ['정보의 연계', 'linkage', 'data linkage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e20', 'canonical': '정보의 기록', 'aliases': ['정보의 기록', 'recording', 'data recording'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e21', 'canonical': '정보의 저장', 'aliases': ['정보의 저장', 'storage', 'data storage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e22', 'canonical': '정보의 보유', 'aliases': ['정보의 보유', 'retention', 'data retention'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e23', 'canonical': '정보의 처리', 'aliases': ['정보의 처리', 'processing', 'data processing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e24', 'canonical': '정보의 편집', 'aliases': ['정보의 편집', 'editing', 'data editing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e25', 'canonical': '정보의 검색', 'aliases': ['정보의 검색', 'search', 'data search'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e26', 'canonical': '정보의 출력', 'aliases': ['정보의 출력', 'output', 'data output'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e3', 'canonical': '가명정보', 'aliases': ['가명정보', 'pseudonymized information', 'pseudonymized data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e5', 'canonical': '과학적 연구', 'aliases': ['과학적 연구', 'scientific research', 'scientific inquiry'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e6', 'canonical': '개인정보', 'aliases': ['개인정보', 'personal information', 'personal data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e7', 'canonical': '정보주체', 'aliases': ['정보주체', 'information subject', 'data subject'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e8', 'canonical': '개인정보 파일', 'aliases': ['개인정보 파일', 'personal information file', 'personal data file'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e9', 'canonical': '개인정보 처리자', 'aliases': ['개인정보 처리자', 'personal information processor', 'personal data processor'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e10', 'canonical': '고정형 영상정보처리기기', 'aliases': ['고정형 영상정보처리기기', 'fixed video information processing device', 'fixed video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e11', 'canonical': '휴대형 영상정보처리기기', 'aliases': ['휴대형 영상정보처리기기', 'portable video information processing device', 'portable video surveillance device'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e12', 'canonical': '중앙행정기관', 'aliases': ['중앙행정기관', 'central administrative agencies', 'central government agencies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e13', 'canonical': '지방자치단체', 'aliases': ['지방자치단체', 'local governments', 'local administrative bodies'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e14', 'canonical': '공공기관', 'aliases': ['공공기관', 'public institution', 'public body'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e15', 'canonical': '영상정보', 'aliases': ['영상정보', 'video information', 'video data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e17', 'canonical': '정보의 생성', 'aliases': ['정보의 생성', 'creation', 'data generation'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e19', 'canonical': '정보의 연계', 'aliases': ['정보의 연계', 'linkage', 'data linkage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e20', 'canonical': '정보의 기록', 'aliases': ['정보의 기록', 'recording', 'data recording'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e21', 'canonical': '정보의 저장', 'aliases': ['정보의 저장', 'storage', 'data storage'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e22', 'canonical': '정보의 보유', 'aliases': ['정보의 보유', 'retention', 'data retention'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e23', 'canonical': '정보의 처리', 'aliases': ['정보의 처리', 'processing', 'data processing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e24', 'canonical': '정보의 편집', 'aliases': ['정보의 편집', 'editing', 'data editing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e25', 'canonical': '정보의 검색', 'aliases': ['정보의 검색', 'search', 'data search'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e26', 'canonical': '정보의 출력', 'aliases': ['정보의 출력', 'output', 'data output'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e4', 'canonical': '가명처리', 'aliases': ['가명처리', 'pseudonymization', 'pseudonymization process'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# ...
# {'id': 'e26', 'canonical': '정보의 출력', 'aliases': ['정보의 출력', 'output', 'data output'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e26', 'canonical': '정보의 출력', 'aliases': ['정보의 출력', 'output', 'data output'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e26', 'canonical': '정보의 출력', 'aliases': ['정보의 출력', 'output', 'data output'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e26', 'canonical': '정보의 출력', 'aliases': ['정보의 출력', 'output', 'data output'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e26', 'canonical': '정보의 출력', 'aliases': ['정보의 출력', 'output', 'data output'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e28', 'canonical': '정보의 복구', 'aliases': ['정보의 복구', 'recovery', 'data recovery'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e29', 'canonical': '정보의 이용', 'aliases': ['정보의 이용', 'use', 'data utilization'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e30', 'canonical': '정보의 제공', 'aliases': ['정보의 제공', 'provision', 'data provision'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e31', 'canonical': '정보의 공개', 'aliases': ['정보의 공개', 'disclosure', 'data disclosure'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e32', 'canonical': '정보의 파기', 'aliases': ['정보의 파기', 'destruction', 'data destruction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e33', 'canonical': '유사행위', 'aliases': ['유사행위', 'other similar acts', 'analogous acts'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e34', 'canonical': '주민등록번호', 'aliases': ['주민등록번호', 'resident registration number', 'resident registration ID'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e35', 'canonical': '이미지', 'aliases': ['이미지', 'images', 'visual data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}

# %%
pairs = []
for a, b in itertools.combinations(all_e, 2):
    scores = [fuzz.token_sort_ratio(a.get("canonical",""), b.get("canonical",""))]
    for x in a.get("aliases", []):
        for y in b.get("aliases", []):
            scores.append(fuzz.token_sort_ratio(x, y))
    if max(scores) >= 85:
        pairs.append((a, b))
        all_e.pop(a)
        print(f'{a}를 pop하였습니다')
        all_e.pop(b)
        print(f'{b}를 pop하였습니다')

# %%
pairs
# Out:
# [({'id': 'e2',
#    'canonical': '제28조의2',
#    'aliases': ['가명정보의 처리'],
#    'type': '조문',
#    'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#    'evidence': ['...']},
#   {'id': 'e23',
#    'canonical': '정보의 처리',
#    'aliases': ['정보의 처리', 'processing', 'data processing'],
#    'type': '행위',
#    'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#    'evidence': ['...']}),
#  ({'id': 'e6',
#    'canonical': '개인정보',
#    'aliases': ['개인정보', 'personal information', 'personal data'],
#    'type': '용어',
#    'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#    'evidence': ['...']},
#   {'id': 'e8',
#    'canonical': '개인정보 파일',
#    'aliases': ['개인정보 파일', 'personal information file', 'personal data file'],
#    'type': '용어',
#    'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#    'evidence': ['...']}),
#  ({'id': 'e16',
#    'canonical': '정보의 수집',
#    'aliases': ['정보의 수집', 'collection', 'data collection'],
#    'type': '행위',
#    'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#    'evidence': ['...']},
#   {'id': 'e18',
#    'canonical': '정보의 결합',
#    'aliases': ['정보의 결합', 'connection', 'data connection'],
#    'type': '행위',
#    'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#    'evidence': ['...']}),
#  ({'id': 'e16',
#    'canonical': '정보의 수집',
#    'aliases': ['정보의 수집', 'collection', 'data collection'],
#    'type': '행위',
#    'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#    'evidence': ['...']},
#   {'id': 'e27',
#    'canonical': '정보의 정정',
#    'aliases': ['정보의 정정', 'correction', 'data correction'],
#    'type': '행위',
#    'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#    'evidence': ['...']}),
#  ({'id': 'e18',
#    'canonical': '정보의 결합',
#    'aliases': ['정보의 결합', 'connection', 'data connection'],
#    'type': '행위',
#    'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#    'evidence': ['...']},
#   {'id': 'e27',
#    'canonical': '정보의 정정',
#    'aliases': ['정보의 정정', 'correction', 'data correction'],
#    'type': '행위',
#    'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'],
#    'evidence': ['...']})]

# %%
for i, (a, b) in enumerate(pairs):
    print(i)
    print(a)
    print(b)
# Out:
# 0
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e23', 'canonical': '정보의 처리', 'aliases': ['정보의 처리', 'processing', 'data processing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# 1
# {'id': 'e6', 'canonical': '개인정보', 'aliases': ['개인정보', 'personal information', 'personal data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e8', 'canonical': '개인정보 파일', 'aliases': ['개인정보 파일', 'personal information file', 'personal data file'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# 2
# {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# 3
# {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# 4
# {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}

# %%
pairs_copied = pairs.copy()
changed = True
while changed:
    changed = False
    for a, b in pairs_copied:
        print(f"a : {a}")
        print(f"b : {b}")
        if llm_equiv(a, b):
            
            # 누락 키 보정
            a.setdefault("aliases", []); b.setdefault("aliases", [])
            a.setdefault("source",  []); b.setdefault("source",  [])

            # alias 병합(원래 canonical까지 alias로 흡수)
            a["aliases"] = sorted(set(
                a["aliases"] + [a.get("canonical",""), b.get("canonical","")] + b["aliases"]
            ))

            # 대표명 선택(간단: 더 짧은 쪽; 필요시 규칙 고도화)
            if a.get("canonical") and b.get("canonical"):
                a["canonical"] = min([a["canonical"], b["canonical"]], key=len)
            else:
                a["canonical"] = a.get("canonical") or b.get("canonical")

            # source 병합
            a["source"] = sorted(set(a["source"] + b["source"]))

            # 타입/정의 충돌 등은 필요시 추가 규칙으로 조정
            # 예: a["type"] 우선, 없으면 b["type"] 채우기
            if not a.get("type") and b.get("type"):
                a["type"] = b["type"]

            # b 제거 후 다시 루프 시작
            pairs_copied.remove(b)
            changed = True
            break
all_e.appned(pairs_copied)
print(f'{pairs_copied}가 다시 all_e에 합산되었습니다')
# Out:
# a : {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# b : {'id': 'e23', 'canonical': '정보의 처리', 'aliases': ['정보의 처리', 'processing', 'data processing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e23', 'canonical': '정보의 처리', 'aliases': ['정보의 처리', 'processing', 'data processing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# False
# a : {'id': 'e6', 'canonical': '개인정보', 'aliases': ['개인정보', 'personal information', 'personal data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# b : {'id': 'e8', 'canonical': '개인정보 파일', 'aliases': ['개인정보 파일', 'personal information file', 'personal data file'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e6', 'canonical': '개인정보', 'aliases': ['개인정보', 'personal information', 'personal data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e8', 'canonical': '개인정보 파일', 'aliases': ['개인정보 파일', 'personal information file', 'personal data file'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# False
# a : {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# b : {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# False
# a : {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# b : {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# False
# a : {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# b : {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}
# False

# %%
print(pairs_copied)
# Out:
# [({'id': 'e2', 'canonical': '제28조의2', 'aliases': ['가명정보의 처리'], 'type': '조문', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}, {'id': 'e23', 'canonical': '정보의 처리', 'aliases': ['정보의 처리', 'processing', 'data processing'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}), ({'id': 'e6', 'canonical': '개인정보', 'aliases': ['개인정보', 'personal information', 'personal data'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}, {'id': 'e8', 'canonical': '개인정보 파일', 'aliases': ['개인정보 파일', 'personal information file', 'personal data file'], 'type': '용어', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}), ({'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}, {'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}), ({'id': 'e16', 'canonical': '정보의 수집', 'aliases': ['정보의 수집', 'collection', 'data collection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}, {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}), ({'id': 'e18', 'canonical': '정보의 결합', 'aliases': ['정보의 결합', 'connection', 'data connection'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']}, {'id': 'e27', 'canonical': '정보의 정정', 'aliases': ['정보의 정정', 'correction', 'data correction'], 'type': '행위', 'source': ['doc://PIPA#제28조의2', 'group:1', 'group:1', 'group:1'], 'evidence': ['...']})]

# %%
import Tuple
def _norm(s: str) -> str:
    return " ".join((s or "").strip().lower().split())

def _names(e: Dict) -> set[str]:
    out = set()
    if e.get("canonical"): out.add(_norm(e["canonical"]))
    for a in e.get("aliases", []) or []:
        if a: out.add(_norm(a))
    return out

def build_name2canon(ents: List[Dict]) -> Dict[str, str]:
    m = {}
    for e in ents:
        can = _norm(e.get("canonical", ""))
        if not can: 
            continue
        for n in _names(e) | {can}:
            m[n] = can
    return m

def normalize_relations(relations: List[Dict], name2canon: Dict[str,str]) -> List[Dict]:
    out = []
    for r in relations:
        s = name2canon.get(_norm(r.get("s","")), _norm(r.get("s","")))
        o = name2canon.get(_norm(r.get("o","")), _norm(r.get("o","")))
        p = _norm(r.get("p",""))
        nr = dict(r)
        nr["s"], nr["o"], nr["p"] = s, o, p
        out.append(nr)
    return out

def _indices_involving(rel_norm: List[Dict], name_norm: str) -> List[int]:
    return [i for i, r in enumerate(rel_norm) if r["s"] == name_norm or r["o"] == name_norm]

def _direction_and_other(rn: Dict, center: str):
    if rn["s"] == center:  return "subj", rn["o"]
    if rn["o"] == center:  return "obj",  rn["s"]
    return "", ""

def _merge_evidence([dst: Dict, src: Dict]) -> None:
    e1 = set(dst.get("evidence", []) or [])
    e2 = set(src.get("evidence", []) or [])
    dst["evidence"] = sorted(e1 | e2)
    if "source" in dst or "source" in src:
        s1 = set(dst.get("source", []) or [])
        s2 = set(src.get("source", []) or [])
        dst["source"] = sorted(s1 | s2)


def dedupe_relations_simple(
    ents: List[Dict],
    relations: List[Dict],
    pairs: List[Tuple[Dict, Dict]],
    max_llm_checks: int = 200
) -> List[Dict]:
    name2canon = build_name2canon(ents)
    rel_norm = normalize_relations(relations, name2canon)

    to_delete = set()
    checks = 0

    for a, b in pairs:
        a_can = _norm(a.get("canonical","")); a_can = name2canon.get(a_can, a_can)
        b_can = _norm(b.get("canonical","")); b_can = name2canon.get(b_can, b_can)
        if not a_can or not b_can: 
            continue

        a_idxs = _indices_involving(rel_norm, a_can)
        b_idxs = _indices_involving(rel_norm, b_can)

        for i in a_idxs:
            if i in to_delete: continue
            r1n = rel_norm[i]

            for j in b_idxs:
                if j in to_delete or i == j: 
                    continue
                r2n = rel_norm[j]

                # 1) predicate 동일
                if r1n["p"] != r2n["p"]:
                    continue

                # 2) 방향 동일
                dir1, other1 = _direction_and_other(r1n, a_can)
                dir2, other2 = _direction_and_other(r2n, b_can)
                if not dir1 or not dir2 or dir1 != dir2:
                    continue

                # 3) 반대편 노드 동일
                if other1 != other2:
                    continue

                # ---- LLM 최종판정 ----
                if checks >= max_llm_checks:
                    break
                checks += 1

                if llm_equiv(relations[i], relations[j]):
                    # 더 많은 evidence 가진 쪽을 남김
                    ei = len(relations[i].get("evidence", []) or [])
                    ej = len(relations[j].get("evidence", []) or [])
                    keep, drop = (i, j) if ei >= ej else (j, i)
                    _merge_evidence(relations[keep], relations[drop])
                    to_delete.add(drop)

    return [r for k, r in enumerate(relations) if k not in to_delete]

# %%
print(f"[DEBUG] candidate_pairs = {[(a['canonical'], b['canonical']) for a,b in pairs]}")

cleaned = dedupe_relations_simple(all_e, all_r, pairs, max_llm_checks=50) 
# entities들을 모두 소문자로 normalize하고, relations들의 node들도 모두 normalize하고
# 유사한 것으로 의심되는 entities들이 들어있는 모든 relations들도 llm에게 판정하라고 시켜서, 유사한 것들은 병합하는 구조

# (5) 결과 확인
print("\n[Before]")
for r in relations:
    print(r)

print("\n[After]")
for r in cleaned:
    print(r)

# %%
# neo4j_io.py
from __future__ import annotations
from typing import List, Dict, Tuple, Optional
from neo4j import GraphDatabase
from datetime import datetime
import re

# ----------------------------
# 기본 정규화 유틸
# ----------------------------
def norm(s: str) -> str:
    return " ".join((s or "").strip().lower().split())

def uniq_list(xs: Optional[List[str]]) -> List[str]:
    if not xs:
        return []
    return sorted(set(x for x in xs if isinstance(x, str) and x.strip()))

def build_name_to_id(ents: List[Dict]) -> Dict[str, str]:
    """
    canonical/aliases 모든 표기를 -> 해당 entity id 로 매핑
    """
    m = {}
    for e in ents:
        eid = e.get("id")
        if not eid:
            continue
        can = e.get("canonical")
        if can:
            m[norm(can)] = eid
        for a in e.get("aliases", []) or []:
            if a:
                m[norm(a)] = eid
    return m

def sanitize_predicate(p: str) -> str:
    """
    관계 속성용 정규화(소문자, 공백 압축).
    (관계 타입으로 쓰지 않고 r.p_norm 속성으로만 보관)
    """
    return norm(p)

# ----------------------------
# Neo4j Writer
# ----------------------------
class Neo4jWriter:
    def __init__(self, uri: str, user: str, password: str):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    # 고유 제약조건: :Entity(id) 유니크
    def ensure_constraints(self):
        cypher = """
        CREATE CONSTRAINT entity_id_unique IF NOT EXISTS
        FOR (n:Entity) REQUIRE n.id IS UNIQUE
        """
        with self.driver.session() as sess:
            sess.run(cypher)

    # 엔터티 업서트 (간단 버전: 전달된 배열/맵을 그대로 세팅)
    def upsert_entities(self, ents: List[Dict], batch: int = 1000):
        rows = []
        now = datetime.utcnow().isoformat()

        for e in ents:
            row = {
                "id": e.get("id"),
                "canonical": e.get("canonical"),
                "type": e.get("type"),
                "aliases": uniq_list(e.get("aliases")),
                "source": uniq_list(e.get("source")),
                "evidence": uniq_list(e.get("evidence")),
                "attrs": e.get("attrs") or {},
                "updated_at": now,
            }
            if not row["id"]:
                continue
            rows.append({"props": row})

        if not rows:
            return

        q = """
        UNWIND $rows AS row
        MERGE (n:Entity {id: row.props.id})
        SET n += row.props
        """
        with self.driver.session() as sess:
            for i in range(0, len(rows), batch):
                sess.run(q, rows=rows[i:i+batch])

    # 관계 업서트
    def upsert_relations(
        self,
        ents: List[Dict],
        relations: List[Dict],
        batch: int = 1000,
        strict: bool = True,
    ):
        """
        relations의 s/o 가 '엔터티 id' 또는 'canonical/alias 문자열'일 수 있음.
        - id로 매칭 실패하면 문자열을 canonical/alias 매핑으로 id 해석 시도.
        - strict=True 이면 해석 실패한 관계는 건너뜀.
        """
        name2id = build_name_to_id(ents)
        id_set = {e["id"] for e in ents if e.get("id")}
        rows = []
        now = datetime.utcnow().isoformat()

        for r in relations:
            s_raw = str(r.get("s", "")).strip()
            o_raw = str(r.get("o", "")).strip()
            p_raw = str(r.get("p", "")).strip()

            # s/o가 이미 id이면 그대로, 아니면 이름->id 해석
            s_id = s_raw if s_raw in id_set else name2id.get(norm(s_raw))
            o_id = o_raw if o_raw in id_set else name2id.get(norm(o_raw))

            if not s_id or not o_id:
                if strict:
                    # 해석 실패 관계 스킵
                    continue
                else:
                    # 필요하면 느슨하게 노드도 함께 생성하는 로직을 넣을 수 있음
                    pass

            row = {
                "s_id": s_id,
                "o_id": o_id,
                "p": p_raw,
                "p_norm": sanitize_predicate(p_raw),
                "evidence": uniq_list(r.get("evidence")),
                "source": uniq_list(r.get("source")),
                "updated_at": now,
            }
            rows.append(row)

        if not rows:
            return

        # 동일 (s, p_norm, o) 조합을 하나로 MERGE
        q = """
        UNWIND $rows AS row
        MATCH (s:Entity {id: row.s_id})
        MATCH (o:Entity {id: row.o_id})
        MERGE (s)-[r:REL {p_norm: row.p_norm}]->(o)
        SET r.p = row.p,
            r.evidence = row.evidence,
            r.source = row.source,
            r.updated_at = row.updated_at
        """
        with self.driver.session() as sess:
            for i in range(0, len(rows), batch):
                sess.run(q, rows=rows[i:i+batch])

# %%
# run_write.py
from neo4j_io import Neo4jWriter

if __name__ == "__main__":
    # 2) 연결
    uri = "bolt://localhost:7687"       # Aura면 neo4j+s://... 형태
    user = "neo4j"
    password = "password"

    writer = Neo4jWriter(uri, user, password)
    writer.ensure_constraints()

    # 3) 엔터티/관계 업서트
    writer.upsert_entities(ents)
    writer.upsert_relations(ents, relations)

    writer.close()
    print("✅ Neo4j 업서트 완료")

# %%
# kb_update_compare.py
from __future__ import annotations
from typing import List, Dict, Tuple, Optional, Set
from dataclasses import dataclass
from neo4j import GraphDatabase
from datetime import datetime
import json
import re

# ----------------------------
# 유틸(정규화/집합 변환)
# ----------------------------
def norm(s: str) -> str:
    return " ".join((s or "").strip().lower().split())

def uniq_list(xs: Optional[List[str]]) -> List[str]:
    if not xs:
        return []
    return sorted(set(x for x in xs if isinstance(x, str) and x.strip()))

# ----------------------------
# 엔터티/관계의 "동일성 키" 정의
#  - 엔터티: (canonical_norm, type, attrs.key subset)
#  - 관계: (s_canonical_norm, p_norm, o_canonical_norm)
# ----------------------------
ENTITY_ATTR_KEY_HINTS = ("code", "number")  # 있으면 동일성 키에 포함

def entity_key(e: Dict) -> str:
    c = norm(e.get("canonical", ""))
    t = e.get("type", "") or ""
    parts = [c, "||", t]
    attrs = e.get("attrs") or {}
    for k in ENTITY_ATTR_KEY_HINTS:
        if k in attrs and attrs[k]:
            parts += ["||", f"{k}=", str(attrs[k])]
    return "".join(parts)

def rel_key(r: Dict, id2canon_norm: Dict[str, str] | None = None) -> str:
    # r["s"], r["o"]가 id거나 이름일 수 있음 -> 가능하면 canonical로 치환
    s_raw = str(r.get("s", ""))
    o_raw = str(r.get("o", ""))
    p_raw = str(r.get("p", r.get("p_norm","")))
    p_norm = norm(r.get("p_norm", p_raw))

    def to_canon_norm(x: str) -> str:
        if id2canon_norm and x in id2canon_norm:
            return id2canon_norm[x]
        return norm(x)

    s = to_canon_norm(s_raw)
    o = to_canon_norm(o_raw)
    return f"{s}||{p_norm}||{o}"

# ----------------------------
# Neo4j I/O (간단 리더/라이터)
# ----------------------------
class Neo4jIO:
    def __init__(self, uri: str, user: str, password: str):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def ensure_constraints(self):
        q = """CREATE CONSTRAINT entity_id_unique IF NOT EXISTS
               FOR (n:Entity) REQUIRE n.id IS UNIQUE"""
        with self.driver.session() as s:
            s.run(q)

    # ===== Read current KB =====
    def read_entities(self) -> List[Dict]:
        q = "MATCH (n:Entity) RETURN n"
        out = []
        with self.driver.session() as s:
            for rec in s.run(q):
                n = rec["n"]
                out.append({
                    "id": n.get("id"),
                    "canonical": n.get("canonical"),
                    "aliases": n.get("aliases") or [],
                    "type": n.get("type"),
                    "source": n.get("source") or [],
                    "evidence": n.get("evidence") or [],
                    "attrs": n.get("attrs") or {},
                })
        return out

    def read_relations(self) -> List[Dict]:
        q = """MATCH (s:Entity)-[r:REL]->(o:Entity)
               RETURN s.id AS s_id, s.canonical AS s_canon,
                      r.p AS p, r.p_norm AS p_norm, r.evidence AS evidence, r.source AS source,
                      o.id AS o_id, o.canonical AS o_canon"""
        out = []
        with self.driver.session() as s:
            for rec in s.run(q):
                out.append({
                    "s_id": rec["s_id"],
                    "s": rec["s_canon"],      # 비교 편의를 위해 canonical로 채움
                    "p": rec["p"],
                    "p_norm": rec["p_norm"],
                    "evidence": rec["evidence"] or [],
                    "source": rec["source"] or [],
                    "o_id": rec["o_id"],
                    "o": rec["o_canon"],
                })
        return out

    # ===== Upsert =====
    def upsert_entities(self, ents: List[Dict], batch: int = 500):
        if not ents:
            return
        rows = []
        now = datetime.utcnow().isoformat()
        for e in ents:
            rows.append({"props": {
                "id": e.get("id"),
                "canonical": e.get("canonical"),
                "type": e.get("type"),
                "aliases": uniq_list(e.get("aliases")),
                "source": uniq_list(e.get("source")),
                "evidence": uniq_list(e.get("evidence")),
                "attrs": e.get("attrs") or {},
                "updated_at": now,
            }})
        q = """
        UNWIND $rows AS row
        MERGE (n:Entity {id: row.props.id})
        SET n += row.props
        """
        with self.driver.session() as s:
            for i in range(0, len(rows), batch):
                s.run(q, rows=rows[i:i+batch])

    def upsert_relations(self, ents: List[Dict], rels: List[Dict], batch: int = 500):
        if not rels:
            return
        # (이 함수는 s/o가 id 또는 이름일 수 있음 → id 우선, 없으면 canonical로 매칭)
        id_set = {e["id"] for e in ents if e.get("id")}
        name2id = {}
        for e in ents:
            can = e.get("canonical")
            if e.get("id") and can:
                name2id[norm(can)] = e["id"]

        rows = []
        now = datetime.utcnow().isoformat()
        for r in rels:
            s_raw = str(r.get("s", ""))
            o_raw = str(r.get("o", ""))
            p = str(r.get("p", ""))
            p_norm = norm(r.get("p_norm", p))
            s_id = s_raw if s_raw in id_set else name2id.get(norm(s_raw))
            o_id = o_raw if o_raw in id_set else name2id.get(norm(o_raw))
            if not s_id or not o_id:
                continue
            rows.append({
                "s_id": s_id, "o_id": o_id,
                "p": p, "p_norm": p_norm,
                "evidence": uniq_list(r.get("evidence")),
                "source": uniq_list(r.get("source")),
                "updated_at": now
            })

        if not rows:
            return
        q = """
        UNWIND $rows AS row
        MATCH (s:Entity {id: row.s_id})
        MATCH (o:Entity {id: row.o_id})
        MERGE (s)-[r:REL {p_norm: row.p_norm}]->(o)
        SET r.p = row.p,
            r.evidence = row.evidence,
            r.source = row.source,
            r.updated_at = row.updated_at
        """
        with self.driver.session() as s:
            for i in range(0, len(rows), batch):
                s.run(q, rows=rows[i:i+batch])

    # ===== Delete (옵션) =====
    def delete_entities_by_canonical_type(self, items: List[Tuple[str, str]]):
        if not items:
            return
        q = """
        UNWIND $rows AS row
        MATCH (n:Entity {canonical: row.canonical, type: row.type})
        DETACH DELETE n
        """
        rows = [{"canonical": c, "type": t} for (c, t) in items]
        with self.driver.session() as s:
            s.run(q, rows=rows)

    def delete_relations_by_triplet(self, items: List[Tuple[str, str, str]]):
        """
        items: (s_canonical, p_norm, o_canonical)
        """
        if not items:
            return
        q = """
        UNWIND $rows AS row
        MATCH (s:Entity {canonical: row.s})
              -[r:REL {p_norm: row.p_norm}]->
              (o:Entity {canonical: row.o})
        DELETE r
        """
        rows = [{"s": s, "p_norm": p, "o": o} for (s, p, o) in items]
        with self.driver.session() as s:
            s.run(q, rows=rows)

# ----------------------------
# Diff 결과 구조체
# ----------------------------
@dataclass
class EntityDiff:
    added: List[Dict]
    removed: List[Dict]
    changed: List[Tuple[Dict, Dict, Dict]]  # (old, new, changes)

@dataclass
class RelationDiff:
    added: List[Dict]
    removed: List[Dict]
    changed: List[Tuple[Dict, Dict, Dict]]  # (old, new, changes)

@dataclass
class KBDiff:
    entities: EntityDiff
    relations: RelationDiff

# ----------------------------
# 새 KB 생성 훅(여러분의 파이프라인 연결)
#  - docs: 문서(텍스트/청크 리스트 등) → 엔터티/관계 반환
# ----------------------------
def run_full_pipeline_over_docs(docs: List[Dict]) -> Tuple[List[Dict], List[Dict]]:
    """
    여러분의 파이프라인을 호출하여 (entities, relations)를 반환하세요.
    반드시 각 엔터티는 id, canonical, type 등을 포함.
    관계는 s/p/o/evidence/source 포함.
    """
    raise NotImplementedError("여러분의 추출/병합 파이프라인 함수를 연결하세요.")

# ----------------------------
# Diff 계산
# ----------------------------
def index_entities_by_key(ents: List[Dict]) -> Dict[str, Dict]:
    return {entity_key(e): e for e in ents}

def index_relations_by_key(rels: List[Dict], id2canon_norm: Dict[str, str] | None = None) -> Dict[str, Dict]:
    return {rel_key(r, id2canon_norm): r for r in rels}

def id2canon_norm_map(ents: List[Dict]) -> Dict[str, str]:
    m = {}
    for e in ents:
        if e.get("id"):
            m[e["id"]] = norm(e.get("canonical",""))
    return m

def diff_sets(old_map: Dict[str, Dict], new_map: Dict[str, Dict]) -> Tuple[List[Dict], List[Dict], Set[str]]:
    old_keys = set(old_map.keys())
    new_keys = set(new_map.keys())
    added_keys = new_keys - old_keys
    removed_keys = old_keys - new_keys
    common_keys = old_keys & new_keys
    added = [new_map[k] for k in sorted(added_keys)]
    removed = [old_map[k] for k in sorted(removed_keys)]
    return added, removed, common_keys

def dict_list_diff(name: str, old_list: List[str], new_list: List[str]) -> Dict:
    o = set(old_list or [])
    n = set(new_list or [])
    add = sorted(n - o)
    rem = sorted(o - n)
    return {f"{name}_added": add, f"{name}_removed": rem} if (add or rem) else {}

def entity_change([old: Dict, new: Dict]) -> Dict:
    changes = {}
    if (old.get("canonical") or "") != (new.get("canonical") or ""):
        changes["canonical"] = {"old": old.get("canonical"), "new": new.get("canonical")}
    if (old.get("type") or "") != (new.get("type") or ""):
        changes["type"] = {"old": old.get("type"), "new": new.get("type")}
    # 리스트/맵 차이
    changes |= dict_list_diff("aliases", old.get("aliases") or [], new.get("aliases") or [])
    changes |= dict_list_diff("source", old.get("source") or [], new.get("source") or [])
    changes |= dict_list_diff("evidence", old.get("evidence") or [], new.get("evidence") or [])
    # attrs는 단순 덮었을 때 변경된 key만 추려봄
    olda, newa = old.get("attrs") or {}, new.get("attrs") or {}
    attr_keys = set(olda.keys()) | set(newa.keys())
    attr_diff = {}
    for k in sorted(attr_keys):
        if json.dumps(olda.get(k), ensure_ascii=False, sort_keys=True) != json.dumps(newa.get(k), ensure_ascii=False, sort_keys=True):
            attr_diff[k] = {"old": olda.get(k), "new": newa.get(k)}
    if attr_diff:
        changes["attrs"] = attr_diff
    return changes

def relation_change([old: Dict, new: Dict]) -> Dict:
    changes = {}
    # p / p_norm 변화
    if (old.get("p") or "") != (new.get("p") or ""):
        changes["p"] = {"old": old.get("p"), "new": new.get("p")}
    if norm(old.get("p_norm", old.get("p",""))) != norm(new.get("p_norm", new.get("p",""))):
        changes["p_norm"] = {"old": old.get("p_norm"), "new": new.get("p_norm")}
    changes |= dict_list_diff("evidence", old.get("evidence") or [], new.get("evidence") or [])
    changes |= dict_list_diff("source", old.get("source") or [], new.get("source") or [])
    return changes

def compute_kb_diff(
    old_ents: List[Dict], old_rels: List[Dict],
    new_ents: List[Dict], new_rels: List[Dict],
) -> KBDiff:
    # 엔터티 매핑
    old_e_map = index_entities_by_key(old_ents)
    new_e_map = index_entities_by_key(new_ents)

    e_added, e_removed, e_common = diff_sets(old_e_map, new_e_map)
    e_changed = []
    for k in sorted(e_common):
        ch = entity_change(old_e_map[k], new_e_map[k])
        if ch:
            e_changed.append((old_e_map[k], new_e_map[k], ch))

    # 관계 매핑 (노드 id->canonical 정규화 맵 사용)
    old_id2canon = id2canon_norm_map(old_ents)
    new_id2canon = id2canon_norm_map(new_ents)
    old_r_map = index_relations_by_key(old_rels, old_id2canon)
    new_r_map = index_relations_by_key(new_rels, new_id2canon)

    r_added, r_removed, r_common = diff_sets(old_r_map, new_r_map)
    r_changed = []
    for k in sorted(r_common):
        ch = relation_change(old_r_map[k], new_r_map[k])
        if ch:
            r_changed.append((old_r_map[k], new_r_map[k], ch))

    return KBDiff(
        entities=EntityDiff(added=e_added, removed=e_removed, changed=e_changed),
        relations=RelationDiff(added=r_added, removed=r_removed, changed=r_changed),
    )

# ----------------------------
# 리포팅(요약 출력)
# ----------------------------
def print_kb_diff_summary(diff: KBDiff, limit: int = 10):
    print("=== KB Diff Summary ===")
    print(f"Entities: +{len(diff.entities.added)} / -{len(diff.entities.removed)} / ~{len(diff.entities.changed)}")
    print(f"Relations: +{len(diff.relations.added)} / -{len(diff.relations.removed)} / ~{len(diff.relations.changed)}")

    def brief_e(e): return f"{e.get('type','?')} :: {e.get('canonical','?')}"
    def brief_r(r): return f"{r.get('s','?')} -[{r.get('p_norm', r.get('p','?'))}]-> {r.get('o','?')}"

    if diff.entities.added:
        print("\n[Entities Added] (up to", limit, ")")
        for e in diff.entities.added[:limit]:
            print(" +", brief_e(e))
    if diff.entities.removed:
        print("\n[Entities Removed] (up to", limit, ")")
        for e in diff.entities.removed[:limit]:
            print(" -", brief_e(e))
    if diff.entities.changed:
        print("\n[Entities Changed] (up to", limit, ")")
        for old, new, ch in diff.entities.changed[:limit]:
            print(" ~", brief_e(old), "=>", brief_e(new), "| changes:", ch)

    if diff.relations.added:
        print("\n[Relations Added] (up to", limit, ")")
        for r in diff.relations.added[:limit]:
            print(" +", brief_r(r))
    if diff.relations.removed:
        print("\n[Relations Removed] (up to", limit, ")")
        for r in diff.relations.removed[:limit]:
            print(" -", brief_r(r))
    if diff.relations.changed:
        print("\n[Relations Changed] (up to", limit, ")")
        for old, new, ch in diff.relations.changed[:limit]:
            print(" ~", brief_r(old), " | changes:", ch)

# ----------------------------
# Neo4j에 패치 적용(옵션)
#   - added/changed 는 upsert
#   - removed 는 (옵션) 삭제
# ----------------------------
def apply_diff_to_neo4j(
    neo: Neo4jIO,
    new_ents: List[Dict],
    new_rels: List[Dict],
    diff: KBDiff,
    delete_removed: bool = False
):
    # 추가/변경 업서트
    ents_to_upsert = diff.entities.added + [new for _, new, _ in diff.entities.changed]
    if ents_to_upsert:
        neo.upsert_entities(ents_to_upsert)
    rels_to_upsert = diff.relations.added + [new for _, new, _ in diff.relations.changed]
    if rels_to_upsert:
        neo.upsert_relations(new_ents, rels_to_upsert)

    # 삭제(선택)
    if delete_removed:
        # 엔터티 삭제는 관계 참조가 있을 수 있으니 신중히.
        ent_del_items = [(e.get("canonical",""), e.get("type","")) for e in diff.entities.removed]
        if ent_del_items:
            neo.delete_entities_by_canonical_type(ent_del_items)

        rel_del_items = []
        for r in diff.relations.removed:
            s = norm(r.get("s",""))
            p = norm(r.get("p_norm", r.get("p","")))
            o = norm(r.get("o",""))
            rel_del_items.append((s, p, o))
        if rel_del_items:
            neo.delete_relations_by_triplet(rel_del_items)

# ----------------------------
# 메인 실행 예시
# ----------------------------
def main():
    # 0) 기존 KB 읽기 (Neo4j)
    uri = "bolt://localhost:7687"; user = "neo4j"; password = "password"
    neo = Neo4jIO(uri, user, password)
    neo.ensure_constraints()

    old_entities = neo.read_entities()
    old_relations = neo.read_relations()

    # 1) 새 문서 포함하여 전체 4개 문서로 파이프라인 실행 → 새 KB
    #    여러분의 함수를 연결하세요.
    docs = [
        # {"doc_id": "doc1", "text": "..."},
        # {"doc_id": "doc2", "text": "..."},
        # {"doc_id": "doc3", "text": "..."},
        # {"doc_id": "doc4_new", "text": "..."},
    ]
    new_entities, new_relations = run_full_pipeline_over_docs(docs)

    # 2) Diff 계산
    diff = compute_kb_diff(old_entities, old_relations, new_entities, new_relations)

    # 3) 요약 출력
    print_kb_diff_summary(diff, limit=15)

    # 4) (옵션) Neo4j에 패치 적용
    #    - removed 삭제까지 반영하려면 delete_removed=True
    apply_diff_to_neo4j(neo, new_entities, new_relations, diff, delete_removed=False)

    neo.close()
    print("✅ 완료")

if __name__ == "__main__":
    main()

# %%
same_entities = {}
pairs = []
for a, b in itertools.combinations(all_e, 2):
    pairs.append((a,b))
    for x in a['entities']:
        for y in b['entities']:
            score = fuzz.token_sort_ratio(x, y)
            print(f"x : {x} y : {y} score = {fuzz.token_sort_ratio(x, y)}")
            if score >= 80 : 
                same_entities[x] = y
# Out:
# x : Personal information y : privacy score = 22.22222222222222
# x : Personal information y : personal data score = 42.42424242424242
# x : Personal information y : processing score = 26.66666666666667
# x : Personal information y : data subjects score = 18.181818181818176
# x : Personal information y : purpose score = 14.814814814814813
# x : Personal information y : minimum necessary score = 21.62162162162162
# x : Personal information y : legally score = 22.22222222222222
# x : Personal information y : justly score = 15.384615384615385
# x : Personal information y : scope score = 16.000000000000004
# x : Personal information y : proper score = 23.076923076923073
# x : Personal information y : infringement score = 37.5
# x : Personal information y : rights score = 23.076923076923073
# x : Personal information y : access score = 15.384615384615385
# x : Personal information y : policies score = 28.57142857142857
# x : Personal information y : rights of data subjects score = 23.25581395348837
# x : Personal information y : invasion score = 42.85714285714286
# x : Personal information y : anonymization score = 54.54545454545454
# x : Personal information y : pseudonymization score = 50.0
# x : Personal information y : trust score = 24.0
# x : living individuals y : privacy score = 24.0
# x : living individuals y : personal data score = 25.806451612903224
# x : living individuals y : processing score = 28.57142857142857
# x : living individuals y : data subjects score = 19.354838709677423
# x : living individuals y : purpose score = 16.000000000000004
# x : living individuals y : minimum necessary score = 34.285714285714285
# x : living individuals y : legally score = 24.0
# x : living individuals y : justly score = 25.0
# x : living individuals y : scope score = 8.695652173913048
# x : living individuals y : proper score = 0.0
# x : living individuals y : infringement score = 33.333333333333336
# x : living individuals y : rights score = 16.666666666666664
# x : living individuals y : access score = 16.666666666666664
# x : living individuals y : policies score = 23.076923076923073
# x : living individuals y : rights of data subjects score = 24.390243902439025
# x : living individuals y : invasion score = 53.84615384615385
# x : living individuals y : anonymization score = 32.25806451612904
# x : living individuals y : pseudonymization score = 29.411764705882348
# x : living individuals y : trust score = 17.391304347826086
# x : categories y : privacy score = 23.529411764705888
# x : categories y : personal data score = 43.47826086956522
# x : categories y : processing score = 30.000000000000004
# x : categories y : data subjects score = 34.78260869565217
# x : categories y : purpose score = 23.529411764705888
# x : categories y : minimum necessary score = 22.22222222222222
# x : categories y : legally score = 23.529411764705888
# x : categories y : justly score = 12.5
# x : categories y : scope score = 40.0
# x : categories y : proper score = 25.0
# x : categories y : infringement score = 27.27272727272727
# x : categories y : rights score = 37.5
# x : categories y : access score = 37.5
# x : categories y : policies score = 44.44444444444444
# x : categories y : rights of data subjects score = 42.42424242424242
# x : categories y : invasion score = 22.22222222222222
# x : categories y : anonymization score = 26.086956521739136
# x : categories y : pseudonymization score = 23.076923076923073
# x : categories y : trust score = 40.0
# x : Collection y : privacy score = 11.764705882352944
# x : Collection y : personal data score = 26.086956521739136
# x : Collection y : processing score = 40.0
# x : Collection y : data subjects score = 26.086956521739136
# x : Collection y : purpose score = 23.529411764705888
# x : Collection y : minimum necessary score = 14.814814814814813
# x : Collection y : legally score = 23.529411764705888
# x : Collection y : justly score = 12.5
# x : Collection y : scope score = 26.66666666666667
# x : Collection y : proper score = 25.0
# x : Collection y : infringement score = 18.181818181818176
# x : Collection y : rights score = 12.5
# x : Collection y : access score = 12.5
# x : Collection y : policies score = 44.44444444444444
# x : Collection y : rights of data subjects score = 24.242424242424242
# x : Collection y : invasion score = 33.333333333333336
# x : Collection y : anonymization score = 43.47826086956522
# x : Collection y : pseudonymization score = 38.46153846153846
# x : Collection y : trust score = 13.33333333333333
# x : Generation y : privacy score = 23.529411764705888
# x : Generation y : personal data score = 34.78260869565217
# x : Generation y : processing score = 30.000000000000004
# x : Generation y : data subjects score = 17.391304347826086
# x : Generation y : purpose score = 23.529411764705888
# x : Generation y : minimum necessary score = 22.22222222222222
# x : Generation y : legally score = 23.529411764705888
# x : Generation y : justly score = 12.5
# x : Generation y : scope score = 13.33333333333333
# x : Generation y : proper score = 25.0
# x : Generation y : infringement score = 36.36363636363637
# x : Generation y : rights score = 25.0
# x : Generation y : access score = 12.5
# x : Generation y : policies score = 11.111111111111116
# x : Generation y : rights of data subjects score = 18.181818181818176
# x : Generation y : invasion score = 55.55555555555556
# x : Generation y : anonymization score = 52.17391304347826
# x : Generation y : pseudonymization score = 53.84615384615385
# x : Generation y : trust score = 26.66666666666667
# x : Connection y : privacy score = 11.764705882352944
# x : Connection y : personal data score = 26.086956521739136
# x : Connection y : processing score = 40.0
# x : Connection y : data subjects score = 26.086956521739136
# x : Connection y : purpose score = 23.529411764705888
# x : Connection y : minimum necessary score = 29.629629629629626
# x : Connection y : legally score = 11.764705882352944
# x : Connection y : justly score = 12.5
# x : Connection y : scope score = 26.66666666666667
# x : Connection y : proper score = 25.0
# x : Connection y : infringement score = 36.36363636363637
# x : Connection y : rights score = 12.5
# x : Connection y : access score = 12.5
# x : Connection y : policies score = 33.333333333333336
# x : Connection y : rights of data subjects score = 24.242424242424242
# x : Connection y : invasion score = 44.44444444444444
# x : Connection y : anonymization score = 52.17391304347826
# x : Connection y : pseudonymization score = 46.15384615384615
# x : Connection y : trust score = 13.33333333333333
# x : Integration y : privacy score = 22.22222222222222
# x : Integration y : personal data score = 41.666666666666664
# x : Integration y : processing score = 28.57142857142857
# x : Integration y : data subjects score = 25.0
# x : Integration y : purpose score = 22.22222222222222
# x : Integration y : minimum necessary score = 21.42857142857143
# x : Integration y : legally score = 33.333333333333336
# x : Integration y : justly score = 11.764705882352944
# x : Integration y : scope score = 12.5
# x : Integration y : proper score = 23.529411764705888
# x : Integration y : infringement score = 34.78260869565217
# x : Integration y : rights score = 23.529411764705888
# x : Integration y : access score = 11.764705882352944
# x : Integration y : policies score = 10.526315789473683
# x : Integration y : rights of data subjects score = 17.647058823529417
# x : Integration y : invasion score = 52.63157894736843
# x : Integration y : anonymization score = 50.0
# x : Integration y : pseudonymization score = 44.44444444444444
# x : Integration y : trust score = 37.5
# x : Recording y : privacy score = 25.0
# x : Recording y : personal data score = 27.27272727272727
# x : Recording y : processing score = 42.10526315789473
# x : Recording y : data subjects score = 18.181818181818176
# x : Recording y : purpose score = 12.5
# x : Recording y : minimum necessary score = 23.076923076923073
# x : Recording y : legally score = 25.0
# x : Recording y : justly score = 0.0
# x : Recording y : scope score = 28.57142857142857
# x : Recording y : proper score = 26.66666666666667
# x : Recording y : infringement score = 38.095238095238095
# x : Recording y : rights score = 40.0
# x : Recording y : access score = 13.33333333333333
# x : Recording y : policies score = 23.529411764705888
# x : Recording y : rights of data subjects score = 25.0
# x : Recording y : invasion score = 23.529411764705888
# x : Recording y : anonymization score = 27.27272727272727
# x : Recording y : pseudonymization score = 31.999999999999996
# x : Recording y : trust score = 14.28571428571429
# x : Storage y : privacy score = 28.57142857142857
# x : Storage y : personal data score = 30.000000000000004
# x : Storage y : processing score = 23.529411764705888
# x : Storage y : data subjects score = 30.000000000000004
# x : Storage y : purpose score = 28.57142857142857
# x : Storage y : minimum necessary score = 8.333333333333337
# x : Storage y : legally score = 14.28571428571429
# x : Storage y : justly score = 15.384615384615385
# x : Storage y : scope score = 33.333333333333336
# x : Storage y : proper score = 30.76923076923077
# x : Storage y : infringement score = 31.57894736842105
# x : Storage y : rights score = 30.76923076923077
# x : Storage y : access score = 30.76923076923077
# x : Storage y : policies score = 26.66666666666667
# x : Storage y : rights of data subjects score = 33.333333333333336
# x : Storage y : invasion score = 13.33333333333333
# x : Storage y : anonymization score = 19.999999999999996
# x : Storage y : pseudonymization score = 17.391304347826086
# x : Storage y : trust score = 33.333333333333336
# x : Retention y : privacy score = 12.5
# x : Retention y : personal data score = 36.36363636363637
# x : Retention y : processing score = 31.57894736842105
# x : Retention y : data subjects score = 27.27272727272727
# x : Retention y : purpose score = 12.5
# x : Retention y : minimum necessary score = 23.076923076923073
# x : Retention y : legally score = 12.5
# x : Retention y : justly score = 13.33333333333333
# x : Retention y : scope score = 14.28571428571429
# x : Retention y : proper score = 13.33333333333333
# x : Retention y : infringement score = 38.095238095238095
# x : Retention y : rights score = 13.33333333333333
# x : Retention y : access score = 13.33333333333333
# x : Retention y : policies score = 11.764705882352944
# x : Retention y : rights of data subjects score = 18.75
# x : Retention y : invasion score = 47.05882352941176
# x : Retention y : anonymization score = 45.45454545454546
# x : Retention y : pseudonymization score = 48.0
# x : Retention y : trust score = 28.57142857142857
# x : Processing y : privacy score = 23.529411764705888
# x : Processing y : personal data score = 26.086956521739136
# x : Processing y : processing score = 90.0
# x : Processing y : data subjects score = 17.391304347826086
# x : Processing y : purpose score = 35.29411764705882
# x : Processing y : minimum necessary score = 29.629629629629626
# x : Processing y : legally score = 23.529411764705888
# x : Processing y : justly score = 12.5
# x : Processing y : scope score = 26.66666666666667
# x : Processing y : proper score = 37.5
# x : Processing y : infringement score = 36.36363636363637
# x : Processing y : rights score = 37.5
# x : Processing y : access score = 50.0
# x : Processing y : policies score = 44.44444444444444
# x : Processing y : rights of data subjects score = 18.181818181818176
# x : Processing y : invasion score = 33.333333333333336
# x : Processing y : anonymization score = 26.086956521739136
# x : Processing y : pseudonymization score = 23.076923076923073
# x : Processing y : trust score = 26.66666666666667
# x : Editing y : privacy score = 14.28571428571429
# x : Editing y : personal data score = 30.000000000000004
# x : Editing y : processing score = 35.29411764705882
# x : Editing y : data subjects score = 19.999999999999996
# x : Editing y : purpose score = 0.0
# x : Editing y : minimum necessary score = 25.0
# x : Editing y : legally score = 14.28571428571429
# x : Editing y : justly score = 15.384615384615385
# x : Editing y : scope score = 0.0
# x : Editing y : proper score = 0.0
# x : Editing y : infringement score = 42.10526315789473
# x : Editing y : rights score = 30.76923076923077
# x : Editing y : access score = 0.0
# x : Editing y : policies score = 26.66666666666667
# x : Editing y : rights of data subjects score = 26.66666666666667
# x : Editing y : invasion score = 40.0
# x : Editing y : anonymization score = 40.0
# x : Editing y : pseudonymization score = 43.47826086956522
# x : Editing y : trust score = 16.666666666666664
# x : Retrieval y : privacy score = 50.0
# x : Retrieval y : personal data score = 36.36363636363637
# x : Retrieval y : processing score = 21.052631578947366
# x : Retrieval y : data subjects score = 18.181818181818176
# x : Retrieval y : purpose score = 25.0
# x : Retrieval y : minimum necessary score = 23.076923076923073
# x : Retrieval y : legally score = 37.5
# x : Retrieval y : justly score = 26.66666666666667
# x : Retrieval y : scope score = 14.28571428571429
# x : Retrieval y : proper score = 26.66666666666667
# x : Retrieval y : infringement score = 28.57142857142857
# x : Retrieval y : rights score = 26.66666666666667
# x : Retrieval y : access score = 13.33333333333333
# x : Retrieval y : policies score = 23.529411764705888
# x : Retrieval y : rights of data subjects score = 25.0
# x : Retrieval y : invasion score = 35.29411764705882
# x : Retrieval y : anonymization score = 18.181818181818176
# x : Retrieval y : pseudonymization score = 24.0
# x : Retrieval y : trust score = 28.57142857142857
# x : Output y : privacy score = 15.384615384615385
# x : Output y : personal data score = 21.052631578947366
# x : Output y : processing score = 12.5
# x : Output y : data subjects score = 31.57894736842105
# x : Output y : purpose score = 30.76923076923077
# x : Output y : minimum necessary score = 8.695652173913048
# x : Output y : legally score = 0.0
# x : Output y : justly score = 33.333333333333336
# x : Output y : scope score = 18.181818181818176
# x : Output y : proper score = 16.666666666666664
# x : Output y : infringement score = 11.111111111111116
# x : Output y : rights score = 16.666666666666664
# x : Output y : access score = 0.0
# x : Output y : policies score = 14.28571428571429
# x : Output y : rights of data subjects score = 20.68965517241379
# x : Output y : invasion score = 0.0
# x : Output y : anonymization score = 10.526315789473683
# x : Output y : pseudonymization score = 27.27272727272727
# x : Output y : trust score = 54.54545454545454
# x : Correction y : privacy score = 23.529411764705888
# x : Correction y : personal data score = 26.086956521739136
# x : Correction y : processing score = 40.0
# x : Correction y : data subjects score = 26.086956521739136
# x : Correction y : purpose score = 23.529411764705888
# x : Correction y : minimum necessary score = 14.814814814814813
# x : Correction y : legally score = 11.764705882352944
# x : Correction y : justly score = 12.5
# x : Correction y : scope score = 26.66666666666667
# x : Correction y : proper score = 25.0
# x : Correction y : infringement score = 27.27272727272727
# x : Correction y : rights score = 25.0
# x : Correction y : access score = 12.5
# x : Correction y : policies score = 33.333333333333336
# x : Correction y : rights of data subjects score = 30.303030303030297
# x : Correction y : invasion score = 33.333333333333336
# x : Correction y : anonymization score = 43.47826086956522
# x : Correction y : pseudonymization score = 38.46153846153846
# x : Correction y : trust score = 26.66666666666667
# x : Recovery y : privacy score = 26.66666666666667
# x : Recovery y : personal data score = 19.047619047619047
# x : Recovery y : processing score = 22.22222222222222
# x : Recovery y : data subjects score = 19.047619047619047
# x : Recovery y : purpose score = 26.66666666666667
# x : Recovery y : minimum necessary score = 40.0
# x : Recovery y : legally score = 26.66666666666667
# x : Recovery y : justly score = 14.28571428571429
# x : Recovery y : scope score = 46.15384615384615
# x : Recovery y : proper score = 42.85714285714286
# x : Recovery y : infringement score = 19.999999999999996
# x : Recovery y : rights score = 14.28571428571429
# x : Recovery y : access score = 28.57142857142857
# x : Recovery y : policies score = 25.0
# x : Recovery y : rights of data subjects score = 12.903225806451612
# x : Recovery y : invasion score = 12.5
# x : Recovery y : anonymization score = 19.047619047619047
# x : Recovery y : pseudonymization score = 25.0
# x : Recovery y : trust score = 15.384615384615385
# x : Use y : privacy score = 0.0
# x : Use y : personal data score = 12.5
# x : Use y : processing score = 15.384615384615385
# x : Use y : data subjects score = 25.0
# x : Use y : purpose score = 40.0
# x : Use y : minimum necessary score = 9.999999999999998
# x : Use y : legally score = 19.999999999999996
# x : Use y : justly score = 22.22222222222222
# x : Use y : scope score = 50.0
# x : Use y : proper score = 22.22222222222222
# x : Use y : infringement score = 13.33333333333333
# x : Use y : rights score = 22.22222222222222
# x : Use y : access score = 22.22222222222222
# x : Use y : policies score = 18.181818181818176
# x : Use y : rights of data subjects score = 15.384615384615385
# x : Use y : invasion score = 18.181818181818176
# x : Use y : anonymization score = 0.0
# x : Use y : pseudonymization score = 21.052631578947366
# x : Use y : trust score = 25.0
# x : Provision y : privacy score = 25.0
# x : Provision y : personal data score = 36.36363636363637
# x : Provision y : processing score = 52.63157894736843
# x : Provision y : data subjects score = 9.090909090909093
# x : Provision y : purpose score = 37.5
# x : Provision y : minimum necessary score = 23.076923076923073
# x : Provision y : legally score = 0.0
# x : Provision y : justly score = 13.33333333333333
# x : Provision y : scope score = 28.57142857142857
# x : Provision y : proper score = 26.66666666666667
# x : Provision y : infringement score = 28.57142857142857
# x : Provision y : rights score = 40.0
# x : Provision y : access score = 13.33333333333333
# x : Provision y : policies score = 35.29411764705882
# x : Provision y : rights of data subjects score = 18.75
# x : Provision y : invasion score = 58.82352941176471
# x : Provision y : anonymization score = 45.45454545454546
# x : Provision y : pseudonymization score = 40.0
# x : Provision y : trust score = 28.57142857142857
# x : Disclosure y : privacy score = 23.529411764705888
# x : Disclosure y : personal data score = 17.391304347826086
# x : Disclosure y : processing score = 19.999999999999996
# x : Disclosure y : data subjects score = 26.086956521739136
# x : Disclosure y : purpose score = 35.29411764705882
# x : Disclosure y : minimum necessary score = 29.629629629629626
# x : Disclosure y : legally score = 23.529411764705888
# x : Disclosure y : justly score = 25.0
# x : Disclosure y : scope score = 53.333333333333336
# x : Disclosure y : proper score = 25.0
# x : Disclosure y : infringement score = 27.27272727272727
# x : Disclosure y : rights score = 25.0
# x : Disclosure y : access score = 25.0
# x : Disclosure y : policies score = 33.333333333333336
# x : Disclosure y : rights of data subjects score = 30.303030303030297
# x : Disclosure y : invasion score = 33.333333333333336
# x : Disclosure y : anonymization score = 17.391304347826086
# x : Disclosure y : pseudonymization score = 15.384615384615385
# x : Disclosure y : trust score = 13.33333333333333
# x : Destruction y : privacy score = 22.22222222222222
# x : Destruction y : personal data score = 33.333333333333336
# x : Destruction y : processing score = 38.095238095238095
# x : Destruction y : data subjects score = 33.333333333333336
# x : Destruction y : purpose score = 22.22222222222222
# x : Destruction y : minimum necessary score = 21.42857142857143
# x : Destruction y : legally score = 11.111111111111116
# x : Destruction y : justly score = 23.529411764705888
# x : Destruction y : scope score = 37.5
# x : Destruction y : proper score = 23.529411764705888
# x : Destruction y : infringement score = 26.086956521739136
# x : Destruction y : rights score = 23.529411764705888
# x : Destruction y : access score = 23.529411764705888
# x : Destruction y : policies score = 21.052631578947366
# x : Destruction y : rights of data subjects score = 29.411764705882348
# x : Destruction y : invasion score = 42.10526315789473
# x : Destruction y : anonymization score = 33.333333333333336
# x : Destruction y : pseudonymization score = 44.44444444444444
# x : Destruction y : trust score = 50.0
# x : Similar actions y : privacy score = 27.27272727272727
# x : Similar actions y : personal data score = 28.57142857142857
# x : Similar actions y : processing score = 31.999999999999996
# x : Similar actions y : data subjects score = 35.71428571428571
# x : Similar actions y : purpose score = 27.27272727272727
# x : Similar actions y : minimum necessary score = 31.25
# x : Similar actions y : legally score = 18.181818181818176
# x : Similar actions y : justly score = 9.523809523809524
# x : Similar actions y : scope score = 19.999999999999996
# x : Similar actions y : proper score = 19.047619047619047
# x : Similar actions y : infringement score = 29.629629629629626
# x : Similar actions y : rights score = 28.57142857142857
# x : Similar actions y : access score = 28.57142857142857
# x : Similar actions y : policies score = 34.78260869565217
# x : Similar actions y : rights of data subjects score = 31.57894736842105
# x : Similar actions y : invasion score = 43.47826086956522
# x : Similar actions y : anonymization score = 50.0
# x : Similar actions y : pseudonymization score = 45.16129032258065
# x : Similar actions y : trust score = 19.999999999999996
# x : Personal information file y : privacy score = 18.75
# x : Personal information file y : personal data score = 36.8421052631579
# x : Personal information file y : processing score = 28.57142857142857
# x : Personal information file y : data subjects score = 21.052631578947366
# x : Personal information file y : purpose score = 18.75
# x : Personal information file y : minimum necessary score = 23.809523809523814
# x : Personal information file y : legally score = 25.0
# x : Personal information file y : justly score = 12.903225806451612
# x : Personal information file y : scope score = 19.999999999999996
# x : Personal information file y : proper score = 25.806451612903224
# x : Personal information file y : infringement score = 32.432432432432435
# x : Personal information file y : rights score = 19.354838709677423
# x : Personal information file y : access score = 12.903225806451612
# x : Personal information file y : policies score = 24.242424242424242
# x : Personal information file y : rights of data subjects score = 25.0
# x : Personal information file y : invasion score = 36.36363636363637
# x : Personal information file y : anonymization score = 47.36842105263158
# x : Personal information file y : pseudonymization score = 43.90243902439024
# x : Personal information file y : trust score = 19.999999999999996
# x : Systematically arranged y : privacy score = 19.999999999999996
# x : Systematically arranged y : personal data score = 33.333333333333336
# x : Systematically arranged y : processing score = 24.242424242424242
# x : Systematically arranged y : data subjects score = 27.77777777777778
# x : Systematically arranged y : purpose score = 13.33333333333333
# x : Systematically arranged y : minimum necessary score = 25.0
# x : Systematically arranged y : legally score = 33.333333333333336
# x : Systematically arranged y : justly score = 27.586206896551722
# x : Systematically arranged y : scope score = 21.42857142857143
# x : Systematically arranged y : proper score = 13.793103448275868
# x : Systematically arranged y : infringement score = 28.57142857142857
# x : Systematically arranged y : rights score = 13.793103448275868
# x : Systematically arranged y : access score = 20.68965517241379
# x : Systematically arranged y : policies score = 19.354838709677423
# x : Systematically arranged y : rights of data subjects score = 30.434782608695656
# x : Systematically arranged y : invasion score = 19.354838709677423
# x : Systematically arranged y : anonymization score = 33.333333333333336
# x : Systematically arranged y : pseudonymization score = 35.89743589743589
# x : Systematically arranged y : trust score = 14.28571428571429
# x : Organized y : privacy score = 25.0
# x : Organized y : personal data score = 18.181818181818176
# x : Organized y : processing score = 21.052631578947366
# x : Organized y : data subjects score = 18.181818181818176
# x : Organized y : purpose score = 25.0
# x : Organized y : minimum necessary score = 23.076923076923073
# x : Organized y : legally score = 25.0
# x : Organized y : justly score = 0.0
# x : Organized y : scope score = 14.28571428571429
# x : Organized y : proper score = 26.66666666666667
# x : Organized y : infringement score = 28.57142857142857
# x : Organized y : rights score = 26.66666666666667
# x : Organized y : access score = 26.66666666666667
# x : Organized y : policies score = 23.529411764705888
# x : Organized y : rights of data subjects score = 18.75
# x : Organized y : invasion score = 23.529411764705888
# x : Organized y : anonymization score = 36.36363636363637
# x : Organized y : pseudonymization score = 24.0
# x : Organized y : trust score = 14.28571428571429
# x : Easy search y : privacy score = 22.22222222222222
# x : Easy search y : personal data score = 33.333333333333336
# x : Easy search y : processing score = 19.047619047619047
# x : Easy search y : data subjects score = 41.666666666666664
# x : Easy search y : purpose score = 22.22222222222222
# x : Easy search y : minimum necessary score = 28.57142857142857
# x : Easy search y : legally score = 22.22222222222222
# x : Easy search y : justly score = 23.529411764705888
# x : Easy search y : scope score = 25.0
# x : Easy search y : proper score = 23.529411764705888
# x : Easy search y : infringement score = 8.695652173913048
# x : Easy search y : rights score = 23.529411764705888
# x : Easy search y : access score = 35.29411764705882
# x : Easy search y : policies score = 10.526315789473683
# x : Easy search y : rights of data subjects score = 35.29411764705882
# x : Easy search y : invasion score = 21.052631578947366
# x : Easy search y : anonymization score = 25.0
# x : Easy search y : pseudonymization score = 22.22222222222222
# x : Easy search y : trust score = 12.5
# x : Data subject y : privacy score = 21.052631578947366
# x : Data subject y : personal data score = 40.0
# x : Data subject y : processing score = 9.090909090909093
# x : Data subject y : data subjects score = 88.0
# x : Data subject y : purpose score = 21.052631578947366
# x : Data subject y : minimum necessary score = 20.68965517241379
# x : Data subject y : legally score = 10.526315789473683
# x : Data subject y : justly score = 22.22222222222222
# x : Data subject y : scope score = 23.529411764705888
# x : Data subject y : proper score = 11.111111111111116
# x : Data subject y : infringement score = 16.666666666666664
# x : Data subject y : rights score = 22.22222222222222
# x : Data subject y : access score = 22.22222222222222
# x : Data subject y : policies score = 9.999999999999998
# x : Data subject y : rights of data subjects score = 62.857142857142854
# x : Data subject y : invasion score = 19.999999999999996
# x : Data subject y : anonymization score = 24.0
# x : Data subject y : pseudonymization score = 21.42857142857143
# x : Data subject y : trust score = 35.29411764705882
# x : Person y : privacy score = 15.384615384615385
# x : Person y : personal data score = 52.63157894736843
# x : Person y : processing score = 37.5
# x : Person y : data subjects score = 21.052631578947366
# x : Person y : purpose score = 30.76923076923077
# x : Person y : minimum necessary score = 17.391304347826086
# x : Person y : legally score = 15.384615384615385
# x : Person y : justly score = 16.666666666666664
# x : Person y : scope score = 36.36363636363637
# x : Person y : proper score = 33.333333333333336
# x : Person y : infringement score = 22.22222222222222
# x : Person y : rights score = 33.333333333333336
# x : Person y : access score = 33.333333333333336
# x : Person y : policies score = 28.57142857142857
# x : Person y : rights of data subjects score = 13.793103448275868
# x : Person y : invasion score = 42.85714285714286
# x : Person y : anonymization score = 21.052631578947366
# x : Person y : pseudonymization score = 27.27272727272727
# x : Person y : trust score = 36.36363636363637
# x : Subject y : privacy score = 14.28571428571429
# x : Subject y : personal data score = 9.999999999999998
# x : Subject y : processing score = 11.764705882352944
# x : Subject y : data subjects score = 60.0
# x : Subject y : purpose score = 28.57142857142857
# x : Subject y : minimum necessary score = 25.0
# x : Subject y : legally score = 14.28571428571429
# x : Subject y : justly score = 30.76923076923077
# x : Subject y : scope score = 16.666666666666664
# x : Subject y : proper score = 15.384615384615385
# x : Subject y : infringement score = 21.052631578947366
# x : Subject y : rights score = 15.384615384615385
# x : Subject y : access score = 15.384615384615385
# x : Subject y : policies score = 13.33333333333333
# x : Subject y : rights of data subjects score = 40.0
# x : Subject y : invasion score = 0.0
# x : Subject y : anonymization score = 9.999999999999998
# x : Subject y : pseudonymization score = 17.391304347826086
# x : Subject y : trust score = 33.333333333333336
# x : Personal information processor y : privacy score = 21.62162162162162
# x : Personal information processor y : personal data score = 32.55813953488372
# x : Personal information processor y : processing score = 35.0
# x : Personal information processor y : data subjects score = 23.25581395348837
# x : Personal information processor y : purpose score = 21.62162162162162
# x : Personal information processor y : minimum necessary score = 38.297872340425535
# x : Personal information processor y : legally score = 16.216216216216218
# x : Personal information processor y : justly score = 11.111111111111116
# x : Personal information processor y : scope score = 22.857142857142854
# x : Personal information processor y : proper score = 27.77777777777778
# x : Personal information processor y : infringement score = 33.333333333333336
# x : Personal information processor y : rights score = 22.22222222222222
# x : Personal information processor y : access score = 27.77777777777778
# x : Personal information processor y : policies score = 31.57894736842105
# x : Personal information processor y : rights of data subjects score = 30.188679245283023
# x : Personal information processor y : invasion score = 31.57894736842105
# x : Personal information processor y : anonymization score = 41.860465116279066
# x : Personal information processor y : pseudonymization score = 39.13043478260869
# x : Personal information processor y : trust score = 17.14285714285714
# x : Public institutions y : privacy score = 15.384615384615385
# x : Public institutions y : personal data score = 25.0
# x : Public institutions y : processing score = 27.586206896551722
# x : Public institutions y : data subjects score = 31.25
# x : Public institutions y : purpose score = 23.076923076923073
# x : Public institutions y : minimum necessary score = 33.333333333333336
# x : Public institutions y : legally score = 7.692307692307687
# x : Public institutions y : justly score = 24.0
# x : Public institutions y : scope score = 16.666666666666664
# x : Public institutions y : proper score = 7.9999999999999964
# x : Public institutions y : infringement score = 25.806451612903224
# x : Public institutions y : rights score = 24.0
# x : Public institutions y : access score = 24.0
# x : Public institutions y : policies score = 37.03703703703704
# x : Public institutions y : rights of data subjects score = 28.57142857142857
# x : Public institutions y : invasion score = 44.44444444444444
# x : Public institutions y : anonymization score = 37.5
# x : Public institutions y : pseudonymization score = 40.0
# x : Public institutions y : trust score = 25.0
# x : Corporations y : privacy score = 31.57894736842105
# x : Corporations y : personal data score = 31.999999999999996
# x : Corporations y : processing score = 36.36363636363637
# x : Corporations y : data subjects score = 24.0
# x : Corporations y : purpose score = 42.10526315789473
# x : Corporations y : minimum necessary score = 20.68965517241379
# x : Corporations y : legally score = 10.526315789473683
# x : Corporations y : justly score = 11.111111111111116
# x : Corporations y : scope score = 23.529411764705888
# x : Corporations y : proper score = 33.333333333333336
# x : Corporations y : infringement score = 25.0
# x : Corporations y : rights score = 33.333333333333336
# x : Corporations y : access score = 22.22222222222222
# x : Corporations y : policies score = 40.0
# x : Corporations y : rights of data subjects score = 22.857142857142854
# x : Corporations y : invasion score = 40.0
# x : Corporations y : anonymization score = 48.0
# x : Corporations y : pseudonymization score = 50.0
# x : Corporations y : trust score = 23.529411764705888
# x : Organizations y : privacy score = 30.000000000000004
# x : Organizations y : personal data score = 30.76923076923077
# x : Organizations y : processing score = 26.086956521739136
# x : Organizations y : data subjects score = 30.76923076923077
# x : Organizations y : purpose score = 30.000000000000004
# x : Organizations y : minimum necessary score = 26.66666666666667
# x : Organizations y : legally score = 19.999999999999996
# x : Organizations y : justly score = 10.526315789473683
# x : Organizations y : scope score = 11.111111111111116
# x : Organizations y : proper score = 21.052631578947366
# x : Organizations y : infringement score = 31.999999999999996
# x : Organizations y : rights score = 42.10526315789473
# x : Organizations y : access score = 21.052631578947366
# x : Organizations y : policies score = 28.57142857142857
# x : Organizations y : rights of data subjects score = 22.22222222222222
# x : Organizations y : invasion score = 47.61904761904761
# x : Organizations y : anonymization score = 69.23076923076923
# x : Organizations y : pseudonymization score = 55.172413793103445
# x : Organizations y : trust score = 22.22222222222222
# x : Individuals y : privacy score = 33.333333333333336
# x : Individuals y : personal data score = 25.0
# x : Individuals y : processing score = 9.523809523809524
# x : Individuals y : data subjects score = 25.0
# x : Individuals y : purpose score = 22.22222222222222
# x : Individuals y : minimum necessary score = 28.57142857142857
# x : Individuals y : legally score = 22.22222222222222
# x : Individuals y : justly score = 23.529411764705888
# x : Individuals y : scope score = 12.5
# x : Individuals y : proper score = 0.0
# x : Individuals y : infringement score = 17.391304347826086
# x : Individuals y : rights score = 23.529411764705888
# x : Individuals y : access score = 23.529411764705888
# x : Individuals y : policies score = 31.57894736842105
# x : Individuals y : rights of data subjects score = 23.529411764705888
# x : Individuals y : invasion score = 42.10526315789473
# x : Individuals y : anonymization score = 25.0
# x : Individuals y : pseudonymization score = 22.22222222222222
# x : Individuals y : trust score = 25.0
# x : Business purposes y : privacy score = 16.666666666666664
# x : Business purposes y : personal data score = 26.66666666666667
# x : Business purposes y : processing score = 37.03703703703704
# x : Business purposes y : data subjects score = 26.66666666666667
# x : Business purposes y : purpose score = 58.33333333333333
# x : Business purposes y : minimum necessary score = 35.29411764705882
# x : Business purposes y : legally score = 8.333333333333337
# x : Business purposes y : justly score = 17.391304347826086
# x : Business purposes y : scope score = 27.27272727272727
# x : Business purposes y : proper score = 34.78260869565217
# x : Business purposes y : infringement score = 27.586206896551722
# x : Business purposes y : rights score = 17.391304347826086
# x : Business purposes y : access score = 26.086956521739136
# x : Business purposes y : policies score = 31.999999999999996
# x : Business purposes y : rights of data subjects score = 30.000000000000004
# x : Business purposes y : invasion score = 31.999999999999996
# x : Business purposes y : anonymization score = 13.33333333333333
# x : Business purposes y : pseudonymization score = 24.242424242424242
# x : Business purposes y : trust score = 18.181818181818176
# x : Directly y : privacy score = 40.0
# x : Directly y : personal data score = 19.047619047619047
# x : Directly y : processing score = 22.22222222222222
# x : Directly y : data subjects score = 28.57142857142857
# x : Directly y : purpose score = 26.66666666666667
# x : Directly y : minimum necessary score = 31.999999999999996
# x : Directly y : legally score = 40.0
# x : Directly y : justly score = 42.85714285714286
# x : Directly y : scope score = 15.384615384615385
# x : Directly y : proper score = 28.57142857142857
# x : Directly y : infringement score = 40.0
# x : Directly y : rights score = 28.57142857142857
# x : Directly y : access score = 14.28571428571429
# x : Directly y : policies score = 25.0
# x : Directly y : rights of data subjects score = 25.806451612903224
# x : Directly y : invasion score = 12.5
# x : Directly y : anonymization score = 19.047619047619047
# x : Directly y : pseudonymization score = 16.666666666666664
# x : Directly y : trust score = 30.76923076923077
# x : Through others y : privacy score = 9.523809523809524
# x : Through others y : personal data score = 29.629629629629626
# x : Through others y : processing score = 33.333333333333336
# x : Through others y : data subjects score = 22.22222222222222
# x : Through others y : purpose score = 28.57142857142857
# x : Through others y : minimum necessary score = 25.806451612903224
# x : Through others y : legally score = 9.523809523809524
# x : Through others y : justly score = 19.999999999999996
# x : Through others y : scope score = 21.052631578947366
# x : Through others y : proper score = 40.0
# x : Through others y : infringement score = 23.076923076923073
# x : Through others y : rights score = 50.0
# x : Through others y : access score = 19.999999999999996
# x : Through others y : policies score = 27.27272727272727
# x : Through others y : rights of data subjects score = 32.432432432432435
# x : Through others y : invasion score = 9.090909090909093
# x : Through others y : anonymization score = 14.814814814814813
# x : Through others y : pseudonymization score = 19.999999999999996
# x : Through others y : trust score = 31.57894736842105
# x : Operate y : privacy score = 42.85714285714286
# x : Operate y : personal data score = 40.0
# x : Operate y : processing score = 35.29411764705882
# x : Operate y : data subjects score = 30.000000000000004
# x : Operate y : purpose score = 42.85714285714286
# x : Operate y : minimum necessary score = 16.666666666666664
# x : Operate y : legally score = 28.57142857142857
# x : Operate y : justly score = 15.384615384615385
# x : Operate y : scope score = 33.333333333333336
# x : Operate y : proper score = 46.15384615384615
# x : Operate y : infringement score = 21.052631578947366
# x : Operate y : rights score = 30.76923076923077
# x : Operate y : access score = 30.76923076923077
# x : Operate y : policies score = 26.66666666666667
# x : Operate y : rights of data subjects score = 19.999999999999996
# x : Operate y : invasion score = 13.33333333333333
# x : Operate y : anonymization score = 19.999999999999996
# x : Operate y : pseudonymization score = 34.78260869565217
# x : Operate y : trust score = 33.333333333333336
# x : Personal information files y : privacy score = 18.181818181818176
# x : Personal information files y : personal data score = 35.89743589743589
# x : Personal information files y : processing score = 33.333333333333336
# x : Personal information files y : data subjects score = 20.512820512820518
# x : Personal information files y : purpose score = 18.181818181818176
# x : Personal information files y : minimum necessary score = 23.25581395348837
# x : Personal information files y : legally score = 24.242424242424242
# x : Personal information files y : justly score = 12.5
# x : Personal information files y : scope score = 19.354838709677423
# x : Personal information files y : proper score = 25.0
# x : Personal information files y : infringement score = 31.57894736842105
# x : Personal information files y : rights score = 18.75
# x : Personal information files y : access score = 18.75
# x : Personal information files y : policies score = 29.411764705882348
# x : Personal information files y : rights of data subjects score = 28.57142857142857
# x : Personal information files y : invasion score = 35.29411764705882
# x : Personal information files y : anonymization score = 46.15384615384615
# x : Personal information files y : pseudonymization score = 42.85714285714286
# x : Personal information files y : trust score = 19.354838709677423
# x : Public institutions y : privacy score = 15.384615384615385
# x : Public institutions y : personal data score = 25.0
# x : Public institutions y : processing score = 27.586206896551722
# x : Public institutions y : data subjects score = 31.25
# x : Public institutions y : purpose score = 23.076923076923073
# x : Public institutions y : minimum necessary score = 33.333333333333336
# x : Public institutions y : legally score = 7.692307692307687
# x : Public institutions y : justly score = 24.0
# x : Public institutions y : scope score = 16.666666666666664
# x : Public institutions y : proper score = 7.9999999999999964
# x : Public institutions y : infringement score = 25.806451612903224
# x : Public institutions y : rights score = 24.0
# x : Public institutions y : access score = 24.0
# x : Public institutions y : policies score = 37.03703703703704
# x : Public institutions y : rights of data subjects score = 28.57142857142857
# x : Public institutions y : invasion score = 44.44444444444444
# x : Public institutions y : anonymization score = 37.5
# x : Public institutions y : pseudonymization score = 40.0
# x : Public institutions y : trust score = 25.0
# x : Administrative affairs y : privacy score = 27.586206896551722
# x : Administrative affairs y : personal data score = 34.285714285714285
# x : Administrative affairs y : processing score = 18.75
# x : Administrative affairs y : data subjects score = 28.57142857142857
# x : Administrative affairs y : purpose score = 13.793103448275868
# x : Administrative affairs y : minimum necessary score = 35.89743589743589
# x : Administrative affairs y : legally score = 13.793103448275868
# x : Administrative affairs y : justly score = 14.28571428571429
# x : Administrative affairs y : scope score = 14.814814814814813
# x : Administrative affairs y : proper score = 21.42857142857143
# x : Administrative affairs y : infringement score = 29.411764705882348
# x : Administrative affairs y : rights score = 21.42857142857143
# x : Administrative affairs y : access score = 21.42857142857143
# x : Administrative affairs y : policies score = 26.66666666666667
# x : Administrative affairs y : rights of data subjects score = 31.11111111111111
# x : Administrative affairs y : invasion score = 33.333333333333336
# x : Administrative affairs y : anonymization score = 28.57142857142857
# x : Administrative affairs y : pseudonymization score = 31.57894736842105
# x : Administrative affairs y : trust score = 22.22222222222222
# x : National Assembly y : privacy score = 16.666666666666664
# x : National Assembly y : personal data score = 40.0
# x : National Assembly y : processing score = 29.629629629629626
# x : National Assembly y : data subjects score = 19.999999999999996
# x : National Assembly y : purpose score = 16.666666666666664
# x : National Assembly y : minimum necessary score = 23.529411764705888
# x : National Assembly y : legally score = 25.0
# x : National Assembly y : justly score = 26.086956521739136
# x : National Assembly y : scope score = 18.181818181818176
# x : National Assembly y : proper score = 8.695652173913048
# x : National Assembly y : infringement score = 20.68965517241379
# x : National Assembly y : rights score = 8.695652173913048
# x : National Assembly y : access score = 17.391304347826086
# x : National Assembly y : policies score = 16.000000000000004
# x : National Assembly y : rights of data subjects score = 19.999999999999996
# x : National Assembly y : invasion score = 31.999999999999996
# x : National Assembly y : anonymization score = 40.0
# x : National Assembly y : pseudonymization score = 48.484848484848484
# x : National Assembly y : trust score = 18.181818181818176
# x : Courts y : privacy score = 15.384615384615385
# x : Courts y : personal data score = 21.052631578947366
# x : Courts y : processing score = 25.0
# x : Courts y : data subjects score = 31.57894736842105
# x : Courts y : purpose score = 46.15384615384615
# x : Courts y : minimum necessary score = 17.391304347826086
# x : Courts y : legally score = 0.0
# x : Courts y : justly score = 33.333333333333336
# x : Courts y : scope score = 18.181818181818176
# x : Courts y : proper score = 33.333333333333336
# x : Courts y : infringement score = 22.22222222222222
# x : Courts y : rights score = 50.0
# x : Courts y : access score = 16.666666666666664
# x : Courts y : policies score = 28.57142857142857
# x : Courts y : rights of data subjects score = 27.586206896551722
# x : Courts y : invasion score = 14.28571428571429
# x : Courts y : anonymization score = 21.052631578947366
# x : Courts y : pseudonymization score = 18.181818181818176
# x : Courts y : trust score = 36.36363636363637
# x : Constitutional Court y : privacy score = 14.814814814814813
# x : Constitutional Court y : personal data score = 30.303030303030297
# x : Constitutional Court y : processing score = 26.66666666666667
# x : Constitutional Court y : data subjects score = 30.303030303030297
# x : Constitutional Court y : purpose score = 14.814814814814813
# x : Constitutional Court y : minimum necessary score = 32.432432432432435
# x : Constitutional Court y : legally score = 14.814814814814813
# x : Constitutional Court y : justly score = 23.076923076923073
# x : Constitutional Court y : scope score = 16.000000000000004
# x : Constitutional Court y : proper score = 15.384615384615385
# x : Constitutional Court y : infringement score = 25.0
# x : Constitutional Court y : rights score = 15.384615384615385
# x : Constitutional Court y : access score = 7.692307692307687
# x : Constitutional Court y : policies score = 21.42857142857143
# x : Constitutional Court y : rights of data subjects score = 27.906976744186053
# x : Constitutional Court y : invasion score = 35.71428571428571
# x : Constitutional Court y : anonymization score = 42.42424242424242
# x : Constitutional Court y : pseudonymization score = 38.888888888888886
# x : Constitutional Court y : trust score = 24.0
# x : National Election Commission y : privacy score = 11.428571428571432
# x : National Election Commission y : personal data score = 29.268292682926834
# x : National Election Commission y : processing score = 26.315789473684216
# x : National Election Commission y : data subjects score = 19.512195121951216
# x : National Election Commission y : purpose score = 17.14285714285714
# x : National Election Commission y : minimum necessary score = 31.11111111111111
# x : National Election Commission y : legally score = 22.857142857142854
# x : National Election Commission y : justly score = 17.647058823529417
# x : National Election Commission y : scope score = 18.181818181818176
# x : National Election Commission y : proper score = 11.764705882352944
# x : National Election Commission y : infringement score = 30.000000000000004
# x : National Election Commission y : rights score = 11.764705882352944
# x : National Election Commission y : access score = 11.764705882352944
# x : National Election Commission y : policies score = 22.22222222222222
# x : National Election Commission y : rights of data subjects score = 27.450980392156865
# x : National Election Commission y : invasion score = 33.333333333333336
# x : National Election Commission y : anonymization score = 39.02439024390244
# x : National Election Commission y : pseudonymization score = 40.90909090909091
# x : National Election Commission y : trust score = 12.121212121212121
# x : Central administrative agencies y : privacy score = 26.315789473684216
# x : Central administrative agencies y : personal data score = 27.27272727272727
# x : Central administrative agencies y : processing score = 19.512195121951216
# x : Central administrative agencies y : data subjects score = 31.818181818181824
# x : Central administrative agencies y : purpose score = 15.789473684210531
# x : Central administrative agencies y : minimum necessary score = 37.5
# ...
# x : Mobile video information processing device y : personal data score = 29.09090909090909
# x : Mobile video information processing device y : processing score = 38.46153846153846
# x : Mobile video information processing device y : data subjects score = 21.818181818181813
# x : Mobile video information processing device y : purpose score = 20.408163265306122
# x : Mobile video information processing device y : minimum necessary score = 27.118644067796616
# x : Mobile video information processing device y : legally score = 12.244897959183676
# x : Mobile video information processing device y : justly score = 4.1666666666666625
# x : Mobile video information processing device y : scope score = 17.021276595744684
# x : Mobile video information processing device y : proper score = 16.666666666666664
# x : Mobile video information processing device y : infringement score = 29.629629629629626
# x : Mobile video information processing device y : rights score = 12.5
# x : Mobile video information processing device y : access score = 20.833333333333336
# x : Mobile video information processing device y : policies score = 28.000000000000004
# x : Mobile video information processing device y : rights of data subjects score = 30.76923076923077
# x : Mobile video information processing device y : invasion score = 24.0
# x : Mobile video information processing device y : anonymization score = 29.09090909090909
# x : Mobile video information processing device y : pseudonymization score = 31.034482758620683
# x : Mobile video information processing device y : trust score = 12.765957446808507
# x : Worn y : privacy score = 18.181818181818176
# x : Worn y : personal data score = 23.529411764705888
# x : Worn y : processing score = 28.57142857142857
# x : Worn y : data subjects score = 0.0
# x : Worn y : purpose score = 18.181818181818176
# x : Worn y : minimum necessary score = 9.523809523809524
# x : Worn y : legally score = 0.0
# x : Worn y : justly score = 0.0
# x : Worn y : scope score = 22.22222222222222
# x : Worn y : proper score = 40.0
# x : Worn y : infringement score = 25.0
# x : Worn y : rights score = 19.999999999999996
# x : Worn y : access score = 0.0
# x : Worn y : policies score = 16.666666666666664
# x : Worn y : rights of data subjects score = 14.814814814814813
# x : Worn y : invasion score = 33.333333333333336
# x : Worn y : anonymization score = 23.529411764705888
# x : Worn y : pseudonymization score = 19.999999999999996
# x : Worn y : trust score = 22.22222222222222
# x : Carried y : privacy score = 28.57142857142857
# x : Carried y : personal data score = 19.999999999999996
# x : Carried y : processing score = 23.529411764705888
# x : Carried y : data subjects score = 19.999999999999996
# x : Carried y : purpose score = 28.57142857142857
# x : Carried y : minimum necessary score = 16.666666666666664
# x : Carried y : legally score = 14.28571428571429
# x : Carried y : justly score = 0.0
# x : Carried y : scope score = 16.666666666666664
# x : Carried y : proper score = 30.76923076923077
# x : Carried y : infringement score = 31.57894736842105
# x : Carried y : rights score = 30.76923076923077
# x : Carried y : access score = 30.76923076923077
# x : Carried y : policies score = 26.66666666666667
# x : Carried y : rights of data subjects score = 26.66666666666667
# x : Carried y : invasion score = 26.66666666666667
# x : Carried y : anonymization score = 19.999999999999996
# x : Carried y : pseudonymization score = 17.391304347826086
# x : Carried y : trust score = 16.666666666666664
# x : Person y : privacy score = 15.384615384615385
# x : Person y : personal data score = 52.63157894736843
# x : Person y : processing score = 37.5
# x : Person y : data subjects score = 21.052631578947366
# x : Person y : purpose score = 30.76923076923077
# x : Person y : minimum necessary score = 17.391304347826086
# x : Person y : legally score = 15.384615384615385
# x : Person y : justly score = 16.666666666666664
# x : Person y : scope score = 36.36363636363637
# x : Person y : proper score = 33.333333333333336
# x : Person y : infringement score = 22.22222222222222
# x : Person y : rights score = 33.333333333333336
# x : Person y : access score = 33.333333333333336
# x : Person y : policies score = 28.57142857142857
# x : Person y : rights of data subjects score = 13.793103448275868
# x : Person y : invasion score = 42.85714285714286
# x : Person y : anonymization score = 21.052631578947366
# x : Person y : pseudonymization score = 27.27272727272727
# x : Person y : trust score = 36.36363636363637
# x : Movable object y : privacy score = 28.57142857142857
# x : Movable object y : personal data score = 22.22222222222222
# x : Movable object y : processing score = 16.666666666666664
# x : Movable object y : data subjects score = 51.85185185185186
# x : Movable object y : purpose score = 19.047619047619047
# x : Movable object y : minimum necessary score = 19.354838709677423
# x : Movable object y : legally score = 19.047619047619047
# x : Movable object y : justly score = 19.999999999999996
# x : Movable object y : scope score = 21.052631578947366
# x : Movable object y : proper score = 19.999999999999996
# x : Movable object y : infringement score = 23.076923076923073
# x : Movable object y : rights score = 9.999999999999998
# x : Movable object y : access score = 19.999999999999996
# x : Movable object y : policies score = 27.27272727272727
# x : Movable object y : rights of data subjects score = 43.24324324324324
# x : Movable object y : invasion score = 27.27272727272727
# x : Movable object y : anonymization score = 22.22222222222222
# x : Movable object y : pseudonymization score = 19.999999999999996
# x : Movable object y : trust score = 10.526315789473683
# x : Capture y : privacy score = 28.57142857142857
# x : Capture y : personal data score = 30.000000000000004
# x : Capture y : processing score = 35.29411764705882
# x : Capture y : data subjects score = 40.0
# x : Capture y : purpose score = 57.14285714285714
# x : Capture y : minimum necessary score = 16.666666666666664
# x : Capture y : legally score = 14.28571428571429
# x : Capture y : justly score = 15.384615384615385
# x : Capture y : scope score = 33.333333333333336
# x : Capture y : proper score = 46.15384615384615
# x : Capture y : infringement score = 21.052631578947366
# x : Capture y : rights score = 15.384615384615385
# x : Capture y : access score = 30.76923076923077
# x : Capture y : policies score = 26.66666666666667
# x : Capture y : rights of data subjects score = 26.66666666666667
# x : Capture y : invasion score = 13.33333333333333
# x : Capture y : anonymization score = 19.999999999999996
# x : Capture y : pseudonymization score = 17.391304347826086
# x : Capture y : trust score = 33.333333333333336
# x : Scientific research y : privacy score = 23.076923076923073
# x : Scientific research y : personal data score = 31.25
# x : Scientific research y : processing score = 20.68965517241379
# x : Scientific research y : data subjects score = 31.25
# x : Scientific research y : purpose score = 23.076923076923073
# x : Scientific research y : minimum necessary score = 44.44444444444444
# x : Scientific research y : legally score = 15.384615384615385
# x : Scientific research y : justly score = 7.9999999999999964
# x : Scientific research y : scope score = 16.666666666666664
# x : Scientific research y : proper score = 24.0
# x : Scientific research y : infringement score = 38.70967741935484
# x : Scientific research y : rights score = 24.0
# x : Scientific research y : access score = 31.999999999999996
# x : Scientific research y : policies score = 29.629629629629626
# x : Scientific research y : rights of data subjects score = 33.333333333333336
# x : Scientific research y : invasion score = 22.22222222222222
# x : Scientific research y : anonymization score = 18.75
# x : Scientific research y : pseudonymization score = 22.857142857142854
# x : Scientific research y : trust score = 25.0
# x : Research y : privacy score = 26.66666666666667
# x : Research y : personal data score = 28.57142857142857
# x : Research y : processing score = 22.22222222222222
# x : Research y : data subjects score = 28.57142857142857
# x : Research y : purpose score = 26.66666666666667
# x : Research y : minimum necessary score = 31.999999999999996
# x : Research y : legally score = 26.66666666666667
# x : Research y : justly score = 14.28571428571429
# x : Research y : scope score = 30.76923076923077
# x : Research y : proper score = 28.57142857142857
# x : Research y : infringement score = 19.999999999999996
# x : Research y : rights score = 28.57142857142857
# x : Research y : access score = 28.57142857142857
# x : Research y : policies score = 25.0
# x : Research y : rights of data subjects score = 19.354838709677423
# x : Research y : invasion score = 12.5
# x : Research y : anonymization score = 9.523809523809524
# x : Research y : pseudonymization score = 25.0
# x : Research y : trust score = 15.384615384615385
# x : Scientific methods y : privacy score = 16.000000000000004
# x : Scientific methods y : personal data score = 25.806451612903224
# x : Scientific methods y : processing score = 21.42857142857143
# x : Scientific methods y : data subjects score = 32.25806451612904
# x : Scientific methods y : purpose score = 16.000000000000004
# x : Scientific methods y : minimum necessary score = 34.285714285714285
# x : Scientific methods y : legally score = 7.9999999999999964
# x : Scientific methods y : justly score = 8.333333333333337
# x : Scientific methods y : scope score = 17.391304347826086
# x : Scientific methods y : proper score = 8.333333333333337
# x : Scientific methods y : infringement score = 46.666666666666664
# x : Scientific methods y : rights score = 25.0
# x : Scientific methods y : access score = 33.333333333333336
# x : Scientific methods y : policies score = 30.76923076923077
# x : Scientific methods y : rights of data subjects score = 34.14634146341463
# x : Scientific methods y : invasion score = 30.76923076923077
# x : Scientific methods y : anonymization score = 25.806451612903224
# x : Scientific methods y : pseudonymization score = 29.411764705882348
# x : Scientific methods y : trust score = 17.391304347826086
# x : Technology development y : privacy score = 13.793103448275868
# x : Technology development y : personal data score = 22.857142857142854
# x : Technology development y : processing score = 18.75
# x : Technology development y : data subjects score = 17.14285714285714
# x : Technology development y : purpose score = 13.793103448275868
# x : Technology development y : minimum necessary score = 20.512820512820518
# x : Technology development y : legally score = 20.68965517241379
# x : Technology development y : justly score = 14.28571428571429
# x : Technology development y : scope score = 29.629629629629626
# x : Technology development y : proper score = 21.42857142857143
# x : Technology development y : infringement score = 41.17647058823529
# x : Technology development y : rights score = 14.28571428571429
# x : Technology development y : access score = 14.28571428571429
# x : Technology development y : policies score = 19.999999999999996
# x : Technology development y : rights of data subjects score = 22.22222222222222
# x : Technology development y : invasion score = 26.66666666666667
# x : Technology development y : anonymization score = 28.57142857142857
# x : Technology development y : pseudonymization score = 26.315789473684216
# x : Technology development y : trust score = 7.4074074074074066
# x : Demonstration y : privacy score = 19.999999999999996
# x : Demonstration y : personal data score = 30.76923076923077
# x : Demonstration y : processing score = 34.78260869565217
# x : Demonstration y : data subjects score = 23.076923076923073
# x : Demonstration y : purpose score = 19.999999999999996
# x : Demonstration y : minimum necessary score = 26.66666666666667
# x : Demonstration y : legally score = 19.999999999999996
# x : Demonstration y : justly score = 21.052631578947366
# x : Demonstration y : scope score = 22.22222222222222
# x : Demonstration y : proper score = 21.052631578947366
# x : Demonstration y : infringement score = 31.999999999999996
# x : Demonstration y : rights score = 21.052631578947366
# x : Demonstration y : access score = 21.052631578947366
# x : Demonstration y : policies score = 19.047619047619047
# x : Demonstration y : rights of data subjects score = 16.666666666666664
# x : Demonstration y : invasion score = 47.61904761904761
# x : Demonstration y : anonymization score = 53.84615384615385
# x : Demonstration y : pseudonymization score = 55.172413793103445
# x : Demonstration y : trust score = 33.333333333333336
# x : Basic research y : privacy score = 28.57142857142857
# x : Basic research y : personal data score = 37.03703703703704
# x : Basic research y : processing score = 25.0
# x : Basic research y : data subjects score = 37.03703703703704
# x : Basic research y : purpose score = 28.57142857142857
# x : Basic research y : minimum necessary score = 38.70967741935484
# x : Basic research y : legally score = 19.047619047619047
# x : Basic research y : justly score = 9.999999999999998
# x : Basic research y : scope score = 31.57894736842105
# x : Basic research y : proper score = 30.000000000000004
# x : Basic research y : infringement score = 30.76923076923077
# x : Basic research y : rights score = 19.999999999999996
# x : Basic research y : access score = 40.0
# x : Basic research y : policies score = 36.36363636363637
# x : Basic research y : rights of data subjects score = 32.432432432432435
# x : Basic research y : invasion score = 27.27272727272727
# x : Basic research y : anonymization score = 22.22222222222222
# x : Basic research y : pseudonymization score = 19.999999999999996
# x : Basic research y : trust score = 21.052631578947366
# x : Applied research y : privacy score = 34.78260869565217
# x : Applied research y : personal data score = 34.48275862068966
# x : Applied research y : processing score = 30.76923076923077
# x : Applied research y : data subjects score = 34.48275862068966
# x : Applied research y : purpose score = 34.78260869565217
# x : Applied research y : minimum necessary score = 36.36363636363637
# x : Applied research y : legally score = 26.086956521739136
# x : Applied research y : justly score = 9.090909090909093
# x : Applied research y : scope score = 19.047619047619047
# x : Applied research y : proper score = 36.36363636363637
# x : Applied research y : infringement score = 28.57142857142857
# x : Applied research y : rights score = 18.181818181818176
# x : Applied research y : access score = 18.181818181818176
# x : Applied research y : policies score = 41.666666666666664
# x : Applied research y : rights of data subjects score = 30.76923076923077
# x : Applied research y : invasion score = 16.666666666666664
# x : Applied research y : anonymization score = 13.793103448275868
# x : Applied research y : pseudonymization score = 25.0
# x : Applied research y : trust score = 19.047619047619047
# x : Privately funded research y : privacy score = 31.25
# x : Privately funded research y : personal data score = 36.8421052631579
# x : Privately funded research y : processing score = 17.14285714285714
# x : Privately funded research y : data subjects score = 31.57894736842105
# x : Privately funded research y : purpose score = 25.0
# x : Privately funded research y : minimum necessary score = 38.095238095238095
# x : Privately funded research y : legally score = 18.75
# x : Privately funded research y : justly score = 19.354838709677423
# x : Privately funded research y : scope score = 13.33333333333333
# x : Privately funded research y : proper score = 19.354838709677423
# x : Privately funded research y : infringement score = 27.027027027027028
# x : Privately funded research y : rights score = 25.806451612903224
# x : Privately funded research y : access score = 19.354838709677423
# x : Privately funded research y : policies score = 18.181818181818176
# x : Privately funded research y : rights of data subjects score = 37.5
# x : Privately funded research y : invasion score = 24.242424242424242
# x : Privately funded research y : anonymization score = 21.052631578947366
# x : Privately funded research y : pseudonymization score = 19.512195121951216
# x : Privately funded research y : trust score = 19.999999999999996

# %%
same_entities
# Out:
# {'Processing': 'processing', 'Data subject': 'data subjects'}

# %%
pairs
# Out:
# [({'id': 'e1',
#    'entities': ['Personal information',
#     'living individuals',
#     'categories',
#     'Collection',
#     'Generation',
#     'Connection',
#     'Integration',
#     'Recording',
#     'Storage',
#     'Retention',
#     'Processing',
#     'Editing',
#     'Retrieval',
#     'Output',
#     'Correction',
#     'Recovery',
#     'Use',
#     'Provision',
#     'Disclosure',
#     'Destruction',
#     'Similar actions',
#     'Personal information file',
#     'Systematically arranged',
#     'Organized',
#     'Easy search',
#     'Data subject',
#     'Person',
#     'Subject',
#     'Personal information processor',
#     'Public institutions',
#     'Corporations',
#     'Organizations',
#     'Individuals',
#     'Business purposes',
#     'Directly',
#     'Through others',
#     'Operate',
#     'Personal information files',
#     'Public institutions',
#     'Administrative affairs',
#     'National Assembly',
#     'Courts',
#     'Constitutional Court',
#     'National Election Commission',
#     'Central administrative agencies',
#     'Affiliated organizations',
#     'Local governments',
#     'National institutions',
#     'Public organizations',
#     'Presidential Decree',
#     'Fixed video information processing device',
#     'Space',
#     'Continuously',
#     'Periodically',
#     'Images',
#     'People',
#     'Objects',
#     'Wired',
#     'Wireless networks',
#     'Transmit',
#     'Mobile video information processing device',
#     'Worn',
#     'Carried',
#     'Person',
#     'Movable object',
#     'Capture',
#     'Scientific research',
#     'Research',
#     'Scientific methods',
#     'Technology development',
#     'Demonstration',
#     'Basic research',
#     'Applied research',
#     'Privately funded research'],
#    'source': ['group:1']},
#   {'id': 'e1',
#    'entities': ['privacy',
#     'personal data',
#     'processing',
#     'data subjects',
#     'purpose',
#     'minimum necessary',
#     'legally',
#     'justly',
#     'scope',
#     'proper',
#     'infringement',
#     'rights',
#     'access',
#     'policies',
#     'rights of data subjects',
#     'invasion',
#     'anonymization',
#     'pseudonymization',
#     'trust'],
#    'source': ['group:2']})]

# %%
ents_f = pairs[:]  # shallow copy
ents_f
# Out:
# [({'id': 'e1',
#    'entities': ['Personal information',
#     'living individuals',
#     'categories',
#     'Collection',
#     'Generation',
#     'Connection',
#     'Integration',
#     'Recording',
#     'Storage',
#     'Retention',
#     'Processing',
#     'Editing',
#     'Retrieval',
#     'Output',
#     'Correction',
#     'Recovery',
#     'Use',
#     'Provision',
#     'Disclosure',
#     'Destruction',
#     'Similar actions',
#     'Personal information file',
#     'Systematically arranged',
#     'Organized',
#     'Easy search',
#     'Data subject',
#     'Person',
#     'Subject',
#     'Personal information processor',
#     'Public institutions',
#     'Corporations',
#     'Organizations',
#     'Individuals',
#     'Business purposes',
#     'Directly',
#     'Through others',
#     'Operate',
#     'Personal information files',
#     'Public institutions',
#     'Administrative affairs',
#     'National Assembly',
#     'Courts',
#     'Constitutional Court',
#     'National Election Commission',
#     'Central administrative agencies',
#     'Affiliated organizations',
#     'Local governments',
#     'National institutions',
#     'Public organizations',
#     'Presidential Decree',
#     'Fixed video information processing device',
#     'Space',
#     'Continuously',
#     'Periodically',
#     'Images',
#     'People',
#     'Objects',
#     'Wired',
#     'Wireless networks',
#     'Transmit',
#     'Mobile video information processing device',
#     'Worn',
#     'Carried',
#     'Person',
#     'Movable object',
#     'Capture',
#     'Scientific research',
#     'Research',
#     'Scientific methods',
#     'Technology development',
#     'Demonstration',
#     'Basic research',
#     'Applied research',
#     'Privately funded research'],
#    'source': ['group:1']},
#   {'id': 'e1',
#    'entities': ['privacy',
#     'personal data',
#     'processing',
#     'data subjects',
#     'purpose',
#     'minimum necessary',
#     'legally',
#     'justly',
#     'scope',
#     'proper',
#     'infringement',
#     'rights',
#     'access',
#     'policies',
#     'rights of data subjects',
#     'invasion',
#     'anonymization',
#     'pseudonymization',
#     'trust'],
#    'source': ['group:2']})]

# %%
# canonical 항목을 entities와 relations 생성할 때 만들어두자
ents_f = pairs[:]  # shallow copy
changed = True
while changed:
    changed = False
    for a, b in ents_f:
        if llm_equiv(a, b):
            # 누락 키 보정
            a.setdefault("entities", []); b.setdefault("entities", [])
            a.setdefault("source",  []); b.setdefault("source",  [])

            # alias 병합(원래 canonical까지 alias로 흡수)
            a["entities"] = sorted(set(
                a["entities"] + [a.get("canonical",""), b.get("canonical","")] + b["aliases"]
            ))

            # 대표명 선택(간단: 더 짧은 쪽; 필요시 규칙 고도화)
            if a.get("canonical") and b.get("canonical"):
                a["canonical"] = min([a["canonical"], b["canonical"]], key=len)
            else:
                a["canonical"] = a.get("canonical") or b.get("canonical")

            # source 병합
            a["source"] = sorted(set(a["source"] + b["source"]))

            # 타입/정의 충돌 등은 필요시 추가 규칙으로 조정
            # 예: a["type"] 우선, 없으면 b["type"] 채우기
            if not a.get("type") and b.get("type"):
                a["type"] = b["type"]

            # b 제거 후 다시 루프 시작
            ents.remove(b)
            changed = True
            break
return ents
